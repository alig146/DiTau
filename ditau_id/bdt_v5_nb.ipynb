# %%
import uproot, ROOT, glob, os, random
import matplotlib.pyplot as plt
import numpy as np
import awkward as ak
from sklearn.metrics import roc_curve, roc_auc_score, auc
from tqdm import tqdm
import pandas as pd
from xgboost import XGBClassifier
import seaborn as sns
from sklearn.metrics import roc_curve, roc_auc_score, auc, accuracy_score
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV, train_test_split

# Set up plot defaults
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = 12.0,8.0  # Roughly 11 cm wde by 8 cm high
mpl.rcParams['font.size'] = 16.0 # Use 14 point font
sns.set(style="whitegrid")

path = '/eos/user/j/jlai/ditau/'

# %%
branches = ['ditau_pt', 'n_subjets', 'IsTruthHadronic', 'n_tracks_lead', 'n_tracks_subl',
 'R_max_lead', 'R_max_subl', 'R_tracks_subl', 'R_isotrack', 'd0_leadtrack_lead',
 'd0_leadtrack_subl', 'f_core_lead', 'f_core_subl', 'f_subjet_subl', 'f_subjets',
 'f_isotracks', 'm_core_lead', 'm_core_subl', 'm_tracks_lead', 'm_tracks_subl',
 'n_track']

training_vars = [
    "f_core_lead", "f_core_subl", "f_subjet_subl", "f_subjets", "f_isotracks",
    "R_max_lead", "R_max_subl", "R_isotrack", "R_tracks_subl", "m_core_lead",
    "m_core_subl", "m_tracks_lead", "m_tracks_subl", "d0_leadtrack_lead",
    "d0_leadtrack_subl", "n_track", "n_tracks_lead"
]

signal = pd.read_csv(path+'combined_signal_inc_2.csv')
bkg = pd.read_csv(path+'combined_bkg_inc_2.csv')
df = pd.concat((bkg, signal))
df = df[4:] # get rid of jz0 and jz1
df = df[df.f_core_subl != -999]
df
# Out:
#         event_id   ditau_pt  IsTruthHadronic  f_core_lead  f_core_subl  \
# 4       28661182  207010.69                0     0.883104     0.701180
# 5       31012373  202973.78                0     0.893525     0.713387
# 6       26917460  221883.73                0     0.882286     0.677054
# 7       31183017  223984.75                0     0.841569     0.756340
# 8       32682502  211992.60                0     0.749230     0.562946
# ...          ...        ...              ...          ...          ...
# 293151  41863732  402376.50                1     0.938707     0.819963
# 293152  41875682  257150.30                1     0.937242     0.856229
# 293153  41933178  483415.30                1     0.962991     0.943157
# 293154  41978643  265805.56                1     0.884850     0.891054
# 293155  42031082  292039.50                1     0.829967     0.890932
#
#         f_subjet_subl  f_subjets  f_isotracks  R_max_lead  R_max_subl  ...  \
# 4            0.167451   0.676483     0.022352    0.041758    0.114734  ...
# 5            0.213471   0.608883     0.013195    0.046999    0.161529  ...
# 6            0.317602   0.644228     0.009284    0.103811    0.168752  ...
# 7            0.274110   0.674390     0.023144    0.047328    0.143165  ...
# 8            0.325747   0.695295     0.012508    0.160978    0.177324  ...
# ...               ...        ...          ...         ...         ...  ...
# 293151       0.128798   0.858344     0.002552    0.010547    0.011293  ...
# 293152       0.368471   0.830305     0.000000    0.023579    0.013075  ...
# 293153       0.263034   0.892043     0.000000    0.012886    0.021818  ...
# 293154       0.140300   0.820904     0.022341    0.008732    0.026567  ...
# 293155       0.104433   0.842942     0.000000    0.012940    0.036800  ...
#
#         n_tracks_subl  n_subjets  event_weight  bdt_score  bdt_score_new  \
# 4                   3          3  1.601067e-01   0.437940       0.165671
# 5                   3          3  2.489046e-02   0.509698       0.451603
# 6                   1          3  5.294116e-03   0.561275       0.070575
# 7                   3          4  9.956257e-02   0.461499       0.092040
# 8                   1          3  4.558297e-03   0.521241       0.048879
# ...               ...        ...           ...        ...            ...
# 293151              1          2  2.144577e-10   0.800688       0.995590
# 293152              1          2  2.144577e-10   0.750652       0.992877
# 293153              3          2  2.144577e-10   0.763553       0.995572
# 293154              1          2  2.144577e-10   0.701484       0.970486
# 293155              1          2  2.144577e-10   0.747585       0.984207
#
#         average_mu       eta    pT_weight  label        weight
# 4        41.499996  0.418528     0.004301      0  6.886847e-04
# 5        56.499996 -0.050249     0.004301      0  1.070641e-04
# 6        42.500000  2.297925     0.004747      0  2.513207e-05
# 7        64.500000 -1.814815     0.004747      0  4.726405e-04
# 8        28.500000  0.286800     0.004301      0  1.960712e-05
# ...            ...       ...          ...    ...           ...
# 293151   27.500000 -1.050984  1824.306013      1  3.912365e-07
# 293152   34.500000  2.017023  3640.309120      1  7.806923e-07
# 293153   30.500000  0.047959  4056.854290      1  8.700236e-07
# 293154   34.500000  2.286975  2174.839596      1  4.664111e-07
# 293155   25.500000  1.053581  1656.795336      1  3.553125e-07
#
# [2473713 rows x 30 columns]

# %%
df.describe()
# Out:
#            event_id      ditau_pt  IsTruthHadronic   f_core_lead  \
# count  2.473713e+06  2.473713e+06     2.473713e+06  2.473713e+06
# mean   2.003528e+08  4.296035e+05     1.185113e-01  8.505446e-01
# std    1.545614e+08  1.876293e+05     3.232127e-01  9.424032e-02
# min    3.000000e+00  2.000000e+05     0.000000e+00  4.786014e-03
# 25%    7.041102e+07  2.796222e+05     0.000000e+00  8.115990e-01
# 50%    1.849358e+08  3.811366e+05     0.000000e+00  8.698879e-01
# 75%    2.902421e+08  5.274780e+05     0.000000e+00  9.138681e-01
# max    4.930031e+08  9.999968e+05     1.000000e+00  9.986886e-01
#
#         f_core_subl  f_subjet_subl     f_subjets   f_isotracks    R_max_lead  \
# count  2.473713e+06   2.473713e+06  2.473713e+06  2.473713e+06  2.473713e+06
# mean   4.819580e-01   8.445789e-02  8.058504e-01  1.515649e-02  8.952992e-02
# std    2.567821e-01   9.161817e-02  1.075705e-01  6.377339e-02  6.506292e-02
# min    2.094379e-04   1.801535e-03  3.916248e-02  0.000000e+00  3.297358e-05
# 25%    2.709139e-01   2.879310e-02  7.443783e-01  3.991326e-03  2.596715e-02
# 50%    4.817073e-01   4.407397e-02  8.262419e-01  1.004901e-02  7.959136e-02
# 75%    6.869910e-01   9.788671e-02  8.862035e-01  1.973761e-02  1.522916e-01
# max    1.000000e+00   5.146357e-01  1.067907e+00  3.583736e+01  2.000000e-01
#
#          R_max_subl  ...  n_tracks_subl     n_subjets  event_weight  \
# count  2.473713e+06  ...   2.473713e+06  2.473713e+06  2.473713e+06
# mean   1.167343e-01  ...   1.627250e+00  2.541615e+00  2.126776e-04
# std    5.863327e-02  ...   9.279319e-01  9.024732e-01  1.668307e-03
# min    6.460488e-06  ...   1.000000e+00  2.000000e+00  4.974442e-16
# 25%    7.020884e-02  ...   1.000000e+00  2.000000e+00  3.917005e-06
# 50%    1.261026e-01  ...   1.000000e+00  2.000000e+00  2.440057e-05
# 75%    1.683205e-01  ...   3.000000e+00  3.000000e+00  2.105218e-04
# max    2.000000e-01  ...   3.000000e+00  1.600000e+01  1.443402e+00
#
#           bdt_score  bdt_score_new    average_mu           eta     pT_weight  \
# count  2.473713e+06   2.473713e+06  2.473713e+06  2.473713e+06  2.473713e+06
# mean   5.192061e-01   1.865045e-01  4.110041e+01  5.381839e-03  2.722449e+03
# std    1.166254e-01   3.299586e-01  1.391164e+01  1.213811e+00  1.406259e+04
# min    2.524264e-01   1.220086e-03  5.000000e-01 -2.499992e+00  4.301412e-03
# 25%    4.299696e-01   5.293073e-03  3.050000e+01 -9.892353e-01  1.551935e-02
# 50%    5.049655e-01   1.783987e-02  3.950000e+01  4.849960e-03  1.984280e-01
# 75%    5.844420e-01   1.335730e-01  5.250000e+01  1.003411e+00  3.996098e+00
# max    8.279592e-01   9.969252e-01  9.050000e+01  2.499999e+00  1.836084e+05
#
#               label        weight
# count  2.473713e+06  2.473713e+06
# mean   1.185085e-01  3.152043e-05
# std    3.232093e-01  1.442587e-04
# min    0.000000e+00  2.139712e-18
# 25%    0.000000e+00  3.041491e-06
# 50%    0.000000e+00  8.884095e-06
# 75%    0.000000e+00  2.472884e-05
# max    1.000000e+00  3.093709e-02
#
# [8 rows x 30 columns]

# %%
df_1p1p = df[(df['n_tracks_lead'] == 1) & (df['n_tracks_subl'] == 1)]
df_3p3p = df[(df['n_tracks_lead'] == 3) & (df['n_tracks_subl'] == 3)]
df_1p3p = df[
    ((df['n_tracks_lead'] == 1) & (df['n_tracks_subl'] == 3)) |
    ((df['n_tracks_lead'] == 3) & (df['n_tracks_subl'] == 1))
]


len(df_1p1p), len(df_3p3p), len(df_1p3p)
# Out:
# (525646, 633118, 1314949)

# %%
def BDT(df):
    training_vars = ["f_core_lead",
                    "f_core_subl",
                    "f_subjet_subl",
                    "f_subjets",
                    "f_isotracks",
                    "R_max_lead",
                    "R_max_subl",
                    "R_isotrack",
                    "R_tracks_subl",
                    "m_core_lead",
                    "m_core_subl",
                    "m_tracks_lead",
                    "m_tracks_subl",
                    "d0_leadtrack_lead",
                    "d0_leadtrack_subl",
                    "n_track",
                    "n_tracks_lead"]


    # Scrambling
    # Calculate the modulo of each eventID with 5
    df['eventID_mod'] = df['event_id'] % 5

    df['weight'] = df['event_weight'] * df['pT_weight']

    log_vars = ["f_isotracks", "m_core_lead", "m_core_subl", "m_tracks_lead", "m_tracks_subl"]
    abs_log_var = ["d0_leadtrack_lead", "d0_leadtrack_subl"]

    train_df = df[df['eventID_mod'] < 4] # 80%
    test_df = df[df['eventID_mod'] == 4] # 20%
    print(f'train bkg: {len(train_df[train_df.label==0])}, train signal: {len(train_df[train_df.label==1])}, test bkg: {len(test_df[test_df.label==0])}, test signal: {len(test_df[test_df.label==1])}')

    train_df = train_df.drop(columns='eventID_mod')
    test_df = test_df.drop(columns='eventID_mod')

    # Training & Testing sets
    training_data, testing_data, training_labels, testing_labels, training_weights, testing_weights = \
    train_df[training_vars], test_df[training_vars], train_df['label'], test_df['label'], train_df['weight'], test_df['weight']

    #Change column names to integers if needed (for ML models that expect numerical feature names)
    feature_mapping = {feature: i for i, feature in enumerate(training_data.columns)}
    training_data.rename(columns=feature_mapping, inplace=True)
    feature_mapping = {feature: i for i, feature in enumerate(testing_data.columns)}
    testing_data.rename(columns=feature_mapping, inplace=True)

    # Define the classifier
    bdt = XGBClassifier(random_state=0, verbosity=1)

    # Define the parameter distribution
    param_dist = {
        'n_estimators': [100, 150, 200, 250, 300, 350, 400, 450, 500],
        'learning_rate': [0.01, 0.05, 0.1, 0.15, 0.2, 0.3],
        'max_depth': [2, 3, 4, 5, 6]
    }

    # Define the search with RandomizedSearchCV
    random_search = RandomizedSearchCV(estimator=bdt, param_distributions=param_dist, n_iter=30, scoring='accuracy', cv=3, verbose=2, random_state=0, n_jobs=-1)

    # Perform the search
    # Note: We don't use the testing set here; it's for final evaluation
    random_search.fit(training_data, training_labels, sample_weight=training_weights)

    # Best estimator found by RandomizedSearchCV
    best_estimator = random_search.best_estimator_

    # Manually apply early stopping using a portion of the training set as a validation set
    # Note: XGBoost handles validation sets for early stopping, but we use training and testing sets as provided
    eval_set = [(testing_data, testing_labels)]
    best_estimator.fit(training_data, training_labels, sample_weight=training_weights, early_stopping_rounds=10, eval_metric="logloss", eval_set=eval_set, verbose=True)

    # Predictions and final evaluation on the testing set
    predictions = best_estimator.predict(testing_data)
    accuracy = accuracy_score(testing_labels, predictions, sample_weight=testing_weights)

    # Output the results
    print("Best parameters found: ", random_search.best_params_)
    print("Testing accuracy after early stopping: ", accuracy)

    # Predict probabilities for the testing data
    probs = best_estimator.predict_proba(testing_data)
    probs = probs[:, 1]
    
    # Feature Importance
    importance = best_estimator.feature_importances_
    # Re-map the feature importance scores to the original feature names
    feature_importances = {training_vars[i]: score for i, score in enumerate(importance)}

    # Plot feature importance
    plt.figure(figsize=(10, 8))
    plt.barh(range(len(feature_importances)), list(feature_importances.values()), align='center')
    plt.yticks(range(len(feature_importances)), list(feature_importances.keys()))
    plt.xlabel('Feature Importance Score')
    plt.title('Feature Importances')
    plt.show()

    fpr, tpr, thresholds = roc_curve(testing_labels, probs, sample_weight=testing_weights)
    auc = roc_auc_score(testing_labels, probs, sample_weight=testing_weights)


    return fpr, tpr, thresholds, auc

# %%
fpr1, tpr1, thresholds1, auc1 = BDT(df_1p1p)
fpr2, tpr2, thresholds2, auc2 = BDT(df_3p3p)
fpr3, tpr3, thresholds3, auc3 = BDT(df_1p3p)
fpr4, tpr4, thresholds4, auc4 = BDT(df)
# Out:
# /tmp/ipykernel_389/3592393373.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['eventID_mod'] = df['event_id'] % 5
# /tmp/ipykernel_389/3592393373.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weight'] = df['event_weight'] * df['pT_weight']
# train bkg: 293741, train signal: 126417, test bkg: 73962, test signal: 31526
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# /tmp/ipykernel_389/3592393373.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data.rename(columns=feature_mapping, inplace=True)
# /tmp/ipykernel_389/3592393373.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data.rename(columns=feature_mapping, inplace=True)
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.90762
# [1]	validation_0-logloss:0.78552
# [2]	validation_0-logloss:0.68963
# [3]	validation_0-logloss:0.62521
# [4]	validation_0-logloss:0.56593
# [5]	validation_0-logloss:0.51773
# [6]	validation_0-logloss:0.48911
# [7]	validation_0-logloss:0.45994
# [8]	validation_0-logloss:0.43125
# [9]	validation_0-logloss:0.40392
# [10]	validation_0-logloss:0.38989
# [11]	validation_0-logloss:0.37239
# [12]	validation_0-logloss:0.36569
# [13]	validation_0-logloss:0.36522
# [14]	validation_0-logloss:0.36484
# [15]	validation_0-logloss:0.36453
# [16]	validation_0-logloss:0.36429
# [17]	validation_0-logloss:0.36410
# [18]	validation_0-logloss:0.36394
# [19]	validation_0-logloss:0.36382
# [20]	validation_0-logloss:0.36372
# [21]	validation_0-logloss:0.36364
# [22]	validation_0-logloss:0.36358
# [23]	validation_0-logloss:0.36353
# [24]	validation_0-logloss:0.36349
# [25]	validation_0-logloss:0.36346
# [26]	validation_0-logloss:0.36343
# [27]	validation_0-logloss:0.36341
# [28]	validation_0-logloss:0.36339
# [29]	validation_0-logloss:0.36338
# [30]	validation_0-logloss:0.36337
# [31]	validation_0-logloss:0.36336
# [32]	validation_0-logloss:0.36335
# [33]	validation_0-logloss:0.36335
# [34]	validation_0-logloss:0.36334
# [35]	validation_0-logloss:0.36334
# [36]	validation_0-logloss:0.36334
# [37]	validation_0-logloss:0.36334
# [38]	validation_0-logloss:0.36333
# [39]	validation_0-logloss:0.36333
# [40]	validation_0-logloss:0.36333
# [41]	validation_0-logloss:0.36333
# [42]	validation_0-logloss:0.36333
# [43]	validation_0-logloss:0.36333
# [44]	validation_0-logloss:0.36333
# [45]	validation_0-logloss:0.36333
# [46]	validation_0-logloss:0.36333
# [47]	validation_0-logloss:0.36333
# [48]	validation_0-logloss:0.36333
# [49]	validation_0-logloss:0.36333
# [50]	validation_0-logloss:0.36333
# [51]	validation_0-logloss:0.36333
# [52]	validation_0-logloss:0.36333
# [53]	validation_0-logloss:0.36333
# [54]	validation_0-logloss:0.36333
# [55]	validation_0-logloss:0.36333
# [56]	validation_0-logloss:0.36333
# [57]	validation_0-logloss:0.36333
# [58]	validation_0-logloss:0.36333
# [59]	validation_0-logloss:0.36333
# [60]	validation_0-logloss:0.36333
# [61]	validation_0-logloss:0.36333
# [62]	validation_0-logloss:0.36333
# [63]	validation_0-logloss:0.36333
# [64]	validation_0-logloss:0.36333
# [65]	validation_0-logloss:0.36333
# [66]	validation_0-logloss:0.36333
# [67]	validation_0-logloss:0.36333
# [68]	validation_0-logloss:0.36333
# [69]	validation_0-logloss:0.36333
# [70]	validation_0-logloss:0.36333
# [71]	validation_0-logloss:0.36333
# [72]	validation_0-logloss:0.36333
# [73]	validation_0-logloss:0.36333
# [74]	validation_0-logloss:0.36333
# [75]	validation_0-logloss:0.36333
# [76]	validation_0-logloss:0.36333
# [77]	validation_0-logloss:0.36333
# [78]	validation_0-logloss:0.36333
# [79]	validation_0-logloss:0.36333
# [80]	validation_0-logloss:0.36333
# [81]	validation_0-logloss:0.36333
# [82]	validation_0-logloss:0.36333
# [83]	validation_0-logloss:0.36333
# [84]	validation_0-logloss:0.36333
# [85]	validation_0-logloss:0.36333
# [86]	validation_0-logloss:0.36333
# [87]	validation_0-logloss:0.36333
# [88]	validation_0-logloss:0.36333
# [89]	validation_0-logloss:0.36333
# [90]	validation_0-logloss:0.36333
# [91]	validation_0-logloss:0.36333
# [92]	validation_0-logloss:0.36333
# [93]	validation_0-logloss:0.36333
# [94]	validation_0-logloss:0.36333
# [95]	validation_0-logloss:0.36333
# [96]	validation_0-logloss:0.36333
# [97]	validation_0-logloss:0.36333
# [98]	validation_0-logloss:0.36333
# [99]	validation_0-logloss:0.36333
# [100]	validation_0-logloss:0.36333
# [101]	validation_0-logloss:0.36333
# [102]	validation_0-logloss:0.36333
# [103]	validation_0-logloss:0.36333
# [104]	validation_0-logloss:0.36333
# [105]	validation_0-logloss:0.36333
# [106]	validation_0-logloss:0.36333
# [107]	validation_0-logloss:0.36333
# [108]	validation_0-logloss:0.36333
# [109]	validation_0-logloss:0.36333
# [110]	validation_0-logloss:0.36333
# [111]	validation_0-logloss:0.36333
# [112]	validation_0-logloss:0.36333
# [113]	validation_0-logloss:0.36333
# [114]	validation_0-logloss:0.36333
# [115]	validation_0-logloss:0.36333
# [116]	validation_0-logloss:0.36333
# [117]	validation_0-logloss:0.36333
# [118]	validation_0-logloss:0.36333
# [119]	validation_0-logloss:0.36333
# [120]	validation_0-logloss:0.36333
# [121]	validation_0-logloss:0.36333
# [122]	validation_0-logloss:0.36333
# [123]	validation_0-logloss:0.36333
# [124]	validation_0-logloss:0.36333
# [125]	validation_0-logloss:0.36333
# [126]	validation_0-logloss:0.36333
# [127]	validation_0-logloss:0.36333
# [128]	validation_0-logloss:0.36333
# [129]	validation_0-logloss:0.36333
# [130]	validation_0-logloss:0.36333
# [131]	validation_0-logloss:0.36333
# [132]	validation_0-logloss:0.36333
# [133]	validation_0-logloss:0.36333
# [134]	validation_0-logloss:0.36333
# [135]	validation_0-logloss:0.36333
# [136]	validation_0-logloss:0.36333
# [137]	validation_0-logloss:0.36333
# [138]	validation_0-logloss:0.36333
# [139]	validation_0-logloss:0.36333
# [140]	validation_0-logloss:0.36333
# [141]	validation_0-logloss:0.36333
# [142]	validation_0-logloss:0.36333
# [143]	validation_0-logloss:0.36333
# [144]	validation_0-logloss:0.36333
# [145]	validation_0-logloss:0.36333
# [146]	validation_0-logloss:0.36333
# [147]	validation_0-logloss:0.36333
# [148]	validation_0-logloss:0.36333
# [149]	validation_0-logloss:0.36333
# Best parameters found:  {'n_estimators': 150, 'max_depth': 5, 'learning_rate': 0.3}
# Testing accuracy after early stopping:  0.944481714810925
# /tmp/ipykernel_389/3592393373.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['eventID_mod'] = df['event_id'] % 5
# /tmp/ipykernel_389/3592393373.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weight'] = df['event_weight'] * df['pT_weight']
# train bkg: 489859, train signal: 16439, test bkg: 122617, test signal: 4203
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# /tmp/ipykernel_389/3592393373.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data.rename(columns=feature_mapping, inplace=True)
# /tmp/ipykernel_389/3592393373.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data.rename(columns=feature_mapping, inplace=True)
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.34094
# [1]	validation_0-logloss:0.33737
# [2]	validation_0-logloss:0.33386
# [3]	validation_0-logloss:0.33050
# [4]	validation_0-logloss:0.32719
# [5]	validation_0-logloss:0.32400
# [6]	validation_0-logloss:0.32092
# [7]	validation_0-logloss:0.31794
# [8]	validation_0-logloss:0.31499
# [9]	validation_0-logloss:0.31213
# [10]	validation_0-logloss:0.30934
# [11]	validation_0-logloss:0.30666
# [12]	validation_0-logloss:0.30613
# [13]	validation_0-logloss:0.30562
# [14]	validation_0-logloss:0.30513
# [15]	validation_0-logloss:0.30466
# [16]	validation_0-logloss:0.30420
# [17]	validation_0-logloss:0.30376
# [18]	validation_0-logloss:0.30333
# [19]	validation_0-logloss:0.30292
# [20]	validation_0-logloss:0.30253
# [21]	validation_0-logloss:0.30214
# [22]	validation_0-logloss:0.30177
# [23]	validation_0-logloss:0.30141
# [24]	validation_0-logloss:0.30107
# [25]	validation_0-logloss:0.30073
# [26]	validation_0-logloss:0.30041
# [27]	validation_0-logloss:0.30010
# [28]	validation_0-logloss:0.29980
# [29]	validation_0-logloss:0.29951
# [30]	validation_0-logloss:0.29923
# [31]	validation_0-logloss:0.29896
# [32]	validation_0-logloss:0.29869
# [33]	validation_0-logloss:0.29844
# [34]	validation_0-logloss:0.29820
# [35]	validation_0-logloss:0.29796
# [36]	validation_0-logloss:0.29773
# [37]	validation_0-logloss:0.29751
# [38]	validation_0-logloss:0.29730
# [39]	validation_0-logloss:0.29709
# [40]	validation_0-logloss:0.29689
# [41]	validation_0-logloss:0.29670
# [42]	validation_0-logloss:0.29651
# [43]	validation_0-logloss:0.29633
# [44]	validation_0-logloss:0.29616
# [45]	validation_0-logloss:0.29599
# [46]	validation_0-logloss:0.29583
# [47]	validation_0-logloss:0.29567
# [48]	validation_0-logloss:0.29552
# [49]	validation_0-logloss:0.29537
# [50]	validation_0-logloss:0.29523
# [51]	validation_0-logloss:0.29509
# [52]	validation_0-logloss:0.29496
# [53]	validation_0-logloss:0.29483
# [54]	validation_0-logloss:0.29471
# [55]	validation_0-logloss:0.29459
# [56]	validation_0-logloss:0.29447
# [57]	validation_0-logloss:0.29436
# [58]	validation_0-logloss:0.29425
# [59]	validation_0-logloss:0.29415
# [60]	validation_0-logloss:0.29405
# [61]	validation_0-logloss:0.29395
# [62]	validation_0-logloss:0.29385
# [63]	validation_0-logloss:0.29376
# [64]	validation_0-logloss:0.29367
# [65]	validation_0-logloss:0.29359
# [66]	validation_0-logloss:0.29351
# [67]	validation_0-logloss:0.29343
# [68]	validation_0-logloss:0.29335
# [69]	validation_0-logloss:0.29328
# [70]	validation_0-logloss:0.29320
# [71]	validation_0-logloss:0.29313
# [72]	validation_0-logloss:0.29307
# [73]	validation_0-logloss:0.29300
# [74]	validation_0-logloss:0.29294
# [75]	validation_0-logloss:0.29288
# [76]	validation_0-logloss:0.29282
# [77]	validation_0-logloss:0.29276
# [78]	validation_0-logloss:0.29271
# [79]	validation_0-logloss:0.29265
# [80]	validation_0-logloss:0.29260
# [81]	validation_0-logloss:0.29255
# [82]	validation_0-logloss:0.29250
# [83]	validation_0-logloss:0.29246
# [84]	validation_0-logloss:0.29241
# [85]	validation_0-logloss:0.29237
# [86]	validation_0-logloss:0.29233
# [87]	validation_0-logloss:0.29229
# [88]	validation_0-logloss:0.29225
# [89]	validation_0-logloss:0.29221
# [90]	validation_0-logloss:0.29217
# [91]	validation_0-logloss:0.29214
# [92]	validation_0-logloss:0.29210
# [93]	validation_0-logloss:0.29207
# [94]	validation_0-logloss:0.29204
# [95]	validation_0-logloss:0.29201
# [96]	validation_0-logloss:0.29198
# [97]	validation_0-logloss:0.29195
# [98]	validation_0-logloss:0.29192
# [99]	validation_0-logloss:0.29189
# [100]	validation_0-logloss:0.29186
# [101]	validation_0-logloss:0.29184
# [102]	validation_0-logloss:0.29181
# [103]	validation_0-logloss:0.29179
# [104]	validation_0-logloss:0.29177
# [105]	validation_0-logloss:0.29175
# [106]	validation_0-logloss:0.29172
# [107]	validation_0-logloss:0.29170
# [108]	validation_0-logloss:0.29168
# [109]	validation_0-logloss:0.29166
# [110]	validation_0-logloss:0.29164
# [111]	validation_0-logloss:0.29163
# [112]	validation_0-logloss:0.29161
# [113]	validation_0-logloss:0.29159
# [114]	validation_0-logloss:0.29158
# [115]	validation_0-logloss:0.29156
# [116]	validation_0-logloss:0.29154
# [117]	validation_0-logloss:0.29153
# [118]	validation_0-logloss:0.29152
# [119]	validation_0-logloss:0.29150
# [120]	validation_0-logloss:0.29149
# [121]	validation_0-logloss:0.29147
# [122]	validation_0-logloss:0.29146
# [123]	validation_0-logloss:0.29145
# [124]	validation_0-logloss:0.29144
# [125]	validation_0-logloss:0.29143
# [126]	validation_0-logloss:0.29142
# [127]	validation_0-logloss:0.29141
# [128]	validation_0-logloss:0.29140
# [129]	validation_0-logloss:0.29139
# [130]	validation_0-logloss:0.29138
# [131]	validation_0-logloss:0.29137
# [132]	validation_0-logloss:0.29136
# [133]	validation_0-logloss:0.29135
# [134]	validation_0-logloss:0.29134
# [135]	validation_0-logloss:0.29133
# [136]	validation_0-logloss:0.29132
# [137]	validation_0-logloss:0.29132
# [138]	validation_0-logloss:0.29131
# [139]	validation_0-logloss:0.29130
# [140]	validation_0-logloss:0.29130
# [141]	validation_0-logloss:0.29129
# [142]	validation_0-logloss:0.29128
# [143]	validation_0-logloss:0.29128
# [144]	validation_0-logloss:0.29127
# [145]	validation_0-logloss:0.29126
# [146]	validation_0-logloss:0.29126
# [147]	validation_0-logloss:0.29125
# [148]	validation_0-logloss:0.29125
# [149]	validation_0-logloss:0.29124
# Best parameters found:  {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.05}
# Testing accuracy after early stopping:  0.7456670878335062
# /tmp/ipykernel_389/3592393373.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['eventID_mod'] = df['event_id'] % 5
# /tmp/ipykernel_389/3592393373.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weight'] = df['event_weight'] * df['pT_weight']
# train bkg: 960356, train signal: 91631, test bkg: 240022, test signal: 22940
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# /tmp/ipykernel_389/3592393373.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data.rename(columns=feature_mapping, inplace=True)
# /tmp/ipykernel_389/3592393373.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data.rename(columns=feature_mapping, inplace=True)
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.51691
# [1]	validation_0-logloss:0.47957
# [2]	validation_0-logloss:0.43974
# [3]	validation_0-logloss:0.41005
# [4]	validation_0-logloss:0.38684
# [5]	validation_0-logloss:0.35860
# [6]	validation_0-logloss:0.33463
# [7]	validation_0-logloss:0.31538
# [8]	validation_0-logloss:0.30042
# [9]	validation_0-logloss:0.28601
# [10]	validation_0-logloss:0.27079
# [11]	validation_0-logloss:0.26004
# [12]	validation_0-logloss:0.25130
# [13]	validation_0-logloss:0.24060
# [14]	validation_0-logloss:0.23119
# [15]	validation_0-logloss:0.22613
# [16]	validation_0-logloss:0.22112
# [17]	validation_0-logloss:0.21433
# [18]	validation_0-logloss:0.20825
# [19]	validation_0-logloss:0.20226
# [20]	validation_0-logloss:0.19573
# [21]	validation_0-logloss:0.19132
# [22]	validation_0-logloss:0.18568
# [23]	validation_0-logloss:0.18371
# [24]	validation_0-logloss:0.18014
# [25]	validation_0-logloss:0.18040
# [26]	validation_0-logloss:0.17798
# [27]	validation_0-logloss:0.17485
# [28]	validation_0-logloss:0.17286
# [29]	validation_0-logloss:0.16990
# [30]	validation_0-logloss:0.16842
# [31]	validation_0-logloss:0.16585
# [32]	validation_0-logloss:0.16342
# [33]	validation_0-logloss:0.16177
# [34]	validation_0-logloss:0.15944
# [35]	validation_0-logloss:0.15988
# [36]	validation_0-logloss:0.15782
# [37]	validation_0-logloss:0.15662
# [38]	validation_0-logloss:0.15465
# [39]	validation_0-logloss:0.15251
# [40]	validation_0-logloss:0.15162
# [41]	validation_0-logloss:0.14994
# [42]	validation_0-logloss:0.14907
# [43]	validation_0-logloss:0.14751
# [44]	validation_0-logloss:0.14605
# [45]	validation_0-logloss:0.14468
# [46]	validation_0-logloss:0.14408
# [47]	validation_0-logloss:0.14296
# [48]	validation_0-logloss:0.14203
# [49]	validation_0-logloss:0.14149
# [50]	validation_0-logloss:0.14025
# [51]	validation_0-logloss:0.13928
# [52]	validation_0-logloss:0.13845
# [53]	validation_0-logloss:0.13697
# [54]	validation_0-logloss:0.13592
# [55]	validation_0-logloss:0.13589
# [56]	validation_0-logloss:0.13581
# [57]	validation_0-logloss:0.13573
# [58]	validation_0-logloss:0.13566
# [59]	validation_0-logloss:0.13559
# [60]	validation_0-logloss:0.13554
# [61]	validation_0-logloss:0.13549
# [62]	validation_0-logloss:0.13544
# [63]	validation_0-logloss:0.13540
# [64]	validation_0-logloss:0.13536
# [65]	validation_0-logloss:0.13533
# [66]	validation_0-logloss:0.13530
# [67]	validation_0-logloss:0.13527
# [68]	validation_0-logloss:0.13525
# [69]	validation_0-logloss:0.13522
# [70]	validation_0-logloss:0.13520
# [71]	validation_0-logloss:0.13519
# [72]	validation_0-logloss:0.13517
# [73]	validation_0-logloss:0.13516
# [74]	validation_0-logloss:0.13514
# [75]	validation_0-logloss:0.13513
# [76]	validation_0-logloss:0.13512
# [77]	validation_0-logloss:0.13511
# [78]	validation_0-logloss:0.13510
# [79]	validation_0-logloss:0.13509
# [80]	validation_0-logloss:0.13509
# [81]	validation_0-logloss:0.13508
# [82]	validation_0-logloss:0.13508
# [83]	validation_0-logloss:0.13507
# [84]	validation_0-logloss:0.13507
# [85]	validation_0-logloss:0.13506
# [86]	validation_0-logloss:0.13506
# [87]	validation_0-logloss:0.13506
# [88]	validation_0-logloss:0.13505
# [89]	validation_0-logloss:0.13505
# [90]	validation_0-logloss:0.13505
# [91]	validation_0-logloss:0.13505
# [92]	validation_0-logloss:0.13504
# [93]	validation_0-logloss:0.13504
# [94]	validation_0-logloss:0.13504
# [95]	validation_0-logloss:0.13504
# [96]	validation_0-logloss:0.13504
# [97]	validation_0-logloss:0.13504
# [98]	validation_0-logloss:0.13503
# [99]	validation_0-logloss:0.13503
# Best parameters found:  {'n_estimators': 100, 'max_depth': 2, 'learning_rate': 0.15}
# Testing accuracy after early stopping:  0.9602260801183089
# train bkg: 1743956, train signal: 234487, test bkg: 436601, test signal: 58669
# /tmp/ipykernel_389/3592393373.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data.rename(columns=feature_mapping, inplace=True)
# /tmp/ipykernel_389/3592393373.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data.rename(columns=feature_mapping, inplace=True)
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.68221
# [1]	validation_0-logloss:0.65180
# [2]	validation_0-logloss:0.62410
# [3]	validation_0-logloss:0.59885
# [4]	validation_0-logloss:0.57477
# [5]	validation_0-logloss:0.55266
# [6]	validation_0-logloss:0.53197
# [7]	validation_0-logloss:0.51272
# [8]	validation_0-logloss:0.49457
# [9]	validation_0-logloss:0.47757
# [10]	validation_0-logloss:0.46144
# [11]	validation_0-logloss:0.44656
# [12]	validation_0-logloss:0.43249
# [13]	validation_0-logloss:0.42027
# [14]	validation_0-logloss:0.40772
# [15]	validation_0-logloss:0.39640
# [16]	validation_0-logloss:0.38612
# [17]	validation_0-logloss:0.37531
# [18]	validation_0-logloss:0.36660
# [19]	validation_0-logloss:0.35741
# [20]	validation_0-logloss:0.34796
# [21]	validation_0-logloss:0.34032
# [22]	validation_0-logloss:0.33245
# [23]	validation_0-logloss:0.32552
# [24]	validation_0-logloss:0.31836
# [25]	validation_0-logloss:0.31079
# [26]	validation_0-logloss:0.30489
# [27]	validation_0-logloss:0.29869
# [28]	validation_0-logloss:0.29210
# [29]	validation_0-logloss:0.28734
# [30]	validation_0-logloss:0.28173
# [31]	validation_0-logloss:0.27587
# [32]	validation_0-logloss:0.27048
# [33]	validation_0-logloss:0.26622
# [34]	validation_0-logloss:0.26175
# [35]	validation_0-logloss:0.25768
# [36]	validation_0-logloss:0.25298
# [37]	validation_0-logloss:0.24885
# [38]	validation_0-logloss:0.24483
# [39]	validation_0-logloss:0.24130
# [40]	validation_0-logloss:0.23812
# [41]	validation_0-logloss:0.23391
# [42]	validation_0-logloss:0.23054
# [43]	validation_0-logloss:0.22760
# [44]	validation_0-logloss:0.22499
# [45]	validation_0-logloss:0.22240
# [46]	validation_0-logloss:0.21901
# [47]	validation_0-logloss:0.21607
# [48]	validation_0-logloss:0.21402
# [49]	validation_0-logloss:0.21099
# [50]	validation_0-logloss:0.20804
# [51]	validation_0-logloss:0.20547
# [52]	validation_0-logloss:0.20363
# [53]	validation_0-logloss:0.20151
# [54]	validation_0-logloss:0.19986
# [55]	validation_0-logloss:0.19770
# [56]	validation_0-logloss:0.19547
# [57]	validation_0-logloss:0.19335
# [58]	validation_0-logloss:0.19181
# [59]	validation_0-logloss:0.18983
# [60]	validation_0-logloss:0.18798
# [61]	validation_0-logloss:0.18676
# [62]	validation_0-logloss:0.18485
# [63]	validation_0-logloss:0.18325
# [64]	validation_0-logloss:0.18182
# [65]	validation_0-logloss:0.18055
# [66]	validation_0-logloss:0.17878
# [67]	validation_0-logloss:0.17770
# [68]	validation_0-logloss:0.17588
# [69]	validation_0-logloss:0.17437
# [70]	validation_0-logloss:0.17295
# [71]	validation_0-logloss:0.17179
# [72]	validation_0-logloss:0.17107
# [73]	validation_0-logloss:0.16988
# [74]	validation_0-logloss:0.16869
# [75]	validation_0-logloss:0.16719
# [76]	validation_0-logloss:0.16612
# [77]	validation_0-logloss:0.16464
# [78]	validation_0-logloss:0.16351
# [79]	validation_0-logloss:0.16288
# [80]	validation_0-logloss:0.16178
# [81]	validation_0-logloss:0.16070
# [82]	validation_0-logloss:0.15984
# [83]	validation_0-logloss:0.15901
# [84]	validation_0-logloss:0.15840
# [85]	validation_0-logloss:0.15749
# [86]	validation_0-logloss:0.15651
# [87]	validation_0-logloss:0.15558
# [88]	validation_0-logloss:0.15439
# [89]	validation_0-logloss:0.15369
# [90]	validation_0-logloss:0.15287
# [91]	validation_0-logloss:0.15206
# [92]	validation_0-logloss:0.15103
# [93]	validation_0-logloss:0.15037
# [94]	validation_0-logloss:0.14960
# [95]	validation_0-logloss:0.14884
# [96]	validation_0-logloss:0.14812
# [97]	validation_0-logloss:0.14753
# [98]	validation_0-logloss:0.14652
# [99]	validation_0-logloss:0.14618
# [100]	validation_0-logloss:0.14549
# [101]	validation_0-logloss:0.14448
# [102]	validation_0-logloss:0.14426
# [103]	validation_0-logloss:0.14361
# [104]	validation_0-logloss:0.14307
# [105]	validation_0-logloss:0.14249
# [106]	validation_0-logloss:0.14176
# [107]	validation_0-logloss:0.14071
# [108]	validation_0-logloss:0.14045
# [109]	validation_0-logloss:0.14029
# [110]	validation_0-logloss:0.13962
# [111]	validation_0-logloss:0.13902
# [112]	validation_0-logloss:0.13815
# [113]	validation_0-logloss:0.13792
# [114]	validation_0-logloss:0.13744
# [115]	validation_0-logloss:0.13732
# [116]	validation_0-logloss:0.13640
# [117]	validation_0-logloss:0.13580
# [118]	validation_0-logloss:0.13536
# [119]	validation_0-logloss:0.13490
# [120]	validation_0-logloss:0.13481
# [121]	validation_0-logloss:0.13425
# [122]	validation_0-logloss:0.13384
# [123]	validation_0-logloss:0.13310
# [124]	validation_0-logloss:0.13299
# [125]	validation_0-logloss:0.13252
# [126]	validation_0-logloss:0.13171
# [127]	validation_0-logloss:0.13163
# [128]	validation_0-logloss:0.13119
# [129]	validation_0-logloss:0.13075
# [130]	validation_0-logloss:0.13029
# [131]	validation_0-logloss:0.13002
# [132]	validation_0-logloss:0.12961
# [133]	validation_0-logloss:0.12893
# [134]	validation_0-logloss:0.12822
# [135]	validation_0-logloss:0.12772
# [136]	validation_0-logloss:0.12752
# [137]	validation_0-logloss:0.12732
# [138]	validation_0-logloss:0.12695
# [139]	validation_0-logloss:0.12679
# [140]	validation_0-logloss:0.12656
# [141]	validation_0-logloss:0.12621
# [142]	validation_0-logloss:0.12562
# [143]	validation_0-logloss:0.12551
# [144]	validation_0-logloss:0.12535
# [145]	validation_0-logloss:0.12508
# [146]	validation_0-logloss:0.12473
# [147]	validation_0-logloss:0.12436
# [148]	validation_0-logloss:0.12401
# [149]	validation_0-logloss:0.12371
# [150]	validation_0-logloss:0.12355
# [151]	validation_0-logloss:0.12329
# [152]	validation_0-logloss:0.12279
# [153]	validation_0-logloss:0.12248
# [154]	validation_0-logloss:0.12229
# [155]	validation_0-logloss:0.12200
# [156]	validation_0-logloss:0.12177
# [157]	validation_0-logloss:0.12163
# [158]	validation_0-logloss:0.12134
# [159]	validation_0-logloss:0.12107
# [160]	validation_0-logloss:0.12071
# [161]	validation_0-logloss:0.12054
# [162]	validation_0-logloss:0.12012
# [163]	validation_0-logloss:0.12005
# [164]	validation_0-logloss:0.11977
# [165]	validation_0-logloss:0.11950
# [166]	validation_0-logloss:0.11939
# [167]	validation_0-logloss:0.11920
# [168]	validation_0-logloss:0.11893
# [169]	validation_0-logloss:0.11875
# [170]	validation_0-logloss:0.11847
# [171]	validation_0-logloss:0.11820
# [172]	validation_0-logloss:0.11796
# [173]	validation_0-logloss:0.11769
# [174]	validation_0-logloss:0.11764
# [175]	validation_0-logloss:0.11733
# [176]	validation_0-logloss:0.11703
# [177]	validation_0-logloss:0.11680
# [178]	validation_0-logloss:0.11671
# [179]	validation_0-logloss:0.11658
# [180]	validation_0-logloss:0.11641
# [181]	validation_0-logloss:0.11634
# [182]	validation_0-logloss:0.11602
# [183]	validation_0-logloss:0.11576
# [184]	validation_0-logloss:0.11565
# [185]	validation_0-logloss:0.11559
# [186]	validation_0-logloss:0.11552
# [187]	validation_0-logloss:0.11540
# [188]	validation_0-logloss:0.11526
# [189]	validation_0-logloss:0.11497
# [190]	validation_0-logloss:0.11489
# [191]	validation_0-logloss:0.11478
# [192]	validation_0-logloss:0.11453
# [193]	validation_0-logloss:0.11466
# [194]	validation_0-logloss:0.11437
# [195]	validation_0-logloss:0.11427
# [196]	validation_0-logloss:0.11416
# [197]	validation_0-logloss:0.11413
# [198]	validation_0-logloss:0.11385
# [199]	validation_0-logloss:0.11366
# [200]	validation_0-logloss:0.11360
# [201]	validation_0-logloss:0.11339
# [202]	validation_0-logloss:0.11351
# [203]	validation_0-logloss:0.11341
# [204]	validation_0-logloss:0.11334
# [205]	validation_0-logloss:0.11307
# [206]	validation_0-logloss:0.11297
# [207]	validation_0-logloss:0.11295
# [208]	validation_0-logloss:0.11289
# [209]	validation_0-logloss:0.11267
# [210]	validation_0-logloss:0.11279
# [211]	validation_0-logloss:0.11262
# [212]	validation_0-logloss:0.11245
# [213]	validation_0-logloss:0.11220
# [214]	validation_0-logloss:0.11214
# [215]	validation_0-logloss:0.11207
# [216]	validation_0-logloss:0.11198
# [217]	validation_0-logloss:0.11180
# [218]	validation_0-logloss:0.11191
# [219]	validation_0-logloss:0.11186
# [220]	validation_0-logloss:0.11162
# [221]	validation_0-logloss:0.11155
# [222]	validation_0-logloss:0.11152
# [223]	validation_0-logloss:0.11132
# [224]	validation_0-logloss:0.11117
# [225]	validation_0-logloss:0.11102
# [226]	validation_0-logloss:0.11094
# [227]	validation_0-logloss:0.11072
# [228]	validation_0-logloss:0.11067
# [229]	validation_0-logloss:0.11063
# [230]	validation_0-logloss:0.11062
# [231]	validation_0-logloss:0.11054
# [232]	validation_0-logloss:0.11038
# [233]	validation_0-logloss:0.11048
# [234]	validation_0-logloss:0.11026
# [235]	validation_0-logloss:0.11030
# [236]	validation_0-logloss:0.11018
# [237]	validation_0-logloss:0.11011
# [238]	validation_0-logloss:0.11002
# [239]	validation_0-logloss:0.10998
# [240]	validation_0-logloss:0.10984
# [241]	validation_0-logloss:0.10981
# [242]	validation_0-logloss:0.10968
# [243]	validation_0-logloss:0.10954
# [244]	validation_0-logloss:0.10950
# [245]	validation_0-logloss:0.10933
# [246]	validation_0-logloss:0.10932
# [247]	validation_0-logloss:0.10911
# [248]	validation_0-logloss:0.10910
# [249]	validation_0-logloss:0.10903
# [250]	validation_0-logloss:0.10897
# [251]	validation_0-logloss:0.10895
# [252]	validation_0-logloss:0.10899
# [253]	validation_0-logloss:0.10879
# [254]	validation_0-logloss:0.10875
# [255]	validation_0-logloss:0.10862
# [256]	validation_0-logloss:0.10856
# [257]	validation_0-logloss:0.10865
# [258]	validation_0-logloss:0.10849
# [259]	validation_0-logloss:0.10830
# [260]	validation_0-logloss:0.10828
# [261]	validation_0-logloss:0.10824
# [262]	validation_0-logloss:0.10823
# [263]	validation_0-logloss:0.10817
# [264]	validation_0-logloss:0.10805
# [265]	validation_0-logloss:0.10793
# [266]	validation_0-logloss:0.10782
# [267]	validation_0-logloss:0.10776
# [268]	validation_0-logloss:0.10775
# [269]	validation_0-logloss:0.10757
# [270]	validation_0-logloss:0.10754
# [271]	validation_0-logloss:0.10752
# [272]	validation_0-logloss:0.10747
# [273]	validation_0-logloss:0.10755
# [274]	validation_0-logloss:0.10744
# [275]	validation_0-logloss:0.10730
# [276]	validation_0-logloss:0.10733
# [277]	validation_0-logloss:0.10731
# [278]	validation_0-logloss:0.10720
# [279]	validation_0-logloss:0.10703
# [280]	validation_0-logloss:0.10698
# [281]	validation_0-logloss:0.10696
# [282]	validation_0-logloss:0.10685
# [283]	validation_0-logloss:0.10693
# [284]	validation_0-logloss:0.10690
# [285]	validation_0-logloss:0.10685
# [286]	validation_0-logloss:0.10668
# [287]	validation_0-logloss:0.10667
# [288]	validation_0-logloss:0.10661
# [289]	validation_0-logloss:0.10660
# [290]	validation_0-logloss:0.10647
# [291]	validation_0-logloss:0.10650
# [292]	validation_0-logloss:0.10640
# [293]	validation_0-logloss:0.10636
# [294]	validation_0-logloss:0.10631
# [295]	validation_0-logloss:0.10615
# [296]	validation_0-logloss:0.10622
# [297]	validation_0-logloss:0.10602
# [298]	validation_0-logloss:0.10601
# [299]	validation_0-logloss:0.10591
# [300]	validation_0-logloss:0.10589
# [301]	validation_0-logloss:0.10587
# [302]	validation_0-logloss:0.10576
# [303]	validation_0-logloss:0.10575
# [304]	validation_0-logloss:0.10570
# [305]	validation_0-logloss:0.10566
# [306]	validation_0-logloss:0.10550
# [307]	validation_0-logloss:0.10550
# [308]	validation_0-logloss:0.10549
# [309]	validation_0-logloss:0.10530
# [310]	validation_0-logloss:0.10528
# [311]	validation_0-logloss:0.10534
# [312]	validation_0-logloss:0.10525
# [313]	validation_0-logloss:0.10521
# [314]	validation_0-logloss:0.10519
# [315]	validation_0-logloss:0.10505
# [316]	validation_0-logloss:0.10495
# [317]	validation_0-logloss:0.10494
# [318]	validation_0-logloss:0.10489
# [319]	validation_0-logloss:0.10488
# [320]	validation_0-logloss:0.10487
# [321]	validation_0-logloss:0.10468
# [322]	validation_0-logloss:0.10464
# [323]	validation_0-logloss:0.10471
# [324]	validation_0-logloss:0.10463
# [325]	validation_0-logloss:0.10455
# [326]	validation_0-logloss:0.10444
# [327]	validation_0-logloss:0.10431
# [328]	validation_0-logloss:0.10430
# [329]	validation_0-logloss:0.10429
# [330]	validation_0-logloss:0.10411
# [331]	validation_0-logloss:0.10411
# [332]	validation_0-logloss:0.10407
# [333]	validation_0-logloss:0.10403
# [334]	validation_0-logloss:0.10402
# [335]	validation_0-logloss:0.10401
# [336]	validation_0-logloss:0.10393
# [337]	validation_0-logloss:0.10393
# [338]	validation_0-logloss:0.10380
# [339]	validation_0-logloss:0.10376
# [340]	validation_0-logloss:0.10375
# [341]	validation_0-logloss:0.10359
# [342]	validation_0-logloss:0.10365
# [343]	validation_0-logloss:0.10357
# [344]	validation_0-logloss:0.10353
# [345]	validation_0-logloss:0.10355
# [346]	validation_0-logloss:0.10350
# [347]	validation_0-logloss:0.10341
# [348]	validation_0-logloss:0.10328
# [349]	validation_0-logloss:0.10328
# Best parameters found:  {'n_estimators': 350, 'max_depth': 3, 'learning_rate': 0.05}
# Testing accuracy after early stopping:  0.9641455561415034

# %%
# Plotting ROC Curve
plt.figure(figsize=(22, 10))
plt.subplot(121)
plt.plot(fpr1, tpr1, lw=2, label='1p1p (area = %0.5f)' % auc1)
plt.plot(fpr2, tpr2, lw=2, label='3p3p (area = %0.5f)' % auc2)
plt.plot(fpr3, tpr3, lw=2, label='1p3p (area = %0.5f)' % auc3)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(True)

plt.subplot(122)
plt.plot(tpr1, 1/fpr1, lw=1, label='1p1p (area = %0.5f)' % auc1)
plt.plot(tpr2, 1/fpr2, lw=1, label='3p3p (area = %0.5f)' % auc2)
plt.plot(tpr3, 1/fpr3, lw=1, label='1p3p (area = %0.5f)' % auc3)

plt.xlabel('Signal efficiency (TPR)')
plt.ylabel('Inverse background efficiency (1/FPR)')
plt.yscale('log')
# yticks = np.linspace(0, 10e9, 71)
# plt.yticks(yticks, labels=[str(ytick) for ytick in yticks])
plt.axhline(y=1e4, color='r', linestyle='--', label='y=1e4')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.show()
# Out:
# /tmp/ipykernel_389/1803732940.py:15: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr1, 1/fpr1, lw=1, label='1p1p (area = %0.5f)' % auc1)
# /tmp/ipykernel_389/1803732940.py:16: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr2, 1/fpr2, lw=1, label='3p3p (area = %0.5f)' % auc2)
# /tmp/ipykernel_389/1803732940.py:17: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr3, 1/fpr3, lw=1, label='1p3p (area = %0.5f)' % auc3)

# %%
training_vars = ["f_core_lead",
                "f_core_subl",
                "f_subjet_subl",
                "f_subjets",
                "f_isotracks",
                "R_max_lead",
                "R_max_subl",
                "R_isotrack",
                "R_tracks_subl",
                "m_core_lead",
                "m_core_subl",
                "m_tracks_lead",
                "m_tracks_subl",
                "d0_leadtrack_lead",
                "d0_leadtrack_subl",
                "n_track",
                "n_tracks_lead"]


# Scrambling
# Calculate the modulo of each eventID with 5
df['eventID_mod'] = df['event_id'] % 5

df['weight'] = df['event_weight'] * df['pT_weight']

log_vars = ["f_isotracks", "m_core_lead", "m_core_subl", "m_tracks_lead", "m_tracks_subl"]
abs_log_var = ["d0_leadtrack_lead", "d0_leadtrack_subl"]

train_df = df[df['eventID_mod'] < 4] # 80%
test_df = df[df['eventID_mod'] == 4] # 20%
print(f'train bkg: {len(train_df[train_df.label==0])}, train signal: {len(train_df[train_df.label==1])}, test bkg: {len(test_df[test_df.label==0])}, test signal: {len(test_df[test_df.label==1])}')

train_df = train_df.drop(columns='eventID_mod')
test_df = test_df.drop(columns='eventID_mod')

# Training & Testing sets
training_data, testing_data, training_labels, testing_labels, training_weights, testing_weights = \
train_df[training_vars], test_df[training_vars], train_df['label'], test_df['label'], train_df['weight'], test_df['weight']

#Change column names to integers if needed (for ML models that expect numerical feature names)
feature_mapping = {feature: i for i, feature in enumerate(training_data.columns)}
training_data.rename(columns=feature_mapping, inplace=True)
feature_mapping = {feature: i for i, feature in enumerate(testing_data.columns)}
testing_data.rename(columns=feature_mapping, inplace=True)

# Define the classifier
bdt = XGBClassifier(random_state=0, verbosity=1)

# Define the parameter distribution
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300, 350, 400, 450, 500],
    'learning_rate': [0.01, 0.05, 0.1, 0.15, 0.2, 0.3],
    'max_depth': [2, 3, 4, 5, 6]
}

# Define the search with RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=bdt, param_distributions=param_dist, n_iter=30, scoring='accuracy', cv=3, verbose=2, random_state=0, n_jobs=-1)

# Perform the search
# Note: We don't use the testing set here; it's for final evaluation
random_search.fit(training_data, training_labels, sample_weight=training_weights)

# Best estimator found by RandomizedSearchCV
best_estimator = random_search.best_estimator_

# Manually apply early stopping using a portion of the training set as a validation set
# Note: XGBoost handles validation sets for early stopping, but we use training and testing sets as provided
eval_set = [(testing_data, testing_labels)]
best_estimator.fit(training_data, training_labels, sample_weight=training_weights, early_stopping_rounds=10, eval_metric="logloss", eval_set=eval_set, verbose=True)

# Predictions and final evaluation on the testing set
predictions = best_estimator.predict(testing_data)
accuracy = accuracy_score(testing_labels, predictions, sample_weight=testing_weights)

# Output the results
print("Best parameters found: ", random_search.best_params_)
print("Testing accuracy after early stopping: ", accuracy)

# Predict probabilities for the testing data
probs = best_estimator.predict_proba(testing_data)
probs = probs[:, 1]

# Feature Importance
importance = best_estimator.feature_importances_
# Re-map the feature importance scores to the original feature names
feature_importances = {training_vars[i]: score for i, score in enumerate(importance)}

# Plot feature importance
plt.figure(figsize=(10, 8))
plt.barh(range(len(feature_importances)), list(feature_importances.values()), align='center')
plt.yticks(range(len(feature_importances)), list(feature_importances.keys()))
plt.xlabel('Feature Importance Score')
plt.title('Feature Importances')
plt.show()
# Out:
# train bkg: 1743956, train signal: 234487, test bkg: 436601, test signal: 58669
# /tmp/ipykernel_389/4124954595.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data.rename(columns=feature_mapping, inplace=True)
# /tmp/ipykernel_389/4124954595.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data.rename(columns=feature_mapping, inplace=True)
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.68221
# [1]	validation_0-logloss:0.65180
# [2]	validation_0-logloss:0.62410
# [3]	validation_0-logloss:0.59885
# [4]	validation_0-logloss:0.57477
# [5]	validation_0-logloss:0.55266
# [6]	validation_0-logloss:0.53197
# [7]	validation_0-logloss:0.51272
# [8]	validation_0-logloss:0.49457
# [9]	validation_0-logloss:0.47757
# [10]	validation_0-logloss:0.46144
# [11]	validation_0-logloss:0.44656
# [12]	validation_0-logloss:0.43249
# [13]	validation_0-logloss:0.42027
# [14]	validation_0-logloss:0.40772
# [15]	validation_0-logloss:0.39640
# [16]	validation_0-logloss:0.38612
# [17]	validation_0-logloss:0.37531
# [18]	validation_0-logloss:0.36660
# [19]	validation_0-logloss:0.35741
# [20]	validation_0-logloss:0.34796
# [21]	validation_0-logloss:0.34032
# [22]	validation_0-logloss:0.33245
# [23]	validation_0-logloss:0.32552
# [24]	validation_0-logloss:0.31836
# [25]	validation_0-logloss:0.31079
# [26]	validation_0-logloss:0.30489
# [27]	validation_0-logloss:0.29869
# [28]	validation_0-logloss:0.29210
# [29]	validation_0-logloss:0.28734
# [30]	validation_0-logloss:0.28173
# [31]	validation_0-logloss:0.27587
# [32]	validation_0-logloss:0.27048
# [33]	validation_0-logloss:0.26622
# [34]	validation_0-logloss:0.26175
# [35]	validation_0-logloss:0.25768
# [36]	validation_0-logloss:0.25298
# [37]	validation_0-logloss:0.24885
# [38]	validation_0-logloss:0.24483
# [39]	validation_0-logloss:0.24130
# [40]	validation_0-logloss:0.23812
# [41]	validation_0-logloss:0.23391
# [42]	validation_0-logloss:0.23054
# [43]	validation_0-logloss:0.22760
# [44]	validation_0-logloss:0.22499
# [45]	validation_0-logloss:0.22240
# [46]	validation_0-logloss:0.21901
# [47]	validation_0-logloss:0.21607
# [48]	validation_0-logloss:0.21402
# [49]	validation_0-logloss:0.21099
# [50]	validation_0-logloss:0.20804
# [51]	validation_0-logloss:0.20547
# [52]	validation_0-logloss:0.20363
# [53]	validation_0-logloss:0.20151
# [54]	validation_0-logloss:0.19986
# [55]	validation_0-logloss:0.19770
# [56]	validation_0-logloss:0.19547
# [57]	validation_0-logloss:0.19335
# [58]	validation_0-logloss:0.19181
# [59]	validation_0-logloss:0.18983
# [60]	validation_0-logloss:0.18798
# [61]	validation_0-logloss:0.18676
# [62]	validation_0-logloss:0.18485
# [63]	validation_0-logloss:0.18325
# [64]	validation_0-logloss:0.18182
# [65]	validation_0-logloss:0.18055
# [66]	validation_0-logloss:0.17878
# [67]	validation_0-logloss:0.17770
# [68]	validation_0-logloss:0.17588
# [69]	validation_0-logloss:0.17437
# [70]	validation_0-logloss:0.17295
# [71]	validation_0-logloss:0.17179
# [72]	validation_0-logloss:0.17107
# [73]	validation_0-logloss:0.16988
# [74]	validation_0-logloss:0.16869
# [75]	validation_0-logloss:0.16719
# [76]	validation_0-logloss:0.16612
# [77]	validation_0-logloss:0.16464
# [78]	validation_0-logloss:0.16351
# [79]	validation_0-logloss:0.16288
# [80]	validation_0-logloss:0.16178
# [81]	validation_0-logloss:0.16070
# [82]	validation_0-logloss:0.15984
# [83]	validation_0-logloss:0.15901
# [84]	validation_0-logloss:0.15840
# [85]	validation_0-logloss:0.15749
# [86]	validation_0-logloss:0.15651
# [87]	validation_0-logloss:0.15558
# [88]	validation_0-logloss:0.15439
# [89]	validation_0-logloss:0.15369
# [90]	validation_0-logloss:0.15287
# [91]	validation_0-logloss:0.15206
# [92]	validation_0-logloss:0.15103
# [93]	validation_0-logloss:0.15037
# [94]	validation_0-logloss:0.14960
# [95]	validation_0-logloss:0.14884
# [96]	validation_0-logloss:0.14812
# [97]	validation_0-logloss:0.14753
# [98]	validation_0-logloss:0.14652
# [99]	validation_0-logloss:0.14618
# [100]	validation_0-logloss:0.14549
# [101]	validation_0-logloss:0.14448
# [102]	validation_0-logloss:0.14426
# [103]	validation_0-logloss:0.14361
# [104]	validation_0-logloss:0.14307
# [105]	validation_0-logloss:0.14249
# [106]	validation_0-logloss:0.14176
# [107]	validation_0-logloss:0.14071
# [108]	validation_0-logloss:0.14045
# [109]	validation_0-logloss:0.14029
# [110]	validation_0-logloss:0.13962
# [111]	validation_0-logloss:0.13902
# [112]	validation_0-logloss:0.13815
# [113]	validation_0-logloss:0.13792
# [114]	validation_0-logloss:0.13744
# [115]	validation_0-logloss:0.13732
# [116]	validation_0-logloss:0.13640
# [117]	validation_0-logloss:0.13580
# [118]	validation_0-logloss:0.13536
# [119]	validation_0-logloss:0.13490
# [120]	validation_0-logloss:0.13481
# [121]	validation_0-logloss:0.13425
# [122]	validation_0-logloss:0.13384
# [123]	validation_0-logloss:0.13310
# [124]	validation_0-logloss:0.13299
# [125]	validation_0-logloss:0.13252
# [126]	validation_0-logloss:0.13171
# [127]	validation_0-logloss:0.13163
# [128]	validation_0-logloss:0.13119
# [129]	validation_0-logloss:0.13075
# [130]	validation_0-logloss:0.13029
# [131]	validation_0-logloss:0.13002
# [132]	validation_0-logloss:0.12961
# [133]	validation_0-logloss:0.12893
# [134]	validation_0-logloss:0.12822
# [135]	validation_0-logloss:0.12772
# [136]	validation_0-logloss:0.12752
# [137]	validation_0-logloss:0.12732
# [138]	validation_0-logloss:0.12695
# [139]	validation_0-logloss:0.12679
# [140]	validation_0-logloss:0.12656
# [141]	validation_0-logloss:0.12621
# [142]	validation_0-logloss:0.12562
# [143]	validation_0-logloss:0.12551
# [144]	validation_0-logloss:0.12535
# [145]	validation_0-logloss:0.12508
# [146]	validation_0-logloss:0.12473
# [147]	validation_0-logloss:0.12436
# [148]	validation_0-logloss:0.12401
# [149]	validation_0-logloss:0.12371
# [150]	validation_0-logloss:0.12355
# [151]	validation_0-logloss:0.12329
# [152]	validation_0-logloss:0.12279
# [153]	validation_0-logloss:0.12248
# [154]	validation_0-logloss:0.12229
# [155]	validation_0-logloss:0.12200
# [156]	validation_0-logloss:0.12177
# [157]	validation_0-logloss:0.12163
# [158]	validation_0-logloss:0.12134
# [159]	validation_0-logloss:0.12107
# [160]	validation_0-logloss:0.12071
# [161]	validation_0-logloss:0.12054
# [162]	validation_0-logloss:0.12012
# [163]	validation_0-logloss:0.12005
# [164]	validation_0-logloss:0.11977
# [165]	validation_0-logloss:0.11950
# [166]	validation_0-logloss:0.11939
# [167]	validation_0-logloss:0.11920
# [168]	validation_0-logloss:0.11893
# [169]	validation_0-logloss:0.11875
# [170]	validation_0-logloss:0.11847
# [171]	validation_0-logloss:0.11820
# [172]	validation_0-logloss:0.11796
# [173]	validation_0-logloss:0.11769
# [174]	validation_0-logloss:0.11764
# [175]	validation_0-logloss:0.11733
# [176]	validation_0-logloss:0.11703
# [177]	validation_0-logloss:0.11680
# [178]	validation_0-logloss:0.11671
# [179]	validation_0-logloss:0.11658
# [180]	validation_0-logloss:0.11641
# [181]	validation_0-logloss:0.11634
# [182]	validation_0-logloss:0.11602
# [183]	validation_0-logloss:0.11576
# [184]	validation_0-logloss:0.11565
# [185]	validation_0-logloss:0.11559
# [186]	validation_0-logloss:0.11552
# [187]	validation_0-logloss:0.11540
# [188]	validation_0-logloss:0.11526
# [189]	validation_0-logloss:0.11497
# [190]	validation_0-logloss:0.11489
# [191]	validation_0-logloss:0.11478
# [192]	validation_0-logloss:0.11453
# [193]	validation_0-logloss:0.11466
# [194]	validation_0-logloss:0.11437
# [195]	validation_0-logloss:0.11427
# [196]	validation_0-logloss:0.11416
# [197]	validation_0-logloss:0.11413
# [198]	validation_0-logloss:0.11385
# [199]	validation_0-logloss:0.11366
# [200]	validation_0-logloss:0.11360
# [201]	validation_0-logloss:0.11339
# [202]	validation_0-logloss:0.11351
# [203]	validation_0-logloss:0.11341
# [204]	validation_0-logloss:0.11334
# [205]	validation_0-logloss:0.11307
# [206]	validation_0-logloss:0.11297
# [207]	validation_0-logloss:0.11295
# [208]	validation_0-logloss:0.11289
# [209]	validation_0-logloss:0.11267
# [210]	validation_0-logloss:0.11279
# [211]	validation_0-logloss:0.11262
# [212]	validation_0-logloss:0.11245
# [213]	validation_0-logloss:0.11220
# [214]	validation_0-logloss:0.11214
# [215]	validation_0-logloss:0.11207
# [216]	validation_0-logloss:0.11198
# [217]	validation_0-logloss:0.11180
# [218]	validation_0-logloss:0.11191
# [219]	validation_0-logloss:0.11186
# [220]	validation_0-logloss:0.11162
# [221]	validation_0-logloss:0.11155
# [222]	validation_0-logloss:0.11152
# [223]	validation_0-logloss:0.11132
# [224]	validation_0-logloss:0.11117
# [225]	validation_0-logloss:0.11102
# [226]	validation_0-logloss:0.11094
# [227]	validation_0-logloss:0.11072
# [228]	validation_0-logloss:0.11067
# [229]	validation_0-logloss:0.11063
# [230]	validation_0-logloss:0.11062
# [231]	validation_0-logloss:0.11054
# [232]	validation_0-logloss:0.11038
# [233]	validation_0-logloss:0.11048
# [234]	validation_0-logloss:0.11026
# [235]	validation_0-logloss:0.11030
# [236]	validation_0-logloss:0.11018
# [237]	validation_0-logloss:0.11011
# [238]	validation_0-logloss:0.11002
# [239]	validation_0-logloss:0.10998
# [240]	validation_0-logloss:0.10984
# [241]	validation_0-logloss:0.10981
# [242]	validation_0-logloss:0.10968
# [243]	validation_0-logloss:0.10954
# [244]	validation_0-logloss:0.10950
# [245]	validation_0-logloss:0.10933
# [246]	validation_0-logloss:0.10932
# [247]	validation_0-logloss:0.10911
# [248]	validation_0-logloss:0.10910
# [249]	validation_0-logloss:0.10903
# [250]	validation_0-logloss:0.10897
# [251]	validation_0-logloss:0.10895
# [252]	validation_0-logloss:0.10899
# [253]	validation_0-logloss:0.10879
# [254]	validation_0-logloss:0.10875
# [255]	validation_0-logloss:0.10862
# [256]	validation_0-logloss:0.10856
# [257]	validation_0-logloss:0.10865
# [258]	validation_0-logloss:0.10849
# [259]	validation_0-logloss:0.10830
# [260]	validation_0-logloss:0.10828
# [261]	validation_0-logloss:0.10824
# [262]	validation_0-logloss:0.10823
# [263]	validation_0-logloss:0.10817
# [264]	validation_0-logloss:0.10805
# [265]	validation_0-logloss:0.10793
# [266]	validation_0-logloss:0.10782
# [267]	validation_0-logloss:0.10776
# [268]	validation_0-logloss:0.10775
# [269]	validation_0-logloss:0.10757
# [270]	validation_0-logloss:0.10754
# [271]	validation_0-logloss:0.10752
# [272]	validation_0-logloss:0.10747
# [273]	validation_0-logloss:0.10755
# [274]	validation_0-logloss:0.10744
# [275]	validation_0-logloss:0.10730
# [276]	validation_0-logloss:0.10733
# [277]	validation_0-logloss:0.10731
# [278]	validation_0-logloss:0.10720
# [279]	validation_0-logloss:0.10703
# [280]	validation_0-logloss:0.10698
# [281]	validation_0-logloss:0.10696
# [282]	validation_0-logloss:0.10685
# [283]	validation_0-logloss:0.10693
# [284]	validation_0-logloss:0.10690
# [285]	validation_0-logloss:0.10685
# [286]	validation_0-logloss:0.10668
# [287]	validation_0-logloss:0.10667
# [288]	validation_0-logloss:0.10661
# [289]	validation_0-logloss:0.10660
# [290]	validation_0-logloss:0.10647
# [291]	validation_0-logloss:0.10650
# [292]	validation_0-logloss:0.10640
# [293]	validation_0-logloss:0.10636
# [294]	validation_0-logloss:0.10631
# [295]	validation_0-logloss:0.10615
# [296]	validation_0-logloss:0.10622
# [297]	validation_0-logloss:0.10602
# [298]	validation_0-logloss:0.10601
# [299]	validation_0-logloss:0.10591
# [300]	validation_0-logloss:0.10589
# [301]	validation_0-logloss:0.10587
# [302]	validation_0-logloss:0.10576
# [303]	validation_0-logloss:0.10575
# [304]	validation_0-logloss:0.10570
# [305]	validation_0-logloss:0.10566
# [306]	validation_0-logloss:0.10550
# [307]	validation_0-logloss:0.10550
# [308]	validation_0-logloss:0.10549
# [309]	validation_0-logloss:0.10530
# [310]	validation_0-logloss:0.10528
# [311]	validation_0-logloss:0.10534
# [312]	validation_0-logloss:0.10525
# [313]	validation_0-logloss:0.10521
# [314]	validation_0-logloss:0.10519
# [315]	validation_0-logloss:0.10505
# [316]	validation_0-logloss:0.10495
# [317]	validation_0-logloss:0.10494
# [318]	validation_0-logloss:0.10489
# [319]	validation_0-logloss:0.10488
# [320]	validation_0-logloss:0.10487
# [321]	validation_0-logloss:0.10468
# [322]	validation_0-logloss:0.10464
# [323]	validation_0-logloss:0.10471
# [324]	validation_0-logloss:0.10463
# [325]	validation_0-logloss:0.10455
# [326]	validation_0-logloss:0.10444
# [327]	validation_0-logloss:0.10431
# [328]	validation_0-logloss:0.10430
# [329]	validation_0-logloss:0.10429
# [330]	validation_0-logloss:0.10411
# [331]	validation_0-logloss:0.10411
# [332]	validation_0-logloss:0.10407
# [333]	validation_0-logloss:0.10403
# [334]	validation_0-logloss:0.10402
# [335]	validation_0-logloss:0.10401
# [336]	validation_0-logloss:0.10393
# [337]	validation_0-logloss:0.10393
# [338]	validation_0-logloss:0.10380
# [339]	validation_0-logloss:0.10376
# [340]	validation_0-logloss:0.10375
# [341]	validation_0-logloss:0.10359
# [342]	validation_0-logloss:0.10365
# [343]	validation_0-logloss:0.10357
# [344]	validation_0-logloss:0.10353
# [345]	validation_0-logloss:0.10355
# [346]	validation_0-logloss:0.10350
# [347]	validation_0-logloss:0.10341
# [348]	validation_0-logloss:0.10328
# [349]	validation_0-logloss:0.10328
# Best parameters found:  {'n_estimators': 350, 'max_depth': 3, 'learning_rate': 0.05}
# Testing accuracy after early stopping:  0.9641455561415034

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

def evaluate_model_and_plot_roc(bdt, df_subset, training_vars, subset_label):
    # Prepare the subset's data
    X_subset = df_subset[training_vars]
    y_subset = df_subset['label']
    weights_subset = df_subset['weight']
    
        #Change column names to integers if needed (for ML models that expect numerical feature names)
    feature_mapping = {feature: i for i, feature in enumerate(X_subset.columns)}
    X_subset.rename(columns=feature_mapping, inplace=True)
    
    # Predict probabilities for the subset data
    probs_subset = bdt.predict_proba(X_subset)[:, 1]  # Assuming positive class is at index 1

    # Calculate FPR, TPR, and AUC for the subset
    fpr, tpr, thresholds = roc_curve(y_subset, probs_subset, sample_weight=weights_subset)
    auc_score = roc_auc_score(y_subset, probs_subset, sample_weight=weights_subset)
    return fpr, tpr, auc_score

# After training and optimizing your BDT, you can evaluate and plot ROC curves for the subsets
plt.figure(figsize=(10, 8))


fpr5, tpr5, auc5 = evaluate_model_and_plot_roc(best_estimator, df_1p1p, training_vars, '1p1p')
fpr6, tpr6, auc6 = evaluate_model_and_plot_roc(best_estimator, df_3p3p, training_vars, '3p3p')
fpr7, tpr7, auc7 = evaluate_model_and_plot_roc(best_estimator, df_1p3p, training_vars, '1p3p')

# Plotting ROC Curve
plt.figure(figsize=(22, 10))
plt.subplot(121)
plt.plot(fpr5, tpr5, lw=2, label='1p1p (area = %0.5f)' % auc5)
plt.plot(fpr6, tpr6, lw=2, label='3p3p (area = %0.5f)' % auc6)
plt.plot(fpr7, tpr7, lw=2, label='1p3p (area = %0.5f)' % auc7)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(True)

plt.subplot(122)
plt.plot(tpr5, 1/fpr5, lw=1, label='1p1p (area = %0.5f)' % auc5)
plt.plot(tpr6, 1/fpr6, lw=1, label='3p3p (area = %0.5f)' % auc6)
plt.plot(tpr7, 1/fpr7, lw=1, label='1p3p (area = %0.5f)' % auc7)

plt.xlabel('Signal efficiency (TPR)')
plt.ylabel('Inverse background efficiency (1/FPR)')
plt.yscale('log')
# yticks = np.linspace(0, 10e9, 71)
# plt.yticks(yticks, labels=[str(ytick) for ytick in yticks])
plt.axhline(y=1e4, color='r', linestyle='--', label='y=1e4')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.show()
# Out:
# /tmp/ipykernel_389/2916452910.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_subset.rename(columns=feature_mapping, inplace=True)
# /tmp/ipykernel_389/2916452910.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_subset.rename(columns=feature_mapping, inplace=True)
# /tmp/ipykernel_389/2916452910.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_subset.rename(columns=feature_mapping, inplace=True)
# /tmp/ipykernel_389/2916452910.py:46: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr5, 1/fpr5, lw=1, label='1p1p (area = %0.5f)' % auc5)
# /tmp/ipykernel_389/2916452910.py:47: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr6, 1/fpr6, lw=1, label='3p3p (area = %0.5f)' % auc6)
# /tmp/ipykernel_389/2916452910.py:48: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr7, 1/fpr7, lw=1, label='1p3p (area = %0.5f)' % auc7)

# %%
# Old BDT ROC

scores = df['bdt_score']
true_labels = df['label'] 


fpr, tpr, thresholds = roc_curve(true_labels, scores)

# Calculate the Area Under the Curve (AUC) for ROC
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(10, 10))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.5f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# Assuming train_df, test_df, and training_vars are already defined in your workspace

# Training & Testing sets as provided
training_data, testing_data, training_labels, testing_labels, training_weights, testing_weights = \
    train_df[training_vars], test_df[training_vars], train_df['label'], test_df['label'], train_df['weight'], test_df['weight']

# Define the classifier
bdt = XGBClassifier(random_state=0, verbosity=1)

# Define the parameter distribution
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [2, 3, 4, 5, 6]
}

# Define the search with RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=bdt, param_distributions=param_dist, n_iter=10, scoring='accuracy', cv=3, verbose=2, random_state=0, n_jobs=-1)

# Perform the search
# Note: We don't use the testing set here; it's for final evaluation
random_search.fit(training_data, training_labels, sample_weight=training_weights)

# Best estimator found by RandomizedSearchCV
best_estimator = random_search.best_estimator_

# Manually apply early stopping using a portion of the training set as a validation set
# Note: XGBoost handles validation sets for early stopping, but we use training and testing sets as provided
eval_set = [(testing_data, testing_labels)]
best_estimator.fit(training_data, training_labels, sample_weight=training_weights, early_stopping_rounds=10, eval_metric="logloss", eval_set=eval_set, verbose=True)

# Predictions and final evaluation on the testing set
predictions = best_estimator.predict(testing_data)
accuracy = accuracy_score(testing_labels, predictions, sample_weight=testing_weights)

# Output the results
print("Best parameters found: ", random_search.best_params_)
print("Testing accuracy after early stopping: ", accuracy)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# /cvmfs/sft.cern.ch/lcg/views/LCG_104a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /cvmfs/sft.cern.ch/lcg/views/LCG_104a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-logloss:0.62437
# [1]	validation_0-logloss:0.56794
# [2]	validation_0-logloss:0.52116
# [3]	validation_0-logloss:0.48210
# [4]	validation_0-logloss:0.44932
# [5]	validation_0-logloss:0.42171
# [6]	validation_0-logloss:0.39842
# [7]	validation_0-logloss:0.37878
# [8]	validation_0-logloss:0.36223
# [9]	validation_0-logloss:0.34832
# [10]	validation_0-logloss:0.33669
# [11]	validation_0-logloss:0.32701
# [12]	validation_0-logloss:0.31904
# [13]	validation_0-logloss:0.31253
# [14]	validation_0-logloss:0.30730
# [15]	validation_0-logloss:0.30319
# [16]	validation_0-logloss:0.30005
# [17]	validation_0-logloss:0.29776
# [18]	validation_0-logloss:0.29621
# [19]	validation_0-logloss:0.29530
# [20]	validation_0-logloss:0.29495
# [21]	validation_0-logloss:0.29508
# [22]	validation_0-logloss:0.29564
# [23]	validation_0-logloss:0.29656
# [24]	validation_0-logloss:0.29780
# [25]	validation_0-logloss:0.29930
# [26]	validation_0-logloss:0.30103
# [27]	validation_0-logloss:0.30296
# [28]	validation_0-logloss:0.30506
# [29]	validation_0-logloss:0.30729
# Best parameters found:  {'n_estimators': 200, 'max_depth': 2, 'learning_rate': 0.1}
# Testing accuracy after early stopping:  0.9996640877197835

# %%
from xgboost import XGBClassifier

# create the BDT

params = {
'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200,
'eval_metric': 'logloss',
'random_state': 0,
'gamma': 0.001,
'verbosity': 2
}
bdt = XGBClassifier(**params)
print(type(bdt))

# Train the classifier
bdt.fit(training_data, training_labels, eval_set=[(testing_data, testing_labels)], sample_weight=training_weights, early_stopping_rounds=10, verbose=True)
# Out:
# <class 'xgboost.sklearn.XGBClassifier'>
# /cvmfs/sft.cern.ch/lcg/views/LCG_104a_cuda/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [21:08:21] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [0]	validation_0-logloss:0.62437
# [21:08:21] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [1]	validation_0-logloss:0.56794
# [21:08:21] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [2]	validation_0-logloss:0.52116
# [21:08:21] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [3]	validation_0-logloss:0.48210
# [21:08:21] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [4]	validation_0-logloss:0.44932
# [21:08:21] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [5]	validation_0-logloss:0.42171
# [21:08:22] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [6]	validation_0-logloss:0.39842
# [21:08:22] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [7]	validation_0-logloss:0.37878
# [21:08:22] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [8]	validation_0-logloss:0.36223
# [21:08:22] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [9]	validation_0-logloss:0.34832
# [21:08:22] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10]	validation_0-logloss:0.33669
# [21:08:22] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [11]	validation_0-logloss:0.32701
# [21:08:22] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12]	validation_0-logloss:0.31904
# [21:08:23] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [13]	validation_0-logloss:0.31253
# [21:08:23] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [14]	validation_0-logloss:0.30730
# [21:08:23] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15]	validation_0-logloss:0.30319
# [21:08:23] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [16]	validation_0-logloss:0.30005
# [21:08:23] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [17]	validation_0-logloss:0.29776
# [21:08:23] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [18]	validation_0-logloss:0.29621
# [21:08:23] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [19]	validation_0-logloss:0.29530
# [21:08:23] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [20]	validation_0-logloss:0.29495
# [21:08:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [21]	validation_0-logloss:0.29508
# [21:08:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [22]	validation_0-logloss:0.29564
# [21:08:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23]	validation_0-logloss:0.29656
# [21:08:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [24]	validation_0-logloss:0.29780
# [21:08:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [25]	validation_0-logloss:0.29930
# [21:08:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [26]	validation_0-logloss:0.30103
# [21:08:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [27]	validation_0-logloss:0.30296
# [21:08:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [28]	validation_0-logloss:0.30506
# [21:08:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [29]	validation_0-logloss:0.30729
# [21:08:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=0.001, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=0, ...)

# %%
# Predict probabilities for the testing data
probs = bdt.predict_proba(testing_data)
probs = probs[:, 1]

fpr_w, tpr_w, thresholds_w = roc_curve(testing_labels, probs, sample_weight=testing_weights)
auc_w = roc_auc_score(testing_labels, probs, sample_weight=testing_weights)
plt.figure(figsize=(10, 10))
plt.plot(fpr_w, tpr_w, label='BDT (area = {:.5f})'.format(auc_w))
plt.plot([0, 1], [0, 1], linestyle='--', label='Random classifier')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)
plt.show()

# %%
# shuffle the data
combined_data = df.sample(frac=1, random_state=42).reset_index(drop=True)

pd_data = combined_data[training_vars]
pd_weights = combined_data["weight"]
pd_labels = combined_data["label"]
print(pd_data)

feature_mapping = {feature: i for i, feature in enumerate(pd_data.columns)}
pd_data.rename(columns=feature_mapping, inplace=True)

print(pd_data)

# split the data into training and testing sets
training_data = pd_data[:int(len(pd_data)*0.8)]
training_labels = pd_labels[:int(len(pd_labels)*0.8)]
training_weights = pd_weights[:int(len(pd_weights)*0.8)]
print("training data: ", training_data.shape)
print("training labels: ", training_labels.shape)
print("training weights: ", training_weights.shape)

testing_data = pd_data[int(len(pd_data)*0.8):]
testing_labels = pd_labels[int(len(pd_labels)*0.8):]
testing_weights = pd_weights[int(len(pd_weights)*0.8):]
print("testing data: ", testing_data.shape)
print("testing labels: ", testing_labels.shape)
print("testing weights: ", testing_weights.shape)

from xgboost import XGBClassifier

# create the BDT

params = {
'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 150,
'eval_metric': 'logloss',
'random_state': 0,
'gamma': 0.001,
'verbosity': 2
}
bdt = XGBClassifier(**params)
print(type(bdt))

# Train the classifier
# bdt.fit(training_data, training_labels, sample_weight=training_weights)
bdt.fit(training_data, training_labels, eval_set=[(testing_data, testing_labels)], sample_weight=training_weights)
# Out:
#         f_core_lead  f_core_subl  f_subjet_subl  f_subjets  f_isotracks  \
# 0          0.827793     0.350880       0.062836   0.858453    -2.799728
# 1          0.764538     0.637128       0.063641   0.695171    -4.067375
# 2          0.732874     0.404267       0.067793   0.794315    -3.245469
# 3          0.904525     0.795641       0.039079   0.908339    -5.659952
# 4          0.912951     0.423179       0.030607   0.743083    -4.251077
# ...             ...          ...            ...        ...          ...
# 504635     0.876822     0.478093       0.067242   0.868660    -3.982208
# 504636     0.879936     0.320422       0.042640   0.774761    -4.539171
# 504637     0.850109     0.076170       0.039220   0.760628    -4.561179
# 504638     0.941038     0.653944       0.222461   0.715479    -3.761817
# 504639     0.767183     0.369936       0.034320   0.814702    -4.180725
#
#         R_max_lead  R_max_subl  R_isotrack  R_tracks_subl  m_core_lead  \
# 0         0.029167    0.063695    0.324031       0.063695     7.865781
# 1         0.010157    0.188378    0.000000       0.045902     4.938566
# 2         0.083204    0.156891    0.266551       0.061745     8.353924
# 3         0.026521    0.025856    0.343312       0.025856     7.811155
# 4         0.041459    0.066418    0.219945       0.066418     7.794516
# ...            ...         ...         ...            ...          ...
# 504635    0.110717    0.068004    0.000000       0.068004     6.477498
# 504636    0.071658    0.041274    0.347089       0.041274     8.429175
# 504637    0.177919    0.194902    0.000000       0.192242     7.295501
# 504638    0.008129    0.148461    0.273591       0.115428     4.938566
# 504639    0.171362    0.096364    0.243293       0.096364     7.706848
#
#         m_core_subl  m_tracks_lead  m_tracks_subl  d0_leadtrack_lead  \
# 0          4.938566       7.865781       4.938566          -5.389095
# 1          5.886131       4.938566       6.976428          -4.095087
# 2          4.938566       8.353924       6.287044          -4.701188
# 3          4.938566       7.811155       4.938566          -3.668038
# 4          4.938566       7.794516       4.938566          -2.695716
# ...             ...            ...            ...                ...
# 504635     4.938566       7.555028       4.938566          -1.657277
# 504636     4.938566       8.429175       4.938566          -3.117984
# 504637     4.938566       8.539675       8.405775          -4.090800
# 504638     6.286530       4.938566       7.316108          -4.659560
# 504639     4.938566       8.299217       4.938566          -8.998904
#
#         d0_leadtrack_subl  n_track  n_tracks_lead
# 0               -4.105252        4              3
# 1               -3.702071        6              1
# 2               -4.414057        6              3
# 3               -3.239069        5              3
# 4               -1.865305        4              3
# ...                   ...      ...            ...
# 504635          -2.609455        4              3
# 504636          -3.018717        4              3
# 504637          -2.913376        4              3
# 504638          -3.926974        8              1
# 504639          -4.329872        4              3
#
# [504640 rows x 17 columns]
#               0         1         2         3         4         5         6   \
# 0       0.827793  0.350880  0.062836  0.858453 -2.799728  0.029167  0.063695
# 1       0.764538  0.637128  0.063641  0.695171 -4.067375  0.010157  0.188378
# 2       0.732874  0.404267  0.067793  0.794315 -3.245469  0.083204  0.156891
# 3       0.904525  0.795641  0.039079  0.908339 -5.659952  0.026521  0.025856
# 4       0.912951  0.423179  0.030607  0.743083 -4.251077  0.041459  0.066418
# ...          ...       ...       ...       ...       ...       ...       ...
# 504635  0.876822  0.478093  0.067242  0.868660 -3.982208  0.110717  0.068004
# 504636  0.879936  0.320422  0.042640  0.774761 -4.539171  0.071658  0.041274
# 504637  0.850109  0.076170  0.039220  0.760628 -4.561179  0.177919  0.194902
# 504638  0.941038  0.653944  0.222461  0.715479 -3.761817  0.008129  0.148461
# 504639  0.767183  0.369936  0.034320  0.814702 -4.180725  0.171362  0.096364
#
#               7         8         9         10        11        12        13  \
# 0       0.324031  0.063695  7.865781  4.938566  7.865781  4.938566 -5.389095
# 1       0.000000  0.045902  4.938566  5.886131  4.938566  6.976428 -4.095087
# 2       0.266551  0.061745  8.353924  4.938566  8.353924  6.287044 -4.701188
# 3       0.343312  0.025856  7.811155  4.938566  7.811155  4.938566 -3.668038
# 4       0.219945  0.066418  7.794516  4.938566  7.794516  4.938566 -2.695716
# ...          ...       ...       ...       ...       ...       ...       ...
# 504635  0.000000  0.068004  6.477498  4.938566  7.555028  4.938566 -1.657277
# 504636  0.347089  0.041274  8.429175  4.938566  8.429175  4.938566 -3.117984
# 504637  0.000000  0.192242  7.295501  4.938566  8.539675  8.405775 -4.090800
# 504638  0.273591  0.115428  4.938566  6.286530  4.938566  7.316108 -4.659560
# 504639  0.243293  0.096364  7.706848  4.938566  8.299217  4.938566 -8.998904
#
#               14  15  16
# 0      -4.105252   4   3
# 1      -3.702071   6   1
# 2      -4.414057   6   3
# 3      -3.239069   5   3
# 4      -1.865305   4   3
# ...          ...  ..  ..
# 504635 -2.609455   4   3
# 504636 -3.018717   4   3
# 504637 -2.913376   4   3
# 504638 -3.926974   8   1
# 504639 -4.329872   4   3
#
# [504640 rows x 17 columns]
# training data:  (403712, 17)
# training labels:  (403712,)
# training weights:  (403712,)
# testing data:  (100928, 17)
# testing labels:  (100928,)
# testing weights:  (100928,)
# <class 'xgboost.sklearn.XGBClassifier'>
# /tmp/ipykernel_7500/279282278.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd_data.rename(columns=feature_mapping, inplace=True)
# [02:40:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [0]	validation_0-logloss:0.64137
# [02:40:24] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [1]	validation_0-logloss:0.59834
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [2]	validation_0-logloss:0.56243
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [3]	validation_0-logloss:0.53237
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [4]	validation_0-logloss:0.50717
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [5]	validation_0-logloss:0.48606
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [6]	validation_0-logloss:0.46840
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [7]	validation_0-logloss:0.45369
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [8]	validation_0-logloss:0.44149
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [9]	validation_0-logloss:0.43147
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10]	validation_0-logloss:0.42331
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [11]	validation_0-logloss:0.41676
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12]	validation_0-logloss:0.41162
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [13]	validation_0-logloss:0.40769
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [14]	validation_0-logloss:0.40481
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15]	validation_0-logloss:0.40285
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [16]	validation_0-logloss:0.40169
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [17]	validation_0-logloss:0.40123
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [18]	validation_0-logloss:0.40136
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [19]	validation_0-logloss:0.40202
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [20]	validation_0-logloss:0.40312
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [21]	validation_0-logloss:0.40462
# [02:40:25] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [22]	validation_0-logloss:0.40645
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23]	validation_0-logloss:0.40858
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [24]	validation_0-logloss:0.41095
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [25]	validation_0-logloss:0.41353
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [26]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [27]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [28]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [29]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [30]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [31]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [32]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [33]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [34]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [35]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [36]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [37]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [38]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [39]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [40]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [41]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [42]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [43]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [44]	validation_0-logloss:0.41628
# [02:40:26] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [45]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [46]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [47]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [48]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [49]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [50]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [51]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [52]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [53]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [54]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [55]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [56]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [57]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [58]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [59]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [60]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [61]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [62]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [63]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [64]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [65]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [66]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [67]	validation_0-logloss:0.41628
# [02:40:27] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [68]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [69]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [70]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [71]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [72]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [73]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [74]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [75]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [76]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [77]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [78]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [79]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [80]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [81]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [82]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [83]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [84]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [85]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [86]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [87]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [88]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [89]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [90]	validation_0-logloss:0.41628
# [02:40:28] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [91]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [92]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [93]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [94]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [95]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [96]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [97]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [98]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [99]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [100]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [101]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [102]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [103]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [104]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [105]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [106]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [107]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [108]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [109]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [110]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [111]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [112]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [113]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [114]	validation_0-logloss:0.41628
# [02:40:29] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [115]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [116]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [117]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [118]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [119]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [120]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [121]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [122]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [123]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [124]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [125]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [126]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [127]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [128]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [129]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [130]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [131]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [132]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [133]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [134]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [135]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [136]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [137]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [138]	validation_0-logloss:0.41628
# [02:40:30] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [139]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [140]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [141]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [142]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [143]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [144]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [145]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [146]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [147]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [148]	validation_0-logloss:0.41628
# [02:40:31] INFO: /build/jenkins/workspace/lcg_release_pipeline/build/pyexternals/xgboost-1.7.3/src/xgboost/1.7.3/src/tree/updater_prune.cc:98: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [149]	validation_0-logloss:0.41628
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=0.001, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=150, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=0, ...)

# %%
# Plotting the ROC
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities
probabilities = bdt.predict_proba(testing_data)[:,1]

# Calculate TPR and FPR
fpr, tpr, _ = roc_curve(testing_labels, probabilities, sample_weight=testing_weights)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.6f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
