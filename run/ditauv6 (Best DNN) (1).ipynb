# %%
import uproot, ROOT, glob, os, random
import matplotlib.pyplot as plt
import numpy as np
import awkward as ak
from sklearn.metrics import roc_curve, roc_auc_score, auc
from tqdm import tqdm
import pandas as pd
from xgboost import XGBClassifier
import seaborn as sns


# Set up plot defaults
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = 12.0,8.0  # Roughly 11 cm wde by 8 cm high
mpl.rcParams['font.size'] = 16.0 # Use 14 point font
sns.set(style="whitegrid")

path = '/eos/user/j/jlai/tau_test/'
# Out:
# Welcome to JupyROOT 6.28/06

# %%
# !ls /eos/user/j/jlai/tau_test
# Out:
# bdt_training_latest.py
# bdt_training.py
# combined_data.csv
# combined_data.h5
# conda_env.txt
# ditau_flattened_0.h5
# ditau_flattened_10.h5
# ditau_flattened_11.h5
# ditau_flattened_12.h5
# ditau_flattened_1.h5
# ditau_flattened_2.h5
# ditau_flattened_3.h5
# ditau_flattened_4.h5
# ditau_flattened_5.h5
# ditau_flattened_6.h5
# ditau_flattened_7.h5
# ditau_flattened_8.h5
# ditau_flattened_9.h5
# ditau_no_empty.py
# gamma_flattened_0.h5
# graviton_flattened_M1000.h5
# graviton_flattened_M1750.h5
# graviton_flattened_M2000.h5
# graviton_flattened_M2500.h5
# graviton_flattened_M5000.h5
# plotter_v4.py
# skimmer.py
# test.py
# user.agarabag.DiJetNewbdt.364701.Pythia8EvtGen_A14NNPDF23LO_jetjet_JZ1WithSW_v1_output.root

# %%
branches = ['ditau_pt', 'n_subjets', 'IsTruthHadronic', 'n_tracks_lead', 'n_tracks_subl',
 'R_max_lead', 'R_max_subl', 'R_tracks_subl', 'R_isotrack', 'd0_leadtrack_lead',
 'd0_leadtrack_subl', 'f_core_lead', 'f_core_subl', 'f_subjet_subl', 'f_subjets',
 'f_isotracks', 'm_core_lead', 'm_core_subl', 'm_tracks_lead', 'm_tracks_subl',
 'n_track']

training_vars = [
    "f_core_lead", "f_core_subl", "f_subjet_subl", "f_subjets", "f_isotracks",
    "R_max_lead", "R_max_subl", "R_isotrack", "R_tracks_subl", "m_core_lead",
    "m_core_subl", "m_tracks_lead", "m_tracks_subl", "d0_leadtrack_lead",
    "d0_leadtrack_subl", "n_track", "n_tracks_lead"
]

df = pd.read_csv(path+'combined_data.csv')
df = df[6:] # get rid of jz0 and jz1
df = df[df.f_core_subl != -999] # get rid of outlier
df['weight'] = df['event_weight'] * df['pT_weight']
df
# Out:
#          event_id   ditau_pt  IsTruthHadronic  f_core_lead  f_core_subl  \
# 6        36300348  200720.88                0     0.847755     0.683239
# 7        27674456  249767.81                0     0.809443     0.844066
# 8        45574018  209212.66                0     0.855507     0.764981
# 9        42745976  215885.73                0     0.963799     0.667000
# 10       40522366  250142.16                0     0.728881     0.689589
# ...           ...        ...              ...          ...          ...
# 1250003  31163332  526071.20                1     0.910397     0.969296
# 1250004  30334126  336502.47                1     0.915086     0.163371
# 1250005  30541837  361832.78                1     0.921741     0.790117
# 1250006  30665541  267720.94                1     0.791846     0.778316
# 1250007  30667209  410118.97                1     0.852904     0.970131
#
#          f_subjet_subl  f_subjets  f_isotracks  R_max_lead  R_max_subl  ...  \
# 6             0.084422   0.555999     0.014591    0.027558    0.149601  ...
# 7             0.247756   0.625814     0.005726    0.182669    0.010000  ...
# 8             0.295278   0.669263     0.003218    0.060898    0.046829  ...
# 9             0.252668   0.700827     0.008621    0.120004    0.182444  ...
# 10            0.396467   0.812390     0.003817    0.194865    0.033817  ...
# ...                ...        ...          ...         ...         ...  ...
# 1250003       0.104997   0.943490     0.000000    0.015913    0.023469  ...
# 1250004       0.118368   0.814084     0.003424    0.013215    0.022163  ...
# 1250005       0.321459   0.791638     0.007923    0.008872    0.035717  ...
# 1250006       0.255994   0.886948     0.003313    0.014343    0.010908  ...
# 1250007       0.218640   0.924706     0.000000    0.007117    0.017163  ...
#
#          d0_leadtrack_subl  n_track  n_tracks_lead  n_tracks_subl  n_subjets  \
# 6                 0.022509        5              1              3          3
# 7                -0.014537        6              3              1          4
# 8                -0.036782        4              1              3          2
# 9                 0.000000       12              3              1          5
# 10               -0.003847        4              3              1          2
# ...                    ...      ...            ...            ...        ...
# 1250003          -0.059134        4              3              1          2
# 1250004          -0.051443        5              3              1          3
# 1250005           0.030005        4              1              3          2
# 1250006          -0.053649        4              3              1          2
# 1250007          -0.005152        4              3              1          2
#
#          event_weight  bdt_score     pT_weight  label    weight
# 6        6.836578e-02   0.610205  2.444456e-04      0  0.000017
# 7        2.085233e-02   0.679975  1.223512e-04      0  0.000003
# 8        1.271062e-02   0.682694  2.444456e-04      0  0.000003
# 9        2.134600e-02   0.419487  2.444456e-04      0  0.000005
# 10       9.952256e-02   0.657240  1.223512e-04      0  0.000012
# ...               ...        ...           ...    ...       ...
# 1250003  2.144722e-10   0.799701  4.662652e+08      1  0.100001
# 1250004  2.144722e-10   0.716544  9.515616e+07      1  0.020408
# 1250005  2.144722e-10   0.747290  1.227014e+08      1  0.026316
# 1250006  2.144722e-10   0.729371  7.173202e+07      1  0.015385
# 1250007  2.144722e-10   0.753709  3.330466e+08      1  0.071429
#
# [1250001 rows x 27 columns]

# %%
df.describe()
# Out:
#            event_id      ditau_pt  IsTruthHadronic   f_core_lead  \
# count  1.250001e+06  1.250001e+06     1.250001e+06  1.250001e+06
# mean   2.073476e+08  4.314831e+05     8.599673e-02  8.598232e-01
# std    1.541140e+08  1.848540e+05     2.803593e-01  8.018174e-02
# min    1.100000e+01  2.000000e+05     0.000000e+00  7.191471e-03
# 25%    7.486472e+07  2.835506e+05     0.000000e+00  8.237005e-01
# 50%    1.900003e+08  3.872961e+05     0.000000e+00  8.742300e-01
# 75%    2.939791e+08  5.260131e+05     0.000000e+00  9.139876e-01
# max    4.930031e+08  9.999968e+05     1.000000e+00  9.975535e-01
#
#         f_core_subl  f_subjet_subl     f_subjets   f_isotracks    R_max_lead  \
# count  1.250001e+06   1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06
# mean   4.351379e-01   6.459976e-02  8.185769e-01  1.535391e-02  8.801527e-02
# std    2.565048e-01   7.808390e-02  9.088417e-02  5.143370e-02  6.308150e-02
# min    2.094379e-04   2.818542e-03  9.065603e-02  0.000000e+00  1.995845e-05
# 25%    2.080576e-01   2.565938e-02  7.623764e-01  4.393903e-03  2.783664e-02
# 50%    4.272147e-01   3.605864e-02  8.344137e-01  1.042412e-02  7.588327e-02
# 75%    6.306292e-01   5.891509e-02  8.880830e-01  1.992001e-02  1.476200e-01
# max    1.000000e+00   5.146357e-01  1.067907e+00  3.191106e+01  2.000000e-01
#
#          R_max_subl  ...  d0_leadtrack_subl       n_track  n_tracks_lead  \
# count  1.250001e+06  ...       1.250001e+06  1.250001e+06   1.250001e+06
# mean   1.161825e-01  ...      -2.685822e-04  4.818627e+00   2.784576e+00
# std    5.708317e-02  ...       8.296457e-02  1.882580e+00   6.200327e-01
# min    5.141489e-05  ...      -1.015759e+00  4.000000e+00   1.000000e+00
# 25%    7.045868e-02  ...       0.000000e+00  4.000000e+00   3.000000e+00
# 50%    1.230879e-01  ...       0.000000e+00  4.000000e+00   3.000000e+00
# 75%    1.665299e-01  ...       0.000000e+00  5.000000e+00   3.000000e+00
# max    1.999999e-01  ...       1.017063e+00  4.800000e+01   3.000000e+00
#
#        n_tracks_subl     n_subjets  event_weight     bdt_score     pT_weight  \
# count   1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06
# mean    1.215424e+00  2.453793e+00  2.448417e-04  5.061150e-01  1.463637e+05
# std     6.200327e-01  8.112378e-01  1.728348e-03  1.070053e-01  1.595557e+07
# min     1.000000e+00  2.000000e+00  5.141540e-16  2.653651e-01  1.223512e-04
# 25%     1.000000e+00  2.000000e+00  5.266416e-06  4.261238e-01  1.503699e-02
# 50%     1.000000e+00  2.000000e+00  2.586703e-05  4.895093e-01  3.608175e-01
# 75%     1.000000e+00  3.000000e+00  2.414404e-04  5.648352e-01  5.069307e+00
# max     3.000000e+00  1.600000e+01  1.437270e+00  8.212081e-01  4.662652e+09
#
#               label        weight
# count  1.250001e+06  1.250001e+06
# mean   8.598953e-02  9.248986e-05
# std    2.803487e-01  3.454206e-03
# min    0.000000e+00  7.057462e-20
# 25%    0.000000e+00  3.004970e-06
# 50%    0.000000e+00  1.732888e-05
# 75%    0.000000e+00  4.427668e-05
# max    1.000000e+00  1.000032e+00
#
# [8 rows x 27 columns]

# %%
from sklearn.preprocessing import StandardScaler

# normalize the data
scaler = StandardScaler()

df[training_vars] = scaler.fit_transform(df[training_vars])

df.describe()
# Out:
#            event_id      ditau_pt  IsTruthHadronic   f_core_lead  \
# count  1.250001e+06  1.250001e+06     1.250001e+06  1.250001e+06
# mean   2.073476e+08  4.314831e+05     8.599673e-02 -9.371426e-16
# std    1.541140e+08  1.848540e+05     2.803593e-01  1.000000e+00
# min    1.100000e+01  2.000000e+05     0.000000e+00 -1.063374e+01
# 25%    7.486472e+07  2.835506e+05     0.000000e+00 -4.505100e-01
# 50%    1.900003e+08  3.872961e+05     0.000000e+00  1.796774e-01
# 75%    2.939791e+08  5.260131e+05     0.000000e+00  6.755212e-01
# max    4.930031e+08  9.999968e+05     1.000000e+00  1.717728e+00
#
#         f_core_subl  f_subjet_subl     f_subjets   f_isotracks    R_max_lead  \
# count  1.250001e+06   1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06
# mean   1.455190e-18   5.529723e-17  1.698935e-16  1.155057e-16  6.912154e-17
# std    1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.695597e+00  -7.912161e-01 -8.009328e+00 -2.985186e-01 -1.394947e+00
# 25%   -8.852872e-01  -4.986994e-01 -6.183751e-01 -2.130901e-01 -9.539827e-01
# 50%   -3.088883e-02  -3.655187e-01  1.742528e-01 -9.584754e-02 -1.923227e-01
# 75%    7.621356e-01  -7.280212e-02  7.647777e-01  8.877638e-02  9.448846e-01
# max    2.202152e+00   5.763494e+00  2.743385e+00  6.201327e+02  1.775239e+00
#
#          R_max_subl  ...  d0_leadtrack_subl       n_track  n_tracks_lead  \
# count  1.250001e+06  ...       1.250001e+06  1.250001e+06   1.250001e+06
# mean  -9.014904e-16  ...      -7.241846e-18  2.011119e-16   1.513398e-16
# std    1.000000e+00  ...       1.000000e+00  1.000000e+00   1.000000e+00
# min   -2.034420e+00  ...      -1.224005e+01 -4.348431e-01  -2.878198e+00
# 25%   -8.010043e-01  ...       3.237313e-03 -4.348431e-01   3.474396e-01
# 50%    1.209699e-01  ...       3.237313e-03 -4.348431e-01   3.474396e-01
# 75%    8.820007e-01  ...       3.237313e-03  9.634306e-02   3.474396e-01
# max    1.468338e+00  ...       1.226225e+01  2.293735e+01   3.474396e-01
#
#        n_tracks_subl     n_subjets  event_weight     bdt_score     pT_weight  \
# count   1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06
# mean    1.215424e+00  2.453793e+00  2.448417e-04  5.061150e-01  1.463637e+05
# std     6.200327e-01  8.112378e-01  1.728348e-03  1.070053e-01  1.595557e+07
# min     1.000000e+00  2.000000e+00  5.141540e-16  2.653651e-01  1.223512e-04
# 25%     1.000000e+00  2.000000e+00  5.266416e-06  4.261238e-01  1.503699e-02
# 50%     1.000000e+00  2.000000e+00  2.586703e-05  4.895093e-01  3.608175e-01
# 75%     1.000000e+00  3.000000e+00  2.414404e-04  5.648352e-01  5.069307e+00
# max     3.000000e+00  1.600000e+01  1.437270e+00  8.212081e-01  4.662652e+09
#
#               label        weight
# count  1.250001e+06  1.250001e+06
# mean   8.598953e-02  9.248986e-05
# std    2.803487e-01  3.454206e-03
# min    0.000000e+00  7.057462e-20
# 25%    0.000000e+00  3.004970e-06
# 50%    0.000000e+00  1.732888e-05
# 75%    0.000000e+00  4.427668e-05
# max    1.000000e+00  1.000032e+00
#
# [8 rows x 27 columns]

# %%
# Plot the Transformed Training Vars
signal = df[df.label==1]
bkg = df[df.label==0]

plt.figure(figsize=(30, 24))
def hist(variable, plot_num):
    plt.subplot(4, 5, plot_num)
    bin = 50
    plt.hist(bkg[variable], bins=bin, histtype='step', linewidth=1, weights=bkg['weight'], label=f'qcd μ:{np.mean(bkg[variable]):.2f}, σ:{np.std(bkg[variable]):.2f}')
    plt.hist(signal[variable], bins=bin, histtype='step', linewidth=1, weights=signal['weight'], label=f'signal μ:{np.mean(signal[variable]):.2f}, σ:{np.std(signal[variable]):.2f}')
    plt.xlabel(variable)
    plt.yscale('log')
    plt.legend()
    plt.grid(True)

for i, label in tqdm(enumerate(training_vars, 1)):
    hist(label, i)
# Out:
# 17it [00:01, 12.74it/s]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import time

start = time.time()

learning_rate = 0.0005
batch_size = 64
dropout = 0
neuron1 = 256
neuron2 = 1024
neuron3 = 512
neuron4 = 128
neuron5 = 32

# features = df[training_vars].values
# labels = df['label'].values
# weights = df['weight'].values

# # Split the dataset into training and validation sets
# X_train, X_val, y_train, y_val, weights_train, weights_val = train_test_split(
#     features, labels, weights, test_size=0.2, random_state=42)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Split the dataset into training and validation sets
df['eventID_mod'] = df['event_id'] % 10

train_loc = df['eventID_mod'] < 7 # 70%
test_loc = df['eventID_mod'] >= 7 # 30%

features, labels, weights = df[training_vars].values, df['label'].values, df['weight'].values

X_train, X_val, y_train, y_val, weights_train, weights_val = \
      features[train_loc], features[test_loc], labels[train_loc], labels[test_loc], weights[train_loc], weights[test_loc] 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Convert to PyTorch tensors and move to device
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
weights_train_tensor = torch.tensor(weights_train, dtype=torch.float32).to(device)

X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device)

# Define the Dataset
class SignalBackgroundDataset(Dataset):
    def __init__(self, features, labels, weights):
        self.features = features
        self.labels = labels
        self.weights = weights

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx], self.weights[idx]

# Define the DNN model with dropout
class DNN(nn.Module):
    def __init__(self, input_size):
        super(DNN, self).__init__()
        self.fc1 = nn.Linear(input_size, neuron1)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
        self.fc2 = nn.Linear(neuron1, neuron2)
        self.fc3 = nn.Linear(neuron2, neuron3)
        self.fc4 = nn.Linear(neuron3, neuron4)
        self.fc5 = nn.Linear(neuron4, neuron5)
        self.fc6 = nn.Linear(neuron5, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.relu(self.fc4(x))
        x = self.dropout(x)
        x = self.relu(self.fc5(x))
        x = self.dropout(x)
        x = self.sigmoid(self.fc6(x))
        return x

model = DNN(X_train_tensor.shape[1]).to(device)
criterion = nn.BCELoss(reduction='none')
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Create DataLoader for training data
train_dataset = SignalBackgroundDataset(X_train_tensor, y_train_tensor, weights_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = SignalBackgroundDataset(X_val_tensor, y_val_tensor, torch.tensor(weights_val, dtype=torch.float32).to(device))
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

num_epochs = 50
patience = 6  # How many epochs to wait after last time validation loss improved.
best_val_loss = np.inf  # Initialize best validation loss to infinity
epochs_no_improve = 0  # Counter for epochs with no improvement

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_predictions, total_predictions = 0, 0

    for inputs, targets, batch_weights in train_loader:
        inputs, targets, batch_weights = inputs.to(device), targets.to(device), batch_weights.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), targets)
        loss = (loss * batch_weights).mean()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # binary classification for accuracy calculation
        preds = outputs.squeeze().round()
        correct_predictions += (preds == targets).sum().item()
        total_predictions += targets.size(0)

    train_accuracy = correct_predictions / total_predictions
    avg_training_loss = running_loss / len(train_loader)

    # Validation phase
    model.eval()
    val_running_loss = 0.0
    correct_predictions, total_predictions = 0, 0

    with torch.no_grad():
        for inputs, targets, batch_weights in val_loader:
            inputs, targets, batch_weights = inputs.to(device), targets.to(device), batch_weights.to(device)

            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), targets)
            loss = (loss * batch_weights).mean()

            val_running_loss += loss.item()

            preds = outputs.squeeze().round()
            correct_predictions += (preds == targets).sum().item()
            total_predictions += targets.size(0)

    val_accuracy = correct_predictions / total_predictions
    avg_val_loss = val_running_loss / len(val_loader)

#     # Log metrics to W&B
#     wandb.log({
#         'epoch': epoch,
#         'training_loss': avg_training_loss,
#         'validation_loss': avg_val_loss,
#         'training_accuracy': train_accuracy,
#         'validation_accuracy': val_accuracy
#     })

    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {avg_training_loss:.4e}, Validation Loss: {avg_val_loss:.4e}, Training Accuracy: {train_accuracy:.4e}, Validation Accuracy: {val_accuracy:.4e}")

    # Check if the validation loss improved
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_no_improve = 0
        # Save the model
        # torch.save(model.state_dict(), 'best_model.pth')
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
            break  # Early stopping


# Evaluate on the validation set
model.eval()
val_predictions = []
with torch.no_grad():
    for inputs, targets, _ in DataLoader(SignalBackgroundDataset(X_val_tensor, y_val_tensor, torch.tensor(weights_val, dtype=torch.float32)), batch_size=batch_size, shuffle=False):
        inputs = inputs.to(device)
        outputs = model(inputs).squeeze()
        val_predictions.extend(outputs.cpu().numpy())
val_predictions = np.array(val_predictions)

# Compute ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_val, val_predictions, sample_weight=weights_val)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(22, 10))
plt.subplot(121)
plt.plot(fpr, tpr, label='BDT (area = {:.5f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], linestyle='--', label='Random classifier')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)

plt.subplot(122)
plt.plot(tpr, 1/fpr, color='black', lw=1, label='ROC curve (area = %0.5f)' % roc_auc)
plt.xlabel('Signal efficiency (TPR)')
plt.ylabel('Inverse backround efficiency (1/FPR)')
plt.yscale('log')
plt.legend()
plt.grid(True)
plt.show()

print(f'Pytorch Time: {(time.time() - start)/60} min')
# Out:
# Epoch 1/50, Training Loss: 1.3271e-05, Validation Loss: 6.8976e-06, Training Accuracy: 9.3166e-01, Validation Accuracy: 9.3499e-01
# Epoch 2/50, Training Loss: 1.0758e-05, Validation Loss: 8.9807e-06, Training Accuracy: 9.4464e-01, Validation Accuracy: 9.2638e-01
# Epoch 3/50, Training Loss: 9.3393e-06, Validation Loss: 6.2364e-06, Training Accuracy: 9.4466e-01, Validation Accuracy: 9.4467e-01
# Epoch 4/50, Training Loss: 1.0008e-05, Validation Loss: 7.7536e-06, Training Accuracy: 9.4304e-01, Validation Accuracy: 9.4690e-01
# Epoch 5/50, Training Loss: 7.7759e-06, Validation Loss: 6.5818e-06, Training Accuracy: 9.5319e-01, Validation Accuracy: 9.5703e-01
# Epoch 6/50, Training Loss: 8.1153e-06, Validation Loss: 6.1538e-06, Training Accuracy: 9.5061e-01, Validation Accuracy: 9.4335e-01
# Epoch 7/50, Training Loss: 6.4432e-06, Validation Loss: 6.2637e-06, Training Accuracy: 9.5423e-01, Validation Accuracy: 9.5537e-01
# Epoch 8/50, Training Loss: 8.3602e-06, Validation Loss: 5.9459e-06, Training Accuracy: 9.5466e-01, Validation Accuracy: 9.6531e-01
# Epoch 9/50, Training Loss: 6.4083e-06, Validation Loss: 6.7875e-06, Training Accuracy: 9.5386e-01, Validation Accuracy: 9.6480e-01
# Epoch 10/50, Training Loss: 6.6853e-06, Validation Loss: 6.7396e-06, Training Accuracy: 9.5699e-01, Validation Accuracy: 9.6645e-01
# Epoch 11/50, Training Loss: 5.7409e-06, Validation Loss: 5.8880e-06, Training Accuracy: 9.5601e-01, Validation Accuracy: 9.6354e-01
# Epoch 12/50, Training Loss: 5.6935e-06, Validation Loss: 6.6002e-06, Training Accuracy: 9.5851e-01, Validation Accuracy: 9.3419e-01
# Epoch 13/50, Training Loss: 5.5121e-06, Validation Loss: 5.6267e-06, Training Accuracy: 9.5869e-01, Validation Accuracy: 9.6324e-01
# Epoch 14/50, Training Loss: 5.4728e-06, Validation Loss: 5.7607e-06, Training Accuracy: 9.5900e-01, Validation Accuracy: 9.6874e-01
# Epoch 15/50, Training Loss: 5.1714e-06, Validation Loss: 6.2050e-06, Training Accuracy: 9.6017e-01, Validation Accuracy: 9.5648e-01
# Epoch 16/50, Training Loss: 4.9550e-06, Validation Loss: 5.8676e-06, Training Accuracy: 9.6097e-01, Validation Accuracy: 9.6290e-01
# Epoch 17/50, Training Loss: 5.3042e-06, Validation Loss: 5.5241e-06, Training Accuracy: 9.6208e-01, Validation Accuracy: 9.6313e-01
# Epoch 18/50, Training Loss: 4.6621e-06, Validation Loss: 7.4982e-06, Training Accuracy: 9.6462e-01, Validation Accuracy: 9.5562e-01
# Epoch 19/50, Training Loss: 4.8683e-06, Validation Loss: 5.8983e-06, Training Accuracy: 9.6305e-01, Validation Accuracy: 9.6357e-01
# Epoch 20/50, Training Loss: 5.3349e-06, Validation Loss: 5.9077e-06, Training Accuracy: 9.6213e-01, Validation Accuracy: 9.7089e-01
# Epoch 21/50, Training Loss: 4.6757e-06, Validation Loss: 6.9843e-06, Training Accuracy: 9.6285e-01, Validation Accuracy: 9.6723e-01
# Epoch 22/50, Training Loss: 4.3973e-06, Validation Loss: 5.6516e-06, Training Accuracy: 9.6438e-01, Validation Accuracy: 9.6876e-01
# Epoch 23/50, Training Loss: 4.5615e-06, Validation Loss: 6.0907e-06, Training Accuracy: 9.6359e-01, Validation Accuracy: 9.7350e-01
# Early stopping triggered after 23 epochs.
# /tmp/ipykernel_460/1773607920.py:206: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr, 1/fpr, color='black', lw=1, label='ROC curve (area = %0.5f)' % roc_auc)
# Pytorch Time: 30.00763546625773 min

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# Model configuration
input_shape = X_train.shape[1]  # Assuming X_train is a 2D array; adjust accordingly
learning_rate = 0.0005
batch_size = 64
epochs = 100  # Set a maximum number of epochs
dropout_rate = 0  # No dropout in this case
neurons = [256, 1024, 512, 128, 32]  # Neurons in each layer

# Define the model
model = Sequential()
model.add(Dense(neurons[0], input_shape=(input_shape,), activation='relu'))
for neuron in neurons[1:]:
    model.add(Dense(neuron, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Assuming binary classification; adjust the activation and units as necessary

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train,
                    sample_weight=weights_train, 
                    validation_data=(X_val, y_val, weights_val), 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[early_stopping],
                    verbose=1)
# Out:
# Epoch 1/100
# 13667/13673 [============================>.] - ETA: 0s - loss: 1.2967e-05 - accuracy: 0.9238WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 259s 19ms/step - loss: 1.2964e-05 - accuracy: 0.9238 - val_loss: 7.7934e-06 - val_accuracy: 0.9539
# Epoch 2/100
# 13669/13673 [============================>.] - ETA: 0s - loss: 1.4803e-05 - accuracy: 0.9381WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 1.4803e-05 - accuracy: 0.9381 - val_loss: 6.9543e-06 - val_accuracy: 0.9540
# Epoch 3/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 1.1324e-05 - accuracy: 0.9444WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 1.1323e-05 - accuracy: 0.9444 - val_loss: 1.9982e-05 - val_accuracy: 0.8609
# Epoch 4/100
# 13671/13673 [============================>.] - ETA: 0s - loss: 8.5503e-06 - accuracy: 0.9433WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 8.5499e-06 - accuracy: 0.9433 - val_loss: 6.0221e-06 - val_accuracy: 0.9511
# Epoch 5/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 7.7872e-06 - accuracy: 0.9452WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 7.7862e-06 - accuracy: 0.9452 - val_loss: 6.4419e-06 - val_accuracy: 0.9540
# Epoch 6/100
# 13669/13673 [============================>.] - ETA: 0s - loss: 6.9923e-06 - accuracy: 0.9523WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 6.9909e-06 - accuracy: 0.9523 - val_loss: 5.8799e-06 - val_accuracy: 0.9491
# Epoch 7/100
# 13665/13673 [============================>.] - ETA: 0s - loss: 8.0705e-06 - accuracy: 0.9516WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 87s 6ms/step - loss: 8.0718e-06 - accuracy: 0.9516 - val_loss: 6.2453e-06 - val_accuracy: 0.9506
# Epoch 8/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 7.4308e-06 - accuracy: 0.9549WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 7.4301e-06 - accuracy: 0.9549 - val_loss: 6.2129e-06 - val_accuracy: 0.9640
# Epoch 9/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 6.0451e-06 - accuracy: 0.9545WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 6.0443e-06 - accuracy: 0.9545 - val_loss: 5.7231e-06 - val_accuracy: 0.9466
# Epoch 10/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 5.9119e-06 - accuracy: 0.9566WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 5.9113e-06 - accuracy: 0.9566 - val_loss: 5.6233e-06 - val_accuracy: 0.9521
# Epoch 11/100
# 13664/13673 [============================>.] - ETA: 0s - loss: 5.7099e-06 - accuracy: 0.9573WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 93s 7ms/step - loss: 5.7102e-06 - accuracy: 0.9573 - val_loss: 5.4201e-06 - val_accuracy: 0.9693
# Epoch 12/100
# 13671/13673 [============================>.] - ETA: 0s - loss: 7.1125e-06 - accuracy: 0.9583WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 88s 6ms/step - loss: 7.1122e-06 - accuracy: 0.9583 - val_loss: 5.5484e-06 - val_accuracy: 0.9617
# Epoch 13/100
# 13671/13673 [============================>.] - ETA: 0s - loss: 5.4050e-06 - accuracy: 0.9570WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 94s 7ms/step - loss: 5.4047e-06 - accuracy: 0.9570 - val_loss: 6.2269e-06 - val_accuracy: 0.9391
# Epoch 14/100
# 13669/13673 [============================>.] - ETA: 0s - loss: 5.2856e-06 - accuracy: 0.9590WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 88s 6ms/step - loss: 5.2862e-06 - accuracy: 0.9590 - val_loss: 5.5868e-06 - val_accuracy: 0.9638
# Epoch 15/100
# 13664/13673 [============================>.] - ETA: 0s - loss: 5.1935e-06 - accuracy: 0.9579WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 5.1941e-06 - accuracy: 0.9579 - val_loss: 5.1826e-06 - val_accuracy: 0.9559
# Epoch 16/100
# 13673/13673 [==============================] - ETA: 0s - loss: 4.9685e-06 - accuracy: 0.9597WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 88s 6ms/step - loss: 4.9685e-06 - accuracy: 0.9597 - val_loss: 5.3440e-06 - val_accuracy: 0.9685
# Epoch 17/100
# 13668/13673 [============================>.] - ETA: 0s - loss: 4.9421e-06 - accuracy: 0.9628WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 87s 6ms/step - loss: 4.9439e-06 - accuracy: 0.9628 - val_loss: 5.3528e-06 - val_accuracy: 0.9563
# Epoch 18/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 4.9887e-06 - accuracy: 0.9628WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 89s 7ms/step - loss: 4.9881e-06 - accuracy: 0.9628 - val_loss: 5.6669e-06 - val_accuracy: 0.9706
# Epoch 19/100
# 13669/13673 [============================>.] - ETA: 0s - loss: 4.6752e-06 - accuracy: 0.9638WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 4.6752e-06 - accuracy: 0.9638 - val_loss: 5.2828e-06 - val_accuracy: 0.9651
# Epoch 20/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 4.5369e-06 - accuracy: 0.9631WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 4.5366e-06 - accuracy: 0.9630 - val_loss: 5.4454e-06 - val_accuracy: 0.9568
# Epoch 21/100
# 13668/13673 [============================>.] - ETA: 0s - loss: 4.4054e-06 - accuracy: 0.9649WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 4.4057e-06 - accuracy: 0.9649 - val_loss: 5.3113e-06 - val_accuracy: 0.9658
# Epoch 22/100
# 13667/13673 [============================>.] - ETA: 0s - loss: 4.5330e-06 - accuracy: 0.9644WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 4.5333e-06 - accuracy: 0.9644 - val_loss: 7.0184e-06 - val_accuracy: 0.9408
# Epoch 23/100
# 13667/13673 [============================>.] - ETA: 0s - loss: 4.3193e-06 - accuracy: 0.9657WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 88s 6ms/step - loss: 4.3244e-06 - accuracy: 0.9656 - val_loss: 5.1231e-06 - val_accuracy: 0.9631
# Epoch 24/100
# 13666/13673 [============================>.] - ETA: 0s - loss: 4.2797e-06 - accuracy: 0.9653WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 87s 6ms/step - loss: 4.2796e-06 - accuracy: 0.9653 - val_loss: 5.0722e-06 - val_accuracy: 0.9607
# Epoch 25/100
# 13665/13673 [============================>.] - ETA: 0s - loss: 4.1968e-06 - accuracy: 0.9672WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 4.1960e-06 - accuracy: 0.9672 - val_loss: 5.2554e-06 - val_accuracy: 0.9644
# Epoch 26/100
# 13668/13673 [============================>.] - ETA: 0s - loss: 4.0824e-06 - accuracy: 0.9677WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 4.0817e-06 - accuracy: 0.9677 - val_loss: 5.0595e-06 - val_accuracy: 0.9634
# Epoch 27/100
# 13671/13673 [============================>.] - ETA: 0s - loss: 3.9952e-06 - accuracy: 0.9670WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 92s 7ms/step - loss: 3.9949e-06 - accuracy: 0.9670 - val_loss: 5.6097e-06 - val_accuracy: 0.9743
# Epoch 28/100
# 13669/13673 [============================>.] - ETA: 0s - loss: 3.9161e-06 - accuracy: 0.9668WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 88s 6ms/step - loss: 3.9157e-06 - accuracy: 0.9668 - val_loss: 5.3784e-06 - val_accuracy: 0.9632
# Epoch 29/100
# 13666/13673 [============================>.] - ETA: 0s - loss: 3.9600e-06 - accuracy: 0.9674WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 87s 6ms/step - loss: 3.9598e-06 - accuracy: 0.9674 - val_loss: 4.9963e-06 - val_accuracy: 0.9616
# Epoch 30/100
# 13669/13673 [============================>.] - ETA: 0s - loss: 4.0878e-06 - accuracy: 0.9686WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 88s 6ms/step - loss: 4.0872e-06 - accuracy: 0.9686 - val_loss: 5.1827e-06 - val_accuracy: 0.9674
# Epoch 31/100
# 13669/13673 [============================>.] - ETA: 0s - loss: 3.7590e-06 - accuracy: 0.9686WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 3.7585e-06 - accuracy: 0.9686 - val_loss: 5.2252e-06 - val_accuracy: 0.9750
# Epoch 32/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 3.6601e-06 - accuracy: 0.9700WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 87s 6ms/step - loss: 3.6605e-06 - accuracy: 0.9700 - val_loss: 5.1456e-06 - val_accuracy: 0.9741
# Epoch 33/100
# 13666/13673 [============================>.] - ETA: 0s - loss: 3.6540e-06 - accuracy: 0.9704WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 88s 6ms/step - loss: 3.6530e-06 - accuracy: 0.9704 - val_loss: 5.7179e-06 - val_accuracy: 0.9698
# Epoch 34/100
# 13672/13673 [============================>.] - ETA: 0s - loss: 3.5395e-06 - accuracy: 0.9707WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 87s 6ms/step - loss: 3.5394e-06 - accuracy: 0.9707 - val_loss: 5.4919e-06 - val_accuracy: 0.9735
# Epoch 35/100
# 13672/13673 [============================>.] - ETA: 0s - loss: 3.5399e-06 - accuracy: 0.9714WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 87s 6ms/step - loss: 3.5399e-06 - accuracy: 0.9714 - val_loss: 5.9017e-06 - val_accuracy: 0.9778
# Epoch 36/100
# 13669/13673 [============================>.] - ETA: 0s - loss: 3.4844e-06 - accuracy: 0.9713WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 3.4852e-06 - accuracy: 0.9713 - val_loss: 6.0581e-06 - val_accuracy: 0.9712
# Epoch 37/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 3.3375e-06 - accuracy: 0.9727WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 3.3379e-06 - accuracy: 0.9727 - val_loss: 5.5219e-06 - val_accuracy: 0.9692
# Epoch 38/100
# 13668/13673 [============================>.] - ETA: 0s - loss: 3.4059e-06 - accuracy: 0.9728WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 3.4051e-06 - accuracy: 0.9729 - val_loss: 4.9695e-06 - val_accuracy: 0.9663
# Epoch 39/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 3.3116e-06 - accuracy: 0.9739WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 3.3119e-06 - accuracy: 0.9739 - val_loss: 5.3589e-06 - val_accuracy: 0.9657
# Epoch 40/100
# 13665/13673 [============================>.] - ETA: 0s - loss: 3.2594e-06 - accuracy: 0.9735WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 87s 6ms/step - loss: 3.2649e-06 - accuracy: 0.9735 - val_loss: 5.2267e-06 - val_accuracy: 0.9590
# Epoch 41/100
# 13671/13673 [============================>.] - ETA: 0s - loss: 3.1997e-06 - accuracy: 0.9730WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 3.1995e-06 - accuracy: 0.9730 - val_loss: 5.7552e-06 - val_accuracy: 0.9707
# Epoch 42/100
# 13670/13673 [============================>.] - ETA: 0s - loss: 3.2305e-06 - accuracy: 0.9732WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 85s 6ms/step - loss: 3.2303e-06 - accuracy: 0.9732 - val_loss: 6.0605e-06 - val_accuracy: 0.9752
# Epoch 43/100
# 13666/13673 [============================>.] - ETA: 0s - loss: 3.2282e-06 - accuracy: 0.9732WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 3.2279e-06 - accuracy: 0.9732 - val_loss: 5.6217e-06 - val_accuracy: 0.9730
# Epoch 44/100
# 13664/13673 [============================>.] - ETA: 0s - loss: 3.0833e-06 - accuracy: 0.9744WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 86s 6ms/step - loss: 3.0825e-06 - accuracy: 0.9744 - val_loss: 5.9821e-06 - val_accuracy: 0.9763
# Epoch 45/100
# 13672/13673 [============================>.] - ETA: 0s - loss: 3.1130e-06 - accuracy: 0.9738WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 87s 6ms/step - loss: 3.1130e-06 - accuracy: 0.9738 - val_loss: 5.4951e-06 - val_accuracy: 0.9724
# Epoch 46/100
# 13667/13673 [============================>.] - ETA: 0s - loss: 3.0315e-06 - accuracy: 0.9749WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 90s 7ms/step - loss: 3.0316e-06 - accuracy: 0.9749 - val_loss: 6.2124e-06 - val_accuracy: 0.9761
# Epoch 47/100
# 13668/13673 [============================>.] - ETA: 0s - loss: 2.9367e-06 - accuracy: 0.9755WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 13673/13673 [==============================] - 90s 7ms/step - loss: 2.9368e-06 - accuracy: 0.9755 - val_loss: 5.5354e-06 - val_accuracy: 0.9742
# Epoch 48/100
# 13668/13673 [============================>.] - ETA: 0s - loss: 2.9018e-06 - accuracy: 0.9758WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# Restoring model weights from the end of the best epoch: 38.
# 13673/13673 [==============================] - 93s 7ms/step - loss: 2.9131e-06 - accuracy: 0.9758 - val_loss: 5.5020e-06 - val_accuracy: 0.9715
# Epoch 48: early stopping

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Make predictions on the validation set
y_val_pred = model.predict(X_val).ravel()  # Flatten the predictions if necessary

# Calculate the ROC curve and AUC score, incorporating weights
fpr, tpr, thresholds = roc_curve(y_val, y_val_pred, sample_weight=weights_val)
roc_auc = auc(fpr, tpr)

# Plotting ROC Curve
plt.figure(figsize=(22, 10))
plt.subplot(121)
plt.plot(fpr, tpr, label='DNN (area = {:.5f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], linestyle='--', label='Random classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)

plt.subplot(122)
plt.plot(tpr, 1/fpr, color='black', lw=1, label='ROC curve (area = %0.5f)' % roc_auc)
plt.xlabel('Signal efficiency (TPR)')
plt.ylabel('Inverse background efficiency (1/FPR)')
plt.yscale('log')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 11719/11719 [==============================] - 22s 2ms/step
# /tmp/ipykernel_460/1418850586.py:23: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr, 1/fpr, color='black', lw=1, label='ROC curve (area = %0.5f)' % roc_auc)
