# %%
import uproot, ROOT, glob, os, sys, random
import matplotlib.pyplot as plt
import numpy as np
import awkward as ak
from sklearn.metrics import roc_curve, roc_auc_score, auc
from tqdm import tqdm
import pandas as pd
from xgboost import XGBClassifier

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split


# Set up plot defaults
# import matplotlib as plt

path = '/global/homes/a/agarabag/pscratch/ditdau_samples/'

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = os.environ['SLURM_LOCALID']
if torch.cuda.is_available():
    # device = torch.device("cuda")
    print("Running on GPU with CUDA.")
else:
    # device = torch.device("cpu")
    print("Running on CPU.")
# Out:
# Running on GPU with CUDA.

# %%
branches = ['ditau_pt', 'n_subjets', 'IsTruthHadronic', 'n_tracks_lead', 'n_tracks_subl',
 'R_max_lead', 'R_max_subl', 'R_tracks_subl', 'R_isotrack', 'd0_leadtrack_lead',
 'd0_leadtrack_subl', 'f_core_lead', 'f_core_subl', 'f_subjet_subl', 'f_subjets',
 'f_isotracks', 'm_core_lead', 'm_core_subl', 'm_tracks_lead', 'm_tracks_subl',
 'n_track']

training_vars = [
    "f_core_lead", "f_core_subl", "f_subjet_subl", "f_subjets", "f_isotracks",
    "R_max_lead", "R_max_subl", "R_isotrack", "R_tracks_subl", "m_core_lead",
    "m_core_subl", "m_tracks_lead", "m_tracks_subl", "d0_leadtrack_lead",
    "d0_leadtrack_subl", "n_track", "n_tracks_lead"
]

df = pd.read_csv(path+'David_comined.csv')
df = df[6:] # get rid of jz0 and jz1
df = df[df.f_core_subl != -999] # get rid of outlier
df['weight'] = df['event_weight'] * df['pT_weight']
df
# Out:
#          event_id   ditau_pt  IsTruthHadronic  f_core_lead  f_core_subl  \
# 6        36300348  200720.88                0     0.847755     0.683239
# 7        27674456  249767.81                0     0.809443     0.844066
# 8        45574018  209212.66                0     0.855507     0.764981
# 9        42745976  215885.73                0     0.963799     0.667000
# 10       40522366  250142.16                0     0.728881     0.689589
# ...           ...        ...              ...          ...          ...
# 1250003  31163332  526071.20                1     0.910397     0.969296
# 1250004  30334126  336502.47                1     0.915086     0.163371
# 1250005  30541837  361832.78                1     0.921741     0.790117
# 1250006  30665541  267720.94                1     0.791846     0.778316
# 1250007  30667209  410118.97                1     0.852904     0.970131
#
#          f_subjet_subl  f_subjets  f_isotracks  R_max_lead  R_max_subl  ...  \
# 6             0.084422   0.555999     0.014591    0.027558    0.149601  ...
# 7             0.247756   0.625814     0.005726    0.182669    0.010000  ...
# 8             0.295278   0.669263     0.003218    0.060898    0.046829  ...
# 9             0.252668   0.700827     0.008621    0.120004    0.182444  ...
# 10            0.396467   0.812390     0.003817    0.194865    0.033817  ...
# ...                ...        ...          ...         ...         ...  ...
# 1250003       0.104997   0.943490     0.000000    0.015913    0.023469  ...
# 1250004       0.118368   0.814084     0.003424    0.013215    0.022163  ...
# 1250005       0.321459   0.791638     0.007923    0.008872    0.035717  ...
# 1250006       0.255994   0.886948     0.003313    0.014343    0.010908  ...
# 1250007       0.218640   0.924706     0.000000    0.007117    0.017163  ...
#
#          d0_leadtrack_subl  n_track  n_tracks_lead  n_tracks_subl  n_subjets  \
# 6                 0.022509        5              1              3          3
# 7                -0.014537        6              3              1          4
# 8                -0.036782        4              1              3          2
# 9                 0.000000       12              3              1          5
# 10               -0.003847        4              3              1          2
# ...                    ...      ...            ...            ...        ...
# 1250003          -0.059134        4              3              1          2
# 1250004          -0.051443        5              3              1          3
# 1250005           0.030005        4              1              3          2
# 1250006          -0.053649        4              3              1          2
# 1250007          -0.005152        4              3              1          2
#
#          event_weight  bdt_score     pT_weight  label    weight
# 6        6.836578e-02   0.610205  2.444456e-04      0  0.000017
# 7        2.085233e-02   0.679975  1.223512e-04      0  0.000003
# 8        1.271062e-02   0.682694  2.444456e-04      0  0.000003
# 9        2.134600e-02   0.419487  2.444456e-04      0  0.000005
# 10       9.952256e-02   0.657240  1.223512e-04      0  0.000012
# ...               ...        ...           ...    ...       ...
# 1250003  2.144722e-10   0.799701  4.662652e+08      1  0.100001
# 1250004  2.144722e-10   0.716544  9.515616e+07      1  0.020408
# 1250005  2.144722e-10   0.747290  1.227014e+08      1  0.026316
# 1250006  2.144722e-10   0.729371  7.173202e+07      1  0.015385
# 1250007  2.144722e-10   0.753709  3.330466e+08      1  0.071429
#
# [1250001 rows x 27 columns]

# %%
df.describe()
# Out:
#            event_id      ditau_pt  IsTruthHadronic   f_core_lead  \
# count  1.250001e+06  1.250001e+06     1.250001e+06  1.250001e+06
# mean   2.073476e+08  4.314831e+05     8.599673e-02  8.598232e-01
# std    1.541140e+08  1.848540e+05     2.803593e-01  8.018174e-02
# min    1.100000e+01  2.000000e+05     0.000000e+00  7.191471e-03
# 25%    7.486472e+07  2.835506e+05     0.000000e+00  8.237005e-01
# 50%    1.900003e+08  3.872961e+05     0.000000e+00  8.742300e-01
# 75%    2.939791e+08  5.260131e+05     0.000000e+00  9.139876e-01
# max    4.930031e+08  9.999968e+05     1.000000e+00  9.975535e-01
#
#         f_core_subl  f_subjet_subl     f_subjets   f_isotracks    R_max_lead  \
# count  1.250001e+06   1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06
# mean   4.351379e-01   6.459976e-02  8.185769e-01  1.535391e-02  8.801527e-02
# std    2.565048e-01   7.808390e-02  9.088417e-02  5.143370e-02  6.308150e-02
# min    2.094379e-04   2.818542e-03  9.065603e-02  0.000000e+00  1.995845e-05
# 25%    2.080576e-01   2.565938e-02  7.623764e-01  4.393903e-03  2.783664e-02
# 50%    4.272147e-01   3.605864e-02  8.344137e-01  1.042412e-02  7.588327e-02
# 75%    6.306292e-01   5.891509e-02  8.880830e-01  1.992001e-02  1.476200e-01
# max    1.000000e+00   5.146357e-01  1.067907e+00  3.191106e+01  2.000000e-01
#
#          R_max_subl  ...  d0_leadtrack_subl       n_track  n_tracks_lead  \
# count  1.250001e+06  ...       1.250001e+06  1.250001e+06   1.250001e+06
# mean   1.161825e-01  ...      -2.685822e-04  4.818627e+00   2.784576e+00
# std    5.708317e-02  ...       8.296457e-02  1.882580e+00   6.200327e-01
# min    5.141489e-05  ...      -1.015759e+00  4.000000e+00   1.000000e+00
# 25%    7.045868e-02  ...       0.000000e+00  4.000000e+00   3.000000e+00
# 50%    1.230879e-01  ...       0.000000e+00  4.000000e+00   3.000000e+00
# 75%    1.665299e-01  ...       0.000000e+00  5.000000e+00   3.000000e+00
# max    1.999999e-01  ...       1.017063e+00  4.800000e+01   3.000000e+00
#
#        n_tracks_subl     n_subjets  event_weight     bdt_score     pT_weight  \
# count   1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06
# mean    1.215424e+00  2.453793e+00  2.448417e-04  5.061150e-01  1.463637e+05
# std     6.200327e-01  8.112378e-01  1.728348e-03  1.070053e-01  1.595557e+07
# min     1.000000e+00  2.000000e+00  5.141540e-16  2.653651e-01  1.223512e-04
# 25%     1.000000e+00  2.000000e+00  5.266416e-06  4.261238e-01  1.503699e-02
# 50%     1.000000e+00  2.000000e+00  2.586703e-05  4.895093e-01  3.608175e-01
# 75%     1.000000e+00  3.000000e+00  2.414404e-04  5.648352e-01  5.069307e+00
# max     3.000000e+00  1.600000e+01  1.437270e+00  8.212081e-01  4.662652e+09
#
#               label        weight
# count  1.250001e+06  1.250001e+06
# mean   8.598953e-02  9.248986e-05
# std    2.803487e-01  3.454206e-03
# min    0.000000e+00  7.057462e-20
# 25%    0.000000e+00  3.004970e-06
# 50%    0.000000e+00  1.732888e-05
# 75%    0.000000e+00  4.427668e-05
# max    1.000000e+00  1.000032e+00
#
# [8 rows x 27 columns]

# %%
from sklearn.preprocessing import StandardScaler

# normalize the data
scaler = StandardScaler()

df[training_vars] = scaler.fit_transform(df[training_vars])

df.describe()
# Out:
#            event_id      ditau_pt  IsTruthHadronic   f_core_lead  \
# count  1.250001e+06  1.250001e+06     1.250001e+06  1.250001e+06
# mean   2.073476e+08  4.314831e+05     8.599673e-02 -9.371426e-16
# std    1.541140e+08  1.848540e+05     2.803593e-01  1.000000e+00
# min    1.100000e+01  2.000000e+05     0.000000e+00 -1.063374e+01
# 25%    7.486472e+07  2.835506e+05     0.000000e+00 -4.505100e-01
# 50%    1.900003e+08  3.872961e+05     0.000000e+00  1.796774e-01
# 75%    2.939791e+08  5.260131e+05     0.000000e+00  6.755212e-01
# max    4.930031e+08  9.999968e+05     1.000000e+00  1.717728e+00
#
#         f_core_subl  f_subjet_subl     f_subjets   f_isotracks    R_max_lead  \
# count  1.250001e+06   1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06
# mean   1.455190e-18   5.529723e-17  1.698935e-16  1.155057e-16  6.912154e-17
# std    1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.695597e+00  -7.912161e-01 -8.009328e+00 -2.985186e-01 -1.394947e+00
# 25%   -8.852872e-01  -4.986994e-01 -6.183751e-01 -2.130901e-01 -9.539827e-01
# 50%   -3.088883e-02  -3.655187e-01  1.742528e-01 -9.584754e-02 -1.923227e-01
# 75%    7.621356e-01  -7.280212e-02  7.647777e-01  8.877638e-02  9.448846e-01
# max    2.202152e+00   5.763494e+00  2.743385e+00  6.201327e+02  1.775239e+00
#
#          R_max_subl  ...  d0_leadtrack_subl       n_track  n_tracks_lead  \
# count  1.250001e+06  ...       1.250001e+06  1.250001e+06   1.250001e+06
# mean  -9.014904e-16  ...      -7.241846e-18  2.011119e-16   1.513398e-16
# std    1.000000e+00  ...       1.000000e+00  1.000000e+00   1.000000e+00
# min   -2.034420e+00  ...      -1.224005e+01 -4.348431e-01  -2.878198e+00
# 25%   -8.010043e-01  ...       3.237313e-03 -4.348431e-01   3.474396e-01
# 50%    1.209699e-01  ...       3.237313e-03 -4.348431e-01   3.474396e-01
# 75%    8.820007e-01  ...       3.237313e-03  9.634306e-02   3.474396e-01
# max    1.468338e+00  ...       1.226225e+01  2.293735e+01   3.474396e-01
#
#        n_tracks_subl     n_subjets  event_weight     bdt_score     pT_weight  \
# count   1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06  1.250001e+06
# mean    1.215424e+00  2.453793e+00  2.448417e-04  5.061150e-01  1.463637e+05
# std     6.200327e-01  8.112378e-01  1.728348e-03  1.070053e-01  1.595557e+07
# min     1.000000e+00  2.000000e+00  5.141540e-16  2.653651e-01  1.223512e-04
# 25%     1.000000e+00  2.000000e+00  5.266416e-06  4.261238e-01  1.503699e-02
# 50%     1.000000e+00  2.000000e+00  2.586703e-05  4.895093e-01  3.608175e-01
# 75%     1.000000e+00  3.000000e+00  2.414404e-04  5.648352e-01  5.069307e+00
# max     3.000000e+00  1.600000e+01  1.437270e+00  8.212081e-01  4.662652e+09
#
#               label        weight
# count  1.250001e+06  1.250001e+06
# mean   8.598953e-02  9.248986e-05
# std    2.803487e-01  3.454206e-03
# min    0.000000e+00  7.057462e-20
# 25%    0.000000e+00  3.004970e-06
# 50%    0.000000e+00  1.732888e-05
# 75%    0.000000e+00  4.427668e-05
# max    1.000000e+00  1.000032e+00
#
# [8 rows x 27 columns]

# %%
# Plot the Transformed Training Vars
signal = df[df.label==1]
bkg = df[df.label==0]

plt.figure(figsize=(30, 24))
def hist(variable, plot_num):
    plt.subplot(4, 5, plot_num)
    bin = 50
    plt.hist(bkg[variable], bins=bin, histtype='step', linewidth=1, weights=bkg['weight'], label=f'qcd μ:{np.mean(bkg[variable]):.2f}, σ:{np.std(bkg[variable]):.2f}')
    plt.hist(signal[variable], bins=bin, histtype='step', linewidth=1, weights=signal['weight'], label=f'signal μ:{np.mean(signal[variable]):.2f}, σ:{np.std(signal[variable]):.2f}')
    plt.xlabel(variable)
    plt.yscale('log')
    plt.legend()
    plt.grid(True)

for i, label in tqdm(enumerate(training_vars, 1)):
    hist(label, i)
# Out:
# 17it [00:00, 27.77it/s]

# %%
if not torch.cuda.is_available():
    device = torch.device('cpu')
else:
    device = torch.device('cuda:0')
    torch.cuda.set_device(device)


learning_rate = 1e-4
batch_size = 512
dropout = 0.1
neuron1 = 256
neuron2 = 1024
neuron3 = 128
neuron4 = 128

features = df[training_vars].values
labels = df['label'].values
weights = df['weight'].values

# Split the dataset into training and validation sets
X_train, X_val, y_train, y_val, weights_train, weights_val = train_test_split(
    features, labels, weights, test_size=0.2, random_state=55)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Convert to PyTorch tensors and move to device
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
weights_train_tensor = torch.tensor(weights_train, dtype=torch.float32).to(device)

X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device)

# Define the Dataset
class SignalBackgroundDataset(Dataset):
    def __init__(self, features, labels, weights):
        self.features = features
        self.labels = labels
        self.weights = weights

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx], self.weights[idx]

# Define the DNN model with dropout
class DNN(nn.Module):
    def __init__(self, input_size):
        super(DNN, self).__init__()
        self.fc1 = nn.Linear(input_size, neuron1)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
        self.fc2 = nn.Linear(neuron1, neuron2)
        self.fc3 = nn.Linear(neuron2, neuron3)
        self.fc4 = nn.Linear(neuron3, neuron4)
        self.fc5 = nn.Linear(neuron4, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.relu(self.fc4(x))
        x = self.dropout(x)
        x = self.sigmoid(self.fc5(x))
        return x


model = DNN(X_train_tensor.shape[1]).to(device)
criterion = nn.BCELoss(reduction='none')
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Create DataLoader for training data
train_dataset = SignalBackgroundDataset(X_train_tensor, y_train_tensor, weights_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = SignalBackgroundDataset(X_val_tensor, y_val_tensor, torch.tensor(weights_val, dtype=torch.float32).to(device))
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

num_epochs = 30
patience = 6  # How many epochs to wait after last time validation loss improved.
best_val_loss = np.inf  # Initialize best validation loss to infinity
epochs_no_improve = 0  # Counter for epochs with no improvement

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_predictions, total_predictions = 0, 0

    for inputs, targets, batch_weights in train_loader:
        inputs, targets, batch_weights = inputs.to(device), targets.to(device), batch_weights.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), targets)
        loss = (loss * batch_weights).mean()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # binary classification for accuracy calculation
        preds = outputs.squeeze().round()
        correct_predictions += (preds == targets).sum().item()
        total_predictions += targets.size(0)

    train_accuracy = correct_predictions / total_predictions
    avg_training_loss = running_loss / len(train_loader)

    # Validation phase
    model.eval()
    val_running_loss = 0.0
    correct_predictions, total_predictions = 0, 0

    with torch.no_grad():
        for inputs, targets, batch_weights in val_loader:
            inputs, targets, batch_weights = inputs.to(device), targets.to(device), batch_weights.to(device)

            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), targets)
            loss = (loss * batch_weights).mean()

            val_running_loss += loss.item()

            preds = outputs.squeeze().round()
            correct_predictions += (preds == targets).sum().item()
            total_predictions += targets.size(0)

    val_accuracy = correct_predictions / total_predictions
    avg_val_loss = val_running_loss / len(val_loader)

#     # Log metrics to W&B
#     wandb.log({
#         'epoch': epoch,
#         'training_loss': avg_training_loss,
#         'validation_loss': avg_val_loss,
#         'training_accuracy': train_accuracy,
#         'validation_accuracy': val_accuracy
#     })

    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {avg_training_loss:.4e}, Validation Loss: {avg_val_loss:.4e}, Training Accuracy: {train_accuracy:.4e}, Validation Accuracy: {val_accuracy:.4e}")

    # Check if the validation loss improved
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_no_improve = 0
        # Save the model
        # torch.save(model.state_dict(), 'best_model.pth')
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
            break  # Early stopping


# Evaluate on the validation set
model.eval()
val_predictions = []
with torch.no_grad():
    for inputs, targets, _ in DataLoader(SignalBackgroundDataset(X_val_tensor, y_val_tensor, torch.tensor(weights_val, dtype=torch.float32)), batch_size=batch_size, shuffle=False):
        inputs = inputs.to(device)
        outputs = model(inputs).squeeze()
        val_predictions.extend(outputs.cpu().numpy())
val_predictions = np.array(val_predictions)

# Compute ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_val, val_predictions, sample_weight=weights_val)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(22, 10))
plt.subplot(121)
plt.plot(fpr, tpr, label='BDT (area = {:.5f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], linestyle='--', label='Random classifier')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)

plt.subplot(122)
plt.plot(tpr, 1/fpr, color='black', lw=1, label='ROC curve (area = %0.5f)' % roc_auc)
plt.xlabel('Signal efficiency (TPR)')
plt.ylabel('Inverse backround efficiency (1/FPR)')
plt.yscale('log')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/30, Training Loss: 1.2661e-05, Validation Loss: 9.1775e-06, Training Accuracy: 8.9605e-01, Validation Accuracy: 9.4468e-01
# Epoch 2/30, Training Loss: 8.9464e-06, Validation Loss: 9.5929e-06, Training Accuracy: 9.3165e-01, Validation Accuracy: 9.2967e-01
# Epoch 3/30, Training Loss: 9.4097e-06, Validation Loss: 9.8007e-06, Training Accuracy: 9.2732e-01, Validation Accuracy: 9.4698e-01
# Epoch 4/30, Training Loss: 7.0370e-06, Validation Loss: 8.8672e-06, Training Accuracy: 9.3805e-01, Validation Accuracy: 9.1667e-01
# Epoch 5/30, Training Loss: 7.7660e-06, Validation Loss: 8.3796e-06, Training Accuracy: 9.3182e-01, Validation Accuracy: 9.3881e-01
# Epoch 6/30, Training Loss: 6.6608e-06, Validation Loss: 8.1570e-06, Training Accuracy: 9.4126e-01, Validation Accuracy: 9.3942e-01
# Epoch 7/30, Training Loss: 7.3043e-06, Validation Loss: 9.4572e-06, Training Accuracy: 9.4024e-01, Validation Accuracy: 9.1569e-01
# Epoch 8/30, Training Loss: 6.5162e-06, Validation Loss: 8.3109e-06, Training Accuracy: 9.4343e-01, Validation Accuracy: 9.4310e-01
# Epoch 9/30, Training Loss: 6.6449e-06, Validation Loss: 8.4637e-06, Training Accuracy: 9.4325e-01, Validation Accuracy: 9.2938e-01
# Epoch 10/30, Training Loss: 6.0896e-06, Validation Loss: 8.1661e-06, Training Accuracy: 9.4598e-01, Validation Accuracy: 9.4923e-01
# Epoch 11/30, Training Loss: 5.9913e-06, Validation Loss: 8.0245e-06, Training Accuracy: 9.4749e-01, Validation Accuracy: 9.5194e-01
# Epoch 12/30, Training Loss: 5.8473e-06, Validation Loss: 8.5574e-06, Training Accuracy: 9.5008e-01, Validation Accuracy: 9.5267e-01
# Epoch 13/30, Training Loss: 5.8312e-06, Validation Loss: 8.9219e-06, Training Accuracy: 9.5130e-01, Validation Accuracy: 9.5069e-01
# Epoch 14/30, Training Loss: 5.7214e-06, Validation Loss: 7.8722e-06, Training Accuracy: 9.5136e-01, Validation Accuracy: 9.5848e-01
# Epoch 15/30, Training Loss: 5.5436e-06, Validation Loss: 8.5047e-06, Training Accuracy: 9.5256e-01, Validation Accuracy: 9.5586e-01
# Epoch 16/30, Training Loss: 5.5523e-06, Validation Loss: 7.8177e-06, Training Accuracy: 9.5281e-01, Validation Accuracy: 9.5234e-01
# Epoch 17/30, Training Loss: 5.4089e-06, Validation Loss: 9.4718e-06, Training Accuracy: 9.5422e-01, Validation Accuracy: 9.5440e-01
# Epoch 18/30, Training Loss: 5.3626e-06, Validation Loss: 8.0143e-06, Training Accuracy: 9.5367e-01, Validation Accuracy: 9.5304e-01
# Epoch 19/30, Training Loss: 5.2895e-06, Validation Loss: 9.3649e-06, Training Accuracy: 9.5369e-01, Validation Accuracy: 9.5437e-01
# Epoch 20/30, Training Loss: 5.1085e-06, Validation Loss: 9.5644e-06, Training Accuracy: 9.5657e-01, Validation Accuracy: 9.6475e-01
# Epoch 21/30, Training Loss: 5.1879e-06, Validation Loss: 6.9037e-06, Training Accuracy: 9.5669e-01, Validation Accuracy: 9.4762e-01
# Epoch 22/30, Training Loss: 4.9923e-06, Validation Loss: 9.1733e-06, Training Accuracy: 9.5709e-01, Validation Accuracy: 9.6169e-01
# Epoch 23/30, Training Loss: 5.0499e-06, Validation Loss: 1.0996e-05, Training Accuracy: 9.5817e-01, Validation Accuracy: 9.3873e-01
# Epoch 24/30, Training Loss: 4.8893e-06, Validation Loss: 8.5784e-06, Training Accuracy: 9.5815e-01, Validation Accuracy: 9.6253e-01
# Epoch 25/30, Training Loss: 4.7813e-06, Validation Loss: 1.0293e-05, Training Accuracy: 9.6034e-01, Validation Accuracy: 9.6324e-01
# Epoch 26/30, Training Loss: 4.7068e-06, Validation Loss: 8.9323e-06, Training Accuracy: 9.5961e-01, Validation Accuracy: 9.5857e-01
# Epoch 27/30, Training Loss: 4.7247e-06, Validation Loss: 9.4015e-06, Training Accuracy: 9.6040e-01, Validation Accuracy: 9.6148e-01
# Early stopping triggered after 27 epochs.
# /tmp/ipykernel_1236496/2844120821.py:186: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr, 1/fpr, color='black', lw=1, label='ROC curve (area = %0.5f)' % roc_auc)

# %%
learning_rate = 0.0005
batch_size = 512
dropout = 0
neuron1 = 256
neuron2 = 1024
neuron3 = 512
neuron4 = 128
neuron5 = 32

# features = df[training_vars].values
# labels = df['label'].values
# weights = df['weight'].values

# # Split the dataset into training and validation sets
# X_train, X_val, y_train, y_val, weights_train, weights_val = train_test_split(
#     features, labels, weights, test_size=0.2, random_state=42)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Split the dataset into training and validation sets
df['eventID_mod'] = df['event_id'] % 10

train_loc = df['eventID_mod'] < 7 # 70%
test_loc = df['eventID_mod'] >= 7 # 30%

features, labels, weights = df[training_vars].values, df['label'].values, df['weight'].values

X_train, X_val, y_train, y_val, weights_train, weights_val = \
      features[train_loc], features[test_loc], labels[train_loc], labels[test_loc], weights[train_loc], weights[test_loc] 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Convert to PyTorch tensors and move to device
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device)
weights_train_tensor = torch.tensor(weights_train, dtype=torch.float32).to(device)

X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device)

# Define the Dataset
class SignalBackgroundDataset(Dataset):
    def __init__(self, features, labels, weights):
        self.features = features
        self.labels = labels
        self.weights = weights

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx], self.weights[idx]

# Define the DNN model with dropout
class DNN(nn.Module):
    def __init__(self, input_size):
        super(DNN, self).__init__()
        self.fc1 = nn.Linear(input_size, neuron1)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
        self.fc2 = nn.Linear(neuron1, neuron2)
        self.fc3 = nn.Linear(neuron2, neuron3)
        self.fc4 = nn.Linear(neuron3, neuron4)
        self.fc5 = nn.Linear(neuron4, neuron5)
        self.fc6 = nn.Linear(neuron5, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.relu(self.fc4(x))
        x = self.dropout(x)
        x = self.relu(self.fc5(x))
        x = self.dropout(x)
        x = self.sigmoid(self.fc6(x))
        return x

model = DNN(X_train_tensor.shape[1]).to(device)
criterion = nn.BCELoss(reduction='none')
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Create DataLoader for training data
train_dataset = SignalBackgroundDataset(X_train_tensor, y_train_tensor, weights_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = SignalBackgroundDataset(X_val_tensor, y_val_tensor, torch.tensor(weights_val, dtype=torch.float32).to(device))
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

num_epochs = 50
patience = 6  # How many epochs to wait after last time validation loss improved.
best_val_loss = np.inf  # Initialize best validation loss to infinity
epochs_no_improve = 0  # Counter for epochs with no improvement

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_predictions, total_predictions = 0, 0

    for inputs, targets, batch_weights in train_loader:
        inputs, targets, batch_weights = inputs.to(device), targets.to(device), batch_weights.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), targets)
        loss = (loss * batch_weights).mean()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # binary classification for accuracy calculation
        preds = outputs.squeeze().round()
        correct_predictions += (preds == targets).sum().item()
        total_predictions += targets.size(0)

    train_accuracy = correct_predictions / total_predictions
    avg_training_loss = running_loss / len(train_loader)

    # Validation phase
    model.eval()
    val_running_loss = 0.0
    correct_predictions, total_predictions = 0, 0

    with torch.no_grad():
        for inputs, targets, batch_weights in val_loader:
            inputs, targets, batch_weights = inputs.to(device), targets.to(device), batch_weights.to(device)

            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), targets)
            loss = (loss * batch_weights).mean()

            val_running_loss += loss.item()

            preds = outputs.squeeze().round()
            correct_predictions += (preds == targets).sum().item()
            total_predictions += targets.size(0)

    val_accuracy = correct_predictions / total_predictions
    avg_val_loss = val_running_loss / len(val_loader)

#     # Log metrics to W&B
#     wandb.log({
#         'epoch': epoch,
#         'training_loss': avg_training_loss,
#         'validation_loss': avg_val_loss,
#         'training_accuracy': train_accuracy,
#         'validation_accuracy': val_accuracy
#     })

    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {avg_training_loss:.4e}, Validation Loss: {avg_val_loss:.4e}, Training Accuracy: {train_accuracy:.4e}, Validation Accuracy: {val_accuracy:.4e}")

    # Check if the validation loss improved
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_no_improve = 0
        # Save the model
        # torch.save(model.state_dict(), 'best_model.pth')
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
            break  # Early stopping


# Evaluate on the validation set
model.eval()
val_predictions = []
with torch.no_grad():
    for inputs, targets, _ in DataLoader(SignalBackgroundDataset(X_val_tensor, y_val_tensor, torch.tensor(weights_val, dtype=torch.float32)), batch_size=batch_size, shuffle=False):
        inputs = inputs.to(device)
        outputs = model(inputs).squeeze()
        val_predictions.extend(outputs.cpu().numpy())
val_predictions = np.array(val_predictions)
# Out:
# Epoch 1/50, Training Loss: 1.2336e-05, Validation Loss: 8.1578e-06, Training Accuracy: 9.2470e-01, Validation Accuracy: 9.3090e-01
# Epoch 2/50, Training Loss: 1.0547e-05, Validation Loss: 9.1808e-06, Training Accuracy: 9.3102e-01, Validation Accuracy: 9.4003e-01
# Epoch 3/50, Training Loss: 7.5305e-06, Validation Loss: 8.4757e-06, Training Accuracy: 9.3608e-01, Validation Accuracy: 9.5085e-01
# Epoch 4/50, Training Loss: 7.3555e-06, Validation Loss: 8.5696e-06, Training Accuracy: 9.4008e-01, Validation Accuracy: 9.5551e-01
# Epoch 5/50, Training Loss: 6.7738e-06, Validation Loss: 7.7796e-06, Training Accuracy: 9.4703e-01, Validation Accuracy: 9.4431e-01
# Epoch 6/50, Training Loss: 5.9151e-06, Validation Loss: 7.4050e-06, Training Accuracy: 9.4854e-01, Validation Accuracy: 9.4883e-01
# Epoch 7/50, Training Loss: 5.6315e-06, Validation Loss: 7.8369e-06, Training Accuracy: 9.5178e-01, Validation Accuracy: 9.5980e-01
# Epoch 8/50, Training Loss: 6.4308e-06, Validation Loss: 6.8826e-06, Training Accuracy: 9.5380e-01, Validation Accuracy: 9.5534e-01
# Epoch 9/50, Training Loss: 5.4792e-06, Validation Loss: 8.6143e-06, Training Accuracy: 9.5676e-01, Validation Accuracy: 9.6326e-01
# Epoch 10/50, Training Loss: 5.7813e-06, Validation Loss: 7.6472e-06, Training Accuracy: 9.5302e-01, Validation Accuracy: 9.5341e-01
# Epoch 11/50, Training Loss: 4.9275e-06, Validation Loss: 7.2696e-06, Training Accuracy: 9.5873e-01, Validation Accuracy: 9.5649e-01
# Epoch 12/50, Training Loss: 4.9270e-06, Validation Loss: 6.9776e-06, Training Accuracy: 9.5904e-01, Validation Accuracy: 9.5984e-01
# Epoch 13/50, Training Loss: 5.0253e-06, Validation Loss: 7.4635e-06, Training Accuracy: 9.5973e-01, Validation Accuracy: 9.6629e-01
# Epoch 14/50, Training Loss: 4.7436e-06, Validation Loss: 6.6291e-06, Training Accuracy: 9.6040e-01, Validation Accuracy: 9.4675e-01
# Epoch 15/50, Training Loss: 4.4491e-06, Validation Loss: 7.5873e-06, Training Accuracy: 9.6235e-01, Validation Accuracy: 9.6946e-01
# Epoch 16/50, Training Loss: 4.6625e-06, Validation Loss: 7.4697e-06, Training Accuracy: 9.6320e-01, Validation Accuracy: 9.6810e-01
# Epoch 17/50, Training Loss: 4.3458e-06, Validation Loss: 7.4781e-06, Training Accuracy: 9.6529e-01, Validation Accuracy: 9.6815e-01
# Epoch 18/50, Training Loss: 4.4205e-06, Validation Loss: 7.2869e-06, Training Accuracy: 9.6558e-01, Validation Accuracy: 9.5694e-01
# Epoch 19/50, Training Loss: 4.1942e-06, Validation Loss: 7.1751e-06, Training Accuracy: 9.6605e-01, Validation Accuracy: 9.6893e-01
# Epoch 20/50, Training Loss: 4.1406e-06, Validation Loss: 6.4596e-06, Training Accuracy: 9.6566e-01, Validation Accuracy: 9.6459e-01
# Epoch 21/50, Training Loss: 4.0479e-06, Validation Loss: 6.2891e-06, Training Accuracy: 9.6743e-01, Validation Accuracy: 9.6397e-01
# Epoch 22/50, Training Loss: 3.9448e-06, Validation Loss: 6.5856e-06, Training Accuracy: 9.6842e-01, Validation Accuracy: 9.6610e-01
# Epoch 23/50, Training Loss: 3.7924e-06, Validation Loss: 6.9706e-06, Training Accuracy: 9.6957e-01, Validation Accuracy: 9.7218e-01
# Epoch 24/50, Training Loss: 4.0380e-06, Validation Loss: 7.2887e-06, Training Accuracy: 9.6640e-01, Validation Accuracy: 9.7006e-01
# Epoch 25/50, Training Loss: 3.7504e-06, Validation Loss: 6.1401e-06, Training Accuracy: 9.7006e-01, Validation Accuracy: 9.6711e-01
# Epoch 26/50, Training Loss: 3.9584e-06, Validation Loss: 6.0970e-06, Training Accuracy: 9.6853e-01, Validation Accuracy: 9.6420e-01
# Epoch 27/50, Training Loss: 3.6502e-06, Validation Loss: 5.9051e-06, Training Accuracy: 9.7061e-01, Validation Accuracy: 9.6603e-01
# Epoch 28/50, Training Loss: 3.5128e-06, Validation Loss: 6.4815e-06, Training Accuracy: 9.7202e-01, Validation Accuracy: 9.7084e-01
# Epoch 29/50, Training Loss: 3.4938e-06, Validation Loss: 6.5471e-06, Training Accuracy: 9.6996e-01, Validation Accuracy: 9.7145e-01
# Epoch 30/50, Training Loss: 3.4325e-06, Validation Loss: 6.4240e-06, Training Accuracy: 9.7166e-01, Validation Accuracy: 9.7210e-01
# Epoch 31/50, Training Loss: 3.4369e-06, Validation Loss: 5.4960e-06, Training Accuracy: 9.7196e-01, Validation Accuracy: 9.6520e-01
# Epoch 32/50, Training Loss: 3.2704e-06, Validation Loss: 7.1034e-06, Training Accuracy: 9.7254e-01, Validation Accuracy: 9.7496e-01
# Epoch 33/50, Training Loss: 3.4140e-06, Validation Loss: 6.5999e-06, Training Accuracy: 9.7152e-01, Validation Accuracy: 9.6619e-01
# Epoch 34/50, Training Loss: 3.3112e-06, Validation Loss: 7.2184e-06, Training Accuracy: 9.7154e-01, Validation Accuracy: 9.7396e-01
# Epoch 35/50, Training Loss: 3.1093e-06, Validation Loss: 6.6515e-06, Training Accuracy: 9.7416e-01, Validation Accuracy: 9.6389e-01
# Epoch 36/50, Training Loss: 3.1305e-06, Validation Loss: 7.9145e-06, Training Accuracy: 9.7391e-01, Validation Accuracy: 9.7735e-01
# Epoch 37/50, Training Loss: 3.1815e-06, Validation Loss: 6.3114e-06, Training Accuracy: 9.7451e-01, Validation Accuracy: 9.6001e-01
# Early stopping triggered after 37 epochs.

# %%
fpr, tpr, _ = roc_curve(y_val, val_predictions, sample_weight=weights_val)
roc_auc = auc(fpr, tpr)

old_bdt_score = df['bdt_score'].values[test_loc]
fpr_old, tpr_old, _ = roc_curve(y_val, old_bdt_score, sample_weight=weights_val)
roc_auc_old = auc(fpr_old, tpr_old)

# import xgboost as xgb
# import json
import joblib
# model = xgb.Booster()
# model = joblib.load('/global/u2/a/agarabag/DiTau/run/bdt_results/xgb_model.json')


# with open('/global/u2/a/agarabag/DiTau/run/bdt_results/.json', 'r') as f:
#     model_json = json.load(f)
# model = xgb.XGBClassifier()
# booster = xgb.Booster(model_file=model_json)
# model._Booster = booster
# probs = model.predict_proba(X_val)

# bst = xgb.Booster()
model = joblib.load('/global/u2/a/agarabag/DiTau/run/bdt_results/xgb_model.joblib')
probs = model.predict_proba(X_val)
# dval = xgb.DMatrix(X_val)
# probs = bst.predict(dval)

probs = probs[:, 1]
fpr_w, tpr_w, thresholds_w = roc_curve(y_val, probs, sample_weight=weights_val)
auc_w = roc_auc_score(y_val, probs, sample_weight=weights_val)

plt.figure(figsize=(22, 10))
plt.subplot(121)
plt.plot(fpr, tpr, label='BDT (area = {:.5f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], linestyle='--', label='Random classifier')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)

plt.subplot(122)
plt.plot(tpr, 1/fpr, color='black', lw=1, label='New (area = %0.5f)' % roc_auc)
plt.plot(tpr_old, 1/fpr_old, lw=1, label='Old (area = %0.5f)' % roc_auc_old)
plt.xlabel('Signal efficiency (TPR)')
plt.ylabel('Inverse backround efficiency (1/FPR)')
plt.yscale('log')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[70], line 23
#      10 import joblib
#      11 # model = xgb.Booster()
#      12 # model = joblib.load('/global/u2/a/agarabag/DiTau/run/bdt_results/xgb_model.json')
#      13
#    (...)
#      21
#      22 # bst = xgb.Booster()
# ---> 23 model = joblib.load('/global/u2/a/agarabag/DiTau/run/bdt_results/xgb_model.joblib')
#      24 probs = model.predict_proba(X_val)
#      25 # dval = xgb.DMatrix(X_val)
#      26 # probs = bst.predict(dval)
#
# File ~/.conda/envs/ditau/lib/python3.11/site-packages/joblib/numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File ~/.conda/envs/ditau/lib/python3.11/site-packages/joblib/numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File ~/.conda/envs/ditau/lib/python3.11/pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File ~/.conda/envs/ditau/lib/python3.11/site-packages/joblib/numpy_pickle.py:402, in NumpyUnpickler.load_build(self)
#     394 def load_build(self):
#     395     """Called to set the state of a newly created object.
#     396
#     397     We capture it to replace our place-holder objects, NDArrayWrapper or
#    (...)
#     400     NDArrayWrapper is used for backward compatibility with joblib <= 0.9.
#     401     """
# --> 402     Unpickler.load_build(self)
#     404     # For backward compatibility, we support NDArrayWrapper objects.
#     405     if isinstance(self.stack[-1], (NDArrayWrapper, NumpyArrayWrapper)):
#
# File ~/.conda/envs/ditau/lib/python3.11/pickle.py:1714, in _Unpickler.load_build(self)
#    1712 def load_build(self):
#    1713     stack = self.stack
# -> 1714     state = stack.pop()
#    1715     inst = stack[-1]
#    1716     setstate = getattr(inst, "__setstate__", None)
#
# IndexError: pop from empty list

# %%
sys.path.append("..")
from utils.utils import *

ROOT.gStyle.SetOptStat(0)
ROOT.gROOT.SetBatch(True)
canvas = ROOT.TCanvas("canvas", "bdt_score_new", 800, 600)
canvas.cd()
sig_score_1p3p = plt_to_root_hist_w(old_bdt_score[y_val==1], 201, 0, 1, weights_val[y_val==1], False)
bkg_score_1p3p = plt_to_root_hist_w(old_bdt_score[y_val==0], 201, 0, 1, weights_val[y_val==0], False)
# normalize_hist(sig_score_1p3p) 
# normalize_hist(bkg_score_1p3p)
sig_score_1p3p.SetLineColor(ROOT.kBlack)
bkg_score_1p3p.SetLineColor(ROOT.kOrange)
sig_score_1p3p.Draw("hist ")
bkg_score_1p3p.Draw("hist same")
ROOT.gPad.SetLogy()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: root_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: root_hist (Potential memory leak).

# %%
c2 = ROOT.TCanvas("canvas2", "ROC", 800, 600)
c2.cd()
root_1p3p_roc = create_roc_graph(sig_score_1p3p, bkg_score_1p3p, effmin=0.05, name="1p3p", normalize=False, reverse=False)
root_1p3p_roc.Draw("")
ROOT.gPad.SetLogy()
c2.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas2

# %%
sys.path.append("..")
from utils.utils import *

ROOT.gStyle.SetOptStat(0)
ROOT.gROOT.SetBatch(True)
canvas = ROOT.TCanvas("canvas", "bdt_score_new", 800, 600)
canvas.cd()
sig_score_1p3p = plt_to_root_hist_w(val_predictions[y_val==1], 201, 0, 1, weights_val[y_val==1], False)
bkg_score_1p3p = plt_to_root_hist_w(val_predictions[y_val==0], 201, 0, 1, weights_val[y_val==0], False)
# normalize_hist(sig_score_1p3p) 
# normalize_hist(bkg_score_1p3p)
sig_score_1p3p.SetLineColor(ROOT.kBlack)
bkg_score_1p3p.SetLineColor(ROOT.kOrange)
sig_score_1p3p.Draw("hist ")
bkg_score_1p3p.Draw("hist same")
ROOT.gPad.SetLogy()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: root_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: root_hist (Potential memory leak).

# %%
c2 = ROOT.TCanvas("canvas2", "ROC", 800, 600)
c2.cd()
root_1p3p_roc = create_roc_graph(sig_score_1p3p, bkg_score_1p3p, effmin=0.04, name="1p3p", normalize=False, reverse=False)
root_1p3p_roc.Draw("")
ROOT.gPad.SetLogy()
c2.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas2
