# %%
import glob, os, sys
sys.path.append("..")
from utils.utils import *
import uproot, ROOT, random, time, vector
import matplotlib.pyplot as plt
import numpy as np
import awkward as ak
import json
from sklearn.metrics import roc_curve, roc_auc_score, auc
from tqdm import tqdm
import pandas as pd
from xgboost import XGBClassifier
import seaborn as sns
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

# Set up plot defaults
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = 12.0,8.0  # Roughly 11 cm wde by 8 cm high
mpl.rcParams['font.size'] = 14.0 # Use 14 point font
sns.set(style="whitegrid")
# Out:
# Welcome to JupyROOT 6.28/04

# %%
# path = '/global/homes/a/agarabag/pscratch/ditdau_samples/nom/'
# vbfh_path = [path+'user.shhirose.Httbst_b4.mc20_13TeV.346190.PoPy8_NNPDF30_VBFH125_ttl13l7.PHYS.e7259_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.346191.PoPy8_NNPDF30_VBFH125_ttlm15hp20.PHYS.e7259_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.346192.PoPy8_NNPDF30_VBFH125_ttlp15hm20.PHYS.e7259_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.346193.PoPy8_NNPDF30_VBFH125_tth30h20.PHYS.e7259_s3681_r13145_p5855.smPre_w_0_HS/user.*.root']
# vbfh_dsid = [346190, 346191, 346192, 346193]
             
# ggh_path = [path+'user.shhirose.Httbst_b4.mc20_13TeV.345120.PoPy8_NNLO_30_ggH125_ttl13l7.PHYS.e5814_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.345121.PoPy8_NNLO_30_ggH125_ttlm15hp20.PHYS.e5814_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.345122.PoPy8_NNLO_30_ggH125_ttlp15hm20.PHYS.e5814_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.345123.PoPy8_NNLO_30_ggH125_tth30h20.PHYS.e5814_s3681_r13145_p5855.smPre_w_0_HS/user.*.root']
# ggh_dsid = [345120, 345121, 345122, 345123]

# vh_path = [path+'user.shhirose.Httbst_b4.mc20_13TeV.345211.PoPy8_NNPDF30__WmH125J_Winc_MINLO_tt.PHYS.e5808_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.345212.PoPy8_NNPDF30__WpH125J_Winc_MINLO_tt.PHYS.e5808_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.345217.PoPy8_NNPDF30__ZH125J_Zinc_MINLO_tt.PHYS.e5808_s3681_r13145_p5855.smPre_w_0_HS/user.*.root']
# vh_dsid = [345211, 345212, 345217]

# vv_path = [path+'user.shhirose.Httbst_b4.mc20_13TeV.700488.Sh_2211_WlvWqq.PHYS.e8338_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700489.Sh_2211_WlvZqq.PHYS.e8338_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700491.Sh_2211_WqqZvv.PHYS.e8338_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700492.Sh_2211_WqqZll.PHYS.e8338_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700493.Sh_2211_ZqqZll.PHYS.e8338_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700495.Sh_2211_ZqqZvv.PHYS.e8338_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700600.Sh_2212_llll.PHYS.e8433_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700601.Sh_2212_lllv.PHYS.e8433_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700602.Sh_2212_llvv_os.PHYS.e8433_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700603.Sh_2212_llvv_ss.PHYS.e8433_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700604.Sh_2212_lvvv.PHYS.e8433_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700605.Sh_2212_vvvv.PHYS.e8433_s3681_r13145_p5855.smPre_w_0_HS/user.*.root']
# vv_dsid = [700488, 700489, 700491, 700492, 700493, 700495, 700600, 700601, 700602, 700603, 700604, 700605]

# ztt_path = [path+'user.shhirose.Httbst_b4.mc20_13TeV.700792.Sh_2214_Ztt_maxHTpT_BF.PHYS.e8527_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700793.Sh_2214_Ztt_maxHTpT_CFBV.PHYS.e8527_s3681_r13145_p5855.smPre_w_0_HS/user.*.root',
# path+'user.shhirose.Httbst_b4.mc20_13TeV.700794.Sh_2214_Ztt_maxHTpT_CVBV.PHYS.e8527_s3681_r13145_p5855.smPre_w_0_HS/user.*.root']
# ztt_dsid = [700792, 700793, 700794]

# %%
##### signal ######
vbfh_dsid = [346190, 346191, 346192, 346193]      
ggh_dsid = [345120, 345121, 345122, 345123]
WH = [345211, 345212]
ZH = [345217]
ttH = [346343,346344,346345]


##### background ######
vh_dsid = [345211, 345212, 345217]
vv_dsid = [700488, 700489, 700491, 700492, 700493, 700495, 700600, 700601, 700602, 700603, 700604, 700605]
ztt_dsid = [700792, 700793, 700794]
ttV = [
    410155, # ttW
    410218, 410219, 410220, # ttZ
    # 412043, 304014 # 4t,3t #! missing these samples
    ]
Top = [
    410470, 410471, 410472, 
    410644, 410645, 410646, 410647, 
    410658, 410659
]
W = [
    700338, 700339, 700340, # Wenu
    700341, 700342, 700343, # Wmunu
    700344, 700345, 700346, # WtaunuL
    700347, 700348, 700349, # WtaunuH #! should these be included? 
    700362, 700363, 700364, # W lep + 2jets
]
Zll_inc = [
    700320, 700321, 700322, # Zee 
    700323, 700324, 700325, # Zmumu
]

# %%
# path_template_test = '/global/homes/a/agarabag/pscratch/ditdau_samples/nom_new/user.shhirose.*{dsid}.*/'
# total_dsid = vbfh_dsid + ggh_dsid + WH + ZH + ttH + vh_dsid + vv_dsid + ztt_dsid + ttV + Top + W + Zll_inc

# def check_directories_with_ids(path_template_test, dsid_arrays):
#     missing_dirs = []

#     for root, dirs, files in os.walk(path_template_test[:path_template_test.index("{dsid}")]):
#         for dsid in dsid_arrays:
#             pattern = path_template_test.format(dsid=dsid)
#             if not any(fnmatch.fnmatch(dir, pattern) for dir in dirs):
#                 missing_dirs.append(pattern)

#     return missing_dirs

# missing_dirs = check_directories_with_ids(path_template_test, total_dsid)

# if missing_dirs:
#     print("Directories missing for the following IDs:")
#     for dir in missing_dirs:
#         print(dir)
# else:
#     print("All directories associated with the IDs are present.")
# Out:
# All directories associated with the IDs are present.

# %%
def read_event_weights(event_id, data_year):
    file_path = '/global/homes/a/agarabag/pscratch/ditdau_samples/xsec_sumofweights_nom.json'
    # Load the data from the JSON file
    with open(file_path, 'r') as file:
        data = json.load(file)
    
    # Get the list of events from the key 'ditau_hh' under 'mc20a'
    events = data.get(data_year, {}).get('ditau_hh', [])

    # Iterate over each event in the list
    for event in events:
        # Check if the first element (ID) matches the provided event_id
        if event[0] == event_id:
            # Return the second (event weight) and third (sum of event weights) elements
            return (event[1], event[2])
    
    # If no matching ID is found, return None for both values
    return (None, None)

def fetch_weights(id_list, data_year):
    results = {}
    for event_id in id_list:
        event_weight, sum_event_weights = read_event_weights(event_id, data_year)
        if event_weight is None:
            print(event_id, "weights filled with one")
            results[event_id] = 1
        else: 
            results[event_id] = event_weight / sum_event_weights
    return results
            
vbfh_ws = fetch_weights(vbfh_dsid, 'mc20e')
ggh_ws = fetch_weights(ggh_dsid, 'mc20e')
vh_ws = fetch_weights(vh_dsid, 'mc20e')
vv_ws = fetch_weights(vv_dsid, 'mc20e')
ztt_ws = fetch_weights(ztt_dsid, 'mc20e')

# %%
ggh_ws, vbfh_ws, vh_ws, vv_ws, ztt_ws
# Out:
# ({345120: 2.0212026206827066e-09,
#   345121: 9.425030499444042e-09,
#   345122: 9.44410126030036e-09,
#   345123: 7.400959896584742e-09},
#  {346190: 3.328334122903121e-07,
#   346191: 2.549934635756314e-07,
#   346192: 2.5594716545460417e-07,
#   346193: 8.930663891591884e-09},
#  {345211: 2.473849483997504e-07,
#   345212: 2.4438917000744885e-07,
#   345217: 1.517906037006081e-07},
#  {700488: 5.3890969934904166e-12,
#   700489: 1.9497701952798617e-11,
#   700491: 1.949792009414876e-11,
#   700492: 2.441655930568653e-11,
#   700493: 8.574958768410377e-12,
#   700495: 1.2756139728894854e-11,
#   700600: 1.221317679493521e-12,
#   700601: 1.0418313396061567e-12,
#   700602: 2.077712372028255e-12,
#   700603: 4.3770307069093114e-11,
#   700604: 3.4483180775898836e-12,
#   700605: 1.1377011487579801e-11},
#  {700792: 5.962806109287312e-13,
#   700793: 7.996092592468891e-13,
#   700794: 5.200913291636743e-13})

# %%
# List = glob.glob(os.path.join(vbfh_path[0]))
# f = uproot.open(List[0])
# f.keys()
# f['NOMINAL'].keys()

# %% [markdown]
# Ten variables are used as input to the NN: pT of the two leptons and leading
# jet, p
# miss
# T
# , mass and pT of the Higgs boson reconstructed from the τ candidates and ~p
# miss
# T
# , ST
# (defined as the scalar sum of the pT of all jets and leptons in the events), transverse mass of the
# 4
# lepton and ~p
# miss
# T
# , value of the MVA isolation of the closest boosted τh
# candidate to the muon
# (electron) in the µτh
# and eµ (eτh
# and eµ) channels, and di-τ mass.

# %%
branches = \
['HLT_j420',
 'HLT_j420_a10t_lcw_jes_35smcINF_L1J100',
 'HLT_j420_a10t_lcw_jes_35smcINF_L1SC111',
 'ditau_obj_IsTruthHadronic',
 'ditau_obj_IsTruthMatched',
#  'boson_0_p4',
 'ditau_obj_truth_p4',
 'jets_b_tag_score',
#  'ditau_obj_R_jet',
#  'ditau_obj_R_subjet',
#  'ditau_obj_Rr_core',
 'ditau_obj_bdt_score',
#  'ditau_obj_charge',
 'ditau_obj_leadsubjet_charge',
 'ditau_obj_leadsubjet_n_core_tracks',
 'ditau_obj_leadsubjet_p4',
 'ditau_obj_nSubjets',
#  'ditau_obj_n_iso_tracks',
 'ditau_obj_n_tracks',
 'ditau_obj_p4',
#  'ditau_obj_subjets_dR',
 'ditau_obj_subleadsubjet_charge',
 'ditau_obj_subleadsubjet_n_core_tracks',
 'ditau_obj_subleadsubjet_p4',
#  'ditau_obj_tauJetVtxFraction',
 # 'missing_pt',
 # 'ditau_visible_mass',
#  'jets_p4',
#  'ditau_obj_truth_leadTau_p4',
#  'ditau_obj_truth_p4',
#  'ditau_obj_truth_subleadTau_p4',
 'NOMINAL_pileup_combined_weight',
 'weight_mc']

# %%
path_template = '/global/homes/a/agarabag/pscratch/ditdau_samples/nom/user.shhirose.*{dsid}.*/user.*.root'

def read_root(dsid_list, mc_ws):
    out = []
    for dsid in dsid_list:
        # Using wildcard pattern around the DSID
        file_pattern = path_template.format(dsid=dsid)
        files = glob.glob(file_pattern)
        s = time.time()
        for file in files:
            with uproot.open(file + ':NOMINAL') as f_1:
                events = f_1.arrays(branches, library='ak')
                events['weight'] = mc_ws[dsid] * ak.ones_like(events['ditau_obj_n_tracks'])
                out = ak.concatenate((out, events))
        print("Processed:", len(files), "files for DSID", dsid, "Time spent:", round(time.time()-s, 4), 's')
    return out

vbfh = read_root(vbfh_dsid, vbfh_ws)
ggh = read_root(ggh_dsid, ggh_ws)
vh = read_root(vh_dsid, vh_ws)
vv = read_root(vv_dsid, vv_ws)
ztt = read_root(ztt_dsid, ztt_ws)
# Out:
# Processed: 1 files for DSID 346190 Time spent: 0.1923 s
# Processed: 1 files for DSID 346191 Time spent: 0.2348 s
# Processed: 1 files for DSID 346192 Time spent: 0.4851 s
# Processed: 1 files for DSID 346193 Time spent: 0.7472 s
# Processed: 3 files for DSID 345120 Time spent: 0.9133 s
# Processed: 2 files for DSID 345121 Time spent: 0.386 s
# Processed: 2 files for DSID 345122 Time spent: 0.363 s
# Processed: 2 files for DSID 345123 Time spent: 1.1713 s
# Processed: 1 files for DSID 345211 Time spent: 0.2157 s
# Processed: 1 files for DSID 345212 Time spent: 0.3192 s
# Processed: 1 files for DSID 345217 Time spent: 0.4096 s
# Processed: 2 files for DSID 700488 Time spent: 19.38 s
# Processed: 3 files for DSID 700489 Time spent: 14.6926 s
# Processed: 2 files for DSID 700491 Time spent: 30.1823 s
# Processed: 2 files for DSID 700492 Time spent: 8.6338 s
# Processed: 1 files for DSID 700493 Time spent: 2.7661 s
# Processed: 3 files for DSID 700495 Time spent: 10.9517 s
# Processed: 10 files for DSID 700600 Time spent: 6.9494 s
# Processed: 6 files for DSID 700601 Time spent: 7.3238 s
# Processed: 3 files for DSID 700602 Time spent: 5.6568 s
# Processed: 1 files for DSID 700603 Time spent: 2.3053 s
# Processed: 1 files for DSID 700604 Time spent: 5.2639 s
# Processed: 1 files for DSID 700605 Time spent: 3.5248 s
# Processed: 11 files for DSID 700792 Time spent: 56.4723 s
# Processed: 6 files for DSID 700793 Time spent: 76.0279 s
# Processed: 34 files for DSID 700794 Time spent: 377.2692 s

# %%
# def read_root(file_paths, dsid_list, mc_ws):
#     out = []
#     for index in range(len(file_paths)):
#         l1 = glob.glob(os.path.join(file_paths[index]))
#         s = time.time()
#         for i in range(len(l1)):
#             f_1 = uproot.open(l1[i]+':NOMINAL')
#             events = f_1.arrays(branches, library='ak')
#             events['weight'] = mc_ws[dsid_list[index]]*ak.ones_like(events['ditau_obj_n_tracks']) 
#             out = ak.concatenate((events, out))
#         print("processed: ", l1[i], "time spent", round(time.time()-s, 4), 's')
#     return out
# vbfh = read_root(vbfh_path, vbfh_dsid, vbfh_ws)
# ggh = read_root(ggh_path, ggh_dsid, ggh_ws)
# vh = read_root(vh_path, vh_dsid, vh_ws)
# vv = read_root(vv_path, vv_dsid, vv_ws)
# ztt = read_root(ztt_path, ztt_dsid, ztt_ws)

# %%
def Cut(t, signal=True):
    if signal:
        cut = ak.where((t['ditau_obj_nSubjets'] >= 2) &
                   (t['ditau_obj_IsTruthHadronic'] == 1) &
                #    (t['ditau_obj_bdt_score'] >= 0.72) &
                   (t['HLT_j420'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1J100'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1SC111']) &
                   (t['ditau_obj_leadsubjet_charge'] * t['ditau_obj_subleadsubjet_charge'] == -1) &
                   (t['ditau_obj_n_tracks']-t['ditau_obj_leadsubjet_n_core_tracks']-t['ditau_obj_subleadsubjet_n_core_tracks'] == 0) &
                   (((t['ditau_obj_leadsubjet_n_core_tracks']==1) | (t['ditau_obj_leadsubjet_n_core_tracks']==3)) &
                   ((t['ditau_obj_subleadsubjet_n_core_tracks']==1) | (t['ditau_obj_subleadsubjet_n_core_tracks']==3))))
    else:
        cut = ak.where((t['ditau_obj_nSubjets'] >= 2) &
                #    (t['ditau_obj_bdt_score'] >= 0.72) &
                   (t['HLT_j420'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1J100'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1SC111']) &
                   (t['ditau_obj_leadsubjet_charge'] * t['ditau_obj_subleadsubjet_charge'] == -1) &
                   (t['ditau_obj_n_tracks']-t['ditau_obj_leadsubjet_n_core_tracks']-t['ditau_obj_subleadsubjet_n_core_tracks'] == 0) &
                   (((t['ditau_obj_leadsubjet_n_core_tracks']==1) | (t['ditau_obj_leadsubjet_n_core_tracks']==3)) &
                   ((t['ditau_obj_subleadsubjet_n_core_tracks']==1) | (t['ditau_obj_subleadsubjet_n_core_tracks']==3))))


    return t[cut]

# %%
ggh['weight_mc'][0]
# Out:
# 28.48573112487793

# %%
ggh_cut = Cut(ggh, signal=True)
vbfh_cut = Cut(vbfh, signal=True)
vv_cut = Cut(vv, signal=False)
ztt_cut = Cut(ztt, signal=False)
vh_cut = Cut(vh, signal=False)

# %%
len(ggh_cut['ditau_obj_subleadsubjet_n_core_tracks'])
# Out:
# 438

# %%
def Printcut(t):
    print(len(ak.where((t['ditau_obj_nSubjets'] >= 2))[0]))
    print(len(ak.where((t['ditau_obj_nSubjets'] >= 2) & (t['ditau_obj_bdt_score'] >= 0.72))[0]))
    print(len(ak.where((t['ditau_obj_nSubjets'] >= 2) & (t['ditau_obj_bdt_score'] >= 0.72) &
                   (t['HLT_j420'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1J100'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1SC111']))[0]))
    print(len(ak.where((t['ditau_obj_nSubjets'] >= 2) & (t['ditau_obj_bdt_score'] >= 0.72) &
           (t['HLT_j420'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1J100'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1SC111']) &
            (t['ditau_obj_leadsubjet_charge'] * t['ditau_obj_subleadsubjet_charge'] == -1))[0]))
    print(len(ak.where((t['ditau_obj_nSubjets'] >= 2) & (t['ditau_obj_bdt_score'] >= 0.72) &
               (t['HLT_j420'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1J100'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1SC111']) &
                (t['ditau_obj_leadsubjet_charge'] * t['ditau_obj_subleadsubjet_charge'] == -1) & 
                 (t['ditau_obj_n_tracks']-t['ditau_obj_leadsubjet_n_core_tracks']-t['ditau_obj_subleadsubjet_n_core_tracks'] == 0))[0]))
    print(len(ak.where((t['ditau_obj_nSubjets'] >= 2) & (t['ditau_obj_bdt_score'] >= 0.72) &
                   (t['HLT_j420'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1J100'] | t['HLT_j420_a10t_lcw_jes_35smcINF_L1SC111']) &
                   (t['ditau_obj_leadsubjet_charge'] * t['ditau_obj_subleadsubjet_charge'] == -1) &
                   (t['ditau_obj_n_tracks']-t['ditau_obj_leadsubjet_n_core_tracks']-t['ditau_obj_subleadsubjet_n_core_tracks'] == 0) &
                   (((t['ditau_obj_leadsubjet_n_core_tracks']==1) | (t['ditau_obj_leadsubjet_n_core_tracks']==3)) &
                   ((t['ditau_obj_subleadsubjet_n_core_tracks']==1) | (t['ditau_obj_subleadsubjet_n_core_tracks']==3))))[0]))

# %%
Printcut(vbfh)
# Out:
# 35260
# 6819
# 1513
# 1141
# 1080
# 1074

# %%
Printcut(ggh)
# Out:
# 32163
# 3147
# 592
# 434
# 399
# 397

# %%
def Var(t):
    '''
    return 'leadsubjet_pT', 'subleadsubjet_pT', 
    //// 'higgs_m', 'higgs_pT',
    'pT_miss', 'ditau_m', 'leadsubjet_eta', 'subleadsubjet_eta',
    'leadsubjet_phi', 'subleadsubjet_phi',
    //////'collinear_mass'
    '''
    leadsubjet_p4 = vector.obj(pt=t['ditau_obj_leadsubjet_p4'].fP.fX,
                           eta=t['ditau_obj_leadsubjet_p4'].fP.fY,
                           phi=t['ditau_obj_leadsubjet_p4'].fP.fZ,
                           energy=t['ditau_obj_leadsubjet_p4'].fE)
    
    subleadsubjet_p4 = vector.obj(pt=t['ditau_obj_subleadsubjet_p4'].fP.fX,
                           eta=t['ditau_obj_subleadsubjet_p4'].fP.fY,
                           phi=t['ditau_obj_subleadsubjet_p4'].fP.fZ,
                           energy=t['ditau_obj_subleadsubjet_p4'].fE)
    
    # jets_pt = vector.obj(px=t['jets_p4'].fP.fX, py=t['jets_p4'].fP.fY)
#     lead_jet_pt = vector.obj(px=leadsubjet_p4.px, py=leadsubjet_p4.py)
#     sublead_jet_pt = vector.obj(px=subleadsubjet_p4.px, py=subleadsubjet_p4.py)

    ditau_p4 = vector.obj(px=t['ditau_obj_truth_p4'].fP.fX,
                           py=t['ditau_obj_truth_p4'].fP.fY,
                           pz=t['ditau_obj_truth_p4'].fP.fZ,
                           energy=t['ditau_obj_truth_p4'].fE)
    # boson_p4 = vector.obj(px=t['boson_0_p4'].fP.fX,
    #                        py=t['boson_0_p4'].fP.fY,
    #                        pz=t['boson_0_p4'].fP.fZ,
    #                        energy=t['boson_0_p4'].fE)
    
    combined_weights = t['weight'] * t['weight_mc'] * t['NOMINAL_pileup_combined_weight']
    
    # ditau_met = -np.sqrt(ditau_p4.px**2 + ditau_p4.py**2)
    # boson_met = -np.sqrt(boson_p4.px**2 + boson_p4.py**2)
    # print(ditau_met)
    # print("BBBBB: ", boson_met)
    # truth_met = boson_met - ditau_met

    # pT_miss = np.sqrt(ak.sum(jets_pt.px, axis=-1)**2 + ak.sum(jets_pt.py, axis=-1)**2)

    visible_ditau_m = (leadsubjet_p4 + subleadsubjet_p4).mass    

    # x_lead = leadsubjet_p4.pt / (leadsubjet_p4.pt+pT_miss)
    # x_sublead = subleadsubjet_p4.pt / (subleadsubjet_p4.pt+pT_miss)
    # collinear_mass = ditau_m / np.sqrt(x_lead*x_sublead)
    
    # return [leadsubjet_p4.pt, subleadsubjet_p4.pt, \
    #         visible_ditau_m, leadsubjet_p4.eta, subleadsubjet_p4.eta, \
    #         leadsubjet_p4.phi, subleadsubjet_p4.phi, combined_weights]
    return [leadsubjet_p4.pt, subleadsubjet_p4.pt, \
            visible_ditau_m, leadsubjet_p4.phi, leadsubjet_p4.eta, combined_weights, t['ditau_obj_bdt_score']]

    # return {
    #     'leadsubjet_pT': leadsubjet_p4.pt, 
    #     'subleadsubjet_pT': subleadsubjet_p4.pt,
    #     'ditau_m': ditau_m, 
    #     'leadsubjet_eta': leadsubjet_p4.eta, 
    #     'subleadsubjet_eta': subleadsubjet_p4.eta,
    #     'leadsubjet_phi': leadsubjet_p4.phi, 
    #     'subleadsubjet_phi': subleadsubjet_p4.phi}

# %%
ggh_plot = Var(ggh_cut)
vbfh_plot = Var(vbfh_cut)
vv_plot = Var(vv_cut)
ztt_plot = Var(ztt_cut)

# %%
plot_var = [
    'leadsubjet_pT', 'subleadsubjet_pT',
    'ditau_m', 'leadsubjet_eta', 'subleadsubjet_eta',
    'leadsubjet_phi', 'subleadsubjet_phi'
]

plt.figure(figsize=(40, 36))
def hist(variable, plot_num):
    print("Start Plot:", variable)
    plt.subplot(5, 5, plot_num+1)
    bin = 50
    plt.hist(ggh_plot[i], bins=bin, histtype='step', linewidth=1, label=f'ggH ')
    plt.hist(vbfh_plot[i], bins=bin, histtype='step', linewidth=1, label=f'VBFH ')
    plt.hist(vv_plot[i], bins=bin, histtype='step', linewidth=1, label=f'VV ')
    # plt.hist(ztt_plot[i], bins=bin, histtype='step', linewidth=1, label=f'Ztt ', weights=np.ones_like(ztt_plot[i])/10)
    plt.xlabel(variable)
    #plt.ylabel("Number of Events (scaled)")
    #plt.title(xlabel)
#     plt.yscale('log')
    plt.legend()
    plt.grid(True)

for i, label in enumerate(plot_var, 0):
    hist(label, i)
# Out:
# Start Plot: leadsubjet_pT
# Start Plot: subleadsubjet_pT
# Start Plot: ditau_m
# Start Plot: leadsubjet_eta
# Start Plot: subleadsubjet_eta
# Start Plot: leadsubjet_phi
# Start Plot: subleadsubjet_phi

# %%
def hist(variable):
    print("Start Plot:", variable)
    bin = 20
    plt.figure(figsize=(8, 6))  # Adjust the figsize as per your preference
    if variable == 'ditau_m':
        plt.hist(ggh_plot[i], bins=bin, range=(0, 150), histtype='step', linewidth=1, label=f'ggH ', weights=ggh_plot[7]*lumi_scale_factor)
        plt.hist(vbfh_plot[i], bins=bin, range=(0, 150), histtype='step', linewidth=1, label=f'VBFH ',  weights=vbfh_plot[7]*lumi_scale_factor)
        plt.hist(vv_plot[i], bins=bin, range=(0, 150), histtype='step', linewidth=1, label=f'VV ', weights=vv_plot[7]*lumi_scale_factor)
        plt.hist(ztt_plot[i], bins=bin, range=(0, 150), histtype='step', linewidth=1, label=f'Ztt / 10', weights=ztt_plot[7]*lumi_scale_factor/10)
    elif variable == 'collinear_mass':
        plt.hist(ggh_plot[i], bins=bin, range=(0, 550), histtype='step', linewidth=1, label=f'ggH ', weights=ggh_plot[7]*lumi_scale_factor)
        plt.hist(vbfh_plot[i], bins=bin, range=(0, 550), histtype='step', linewidth=1, label=f'VBFH ',  weights=vbfh_plot[7]*lumi_scale_factor)
        plt.hist(vv_plot[i], bins=bin, range=(0, 550), histtype='step', linewidth=1, label=f'VV ', weights=vv_plot[7]*lumi_scale_factor)
        plt.hist(ztt_plot[i], bins=bin, range=(0, 550), histtype='step', linewidth=1, label=f'Ztt / 10', weights=ztt_plot[7]*lumi_scale_factor/10)
    else:
        plt.hist(ggh_plot[i], bins=bin, histtype='step', linewidth=1, label=f'ggH ', weights=ggh_plot[7]*lumi_scale_factor)
        plt.hist(vbfh_plot[i], bins=bin, histtype='step', linewidth=1, label=f'VBFH ',  weights=vbfh_plot[7]*lumi_scale_factor)
        plt.hist(vv_plot[i], bins=bin, histtype='step', linewidth=1, label=f'VV ', weights=vv_plot[7]*lumi_scale_factor)
        plt.hist(ztt_plot[i], bins=bin, histtype='step', linewidth=1, label=f'Ztt / 10', weights=ztt_plot[7]*lumi_scale_factor/10)
        
    plt.xlabel(variable)
    plt.ylabel("Number of Events (scaled)")
#     plt.yscale('log')
    plt.legend()
    plt.grid(True)
    plt.show()

for i, label in enumerate(plot_var):
    hist(label)
# Out:
# Start Plot: leadsubjet_pT
# Start Plot: subleadsubjet_pT
# Start Plot: ditau_m
# Start Plot: leadsubjet_eta
# Start Plot: subleadsubjet_eta
# Start Plot: leadsubjet_phi
# Start Plot: subleadsubjet_phi

# %%
ROOT.gROOT.SetStyle("ATLAS")
canvas = ROOT.TCanvas("canvas", "eff_plots", 500, 500)
canvas.Clear()
canvas.cd()

# ggh_plt = plt_to_root_hist_w(ggh_plot[2], 10, 0, 150, None, False)
# ggh_plt.SetLineColor(ROOT.kRed)
# ggh_plt.SetMarkerColor(ROOT.kRed)
# vbfh_plt = plt_to_root_hist_w(vbfh_plot[2], 10, 0, 150, None, False)
# vbfh_plt.SetLineColor(ROOT.kBlue)
# vbfh_plt.SetMarkerColor(ROOT.kBlue)
# vv_plt = plt_to_root_hist_w(vv_plot[2], 10, 0, 150, None, False)
# vv_plt.SetLineColor(ROOT.kGreen)
# vv_plt.SetMarkerColor(ROOT.kGreen)
# ztt_plt = plt_to_root_hist_w(ztt_plot[2], 10, 0, 150, None, False)
# ztt_plt.SetLineColor(ROOT.kOrange)
# ztt_plt.SetMarkerColor(ROOT.kOrange)

lumi_scale_factor = 58450.1 #for mc20e

ggh_plt = plt_to_root_hist_w(ggh_plot[2], 20, 0, 150, ggh_plot[7]*lumi_scale_factor, False)
ggh_plt.SetLineColor(ROOT.kBlue)
ggh_plt.SetMarkerColor(ROOT.kBlue)
vbfh_plt = plt_to_root_hist_w(vbfh_plot[2], 20, 0, 150, vbfh_plot[7]*lumi_scale_factor, False)
vbfh_plt.SetLineColor(ROOT.kRed)
vbfh_plt.SetMarkerColor(ROOT.kRed)
vv_plt = plt_to_root_hist_w(vv_plot[2], 20, 0, 150, vv_plot[7]*lumi_scale_factor, False)
vv_plt.SetLineColor(ROOT.kGreen)
vv_plt.SetMarkerColor(ROOT.kGreen)
ztt_plt = plt_to_root_hist_w(ztt_plot[2], 20, 0, 150, ztt_plot[7]*lumi_scale_factor/10, False)
ztt_plt.SetLineColor(ROOT.kOrange)
ztt_plt.SetMarkerColor(ROOT.kOrange)

# ggh_plt.Scale(1. / ggh_plt.Integral())
# vbfh_plt.Scale(1. / vbfh_plt.Integral())
# vv_plt.Scale(1. / vv_plt.Integral())
# ztt_plt.Scale(1. / ztt_plt.Integral())
# ggh_plt.Scale(1000.)
# vbfh_plt.Scale(1000.)
# vv_plt.Scale(1000.)
# ztt_plt.Scale(1000.)

ztt_plt.Draw("hist e ")
vv_plt.Draw("hist e same")
vbfh_plt.Draw("hist e same")
ggh_plt.Draw("hist e same")

ztt_plt.GetXaxis().SetTitle('Visible DiTau Mass')

legend = ROOT.TLegend(0.8, 0.8, 0.9, 0.9)
legend.SetBorderSize(0)
legend.SetFillColor(0)
legend.AddEntry(ggh_plt, "ggH")
legend.AddEntry(vbfh_plt, "VBFH")
legend.AddEntry(vv_plt, "VV")
legend.AddEntry(ztt_plt, "Ztt")
legend.Draw()

canvas.Draw()
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: root_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: root_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: root_hist (Potential memory leak).

# %%
import logging

def bin_significance_counting(signal, bkg, s_much_less_than_b=True):
    """
    Helper function to compute significance in a given bin
    Given by the following formula:

    Z = sqrt(2 * ((s + b) * log(1 + s / b) - s))
    """
    if s_much_less_than_b:
        return signal / np.sqrt(bkg)
    else:
        sig = (signal + bkg) * np.log(1 + signal / bkg) - signal
        sig = np.sqrt(2 * sig)
        return sig

def significance_bin_by_bin(signal, bkg, s_much_less_than_b=True):
    """
    Calculate total significance using bin-by-bin significance
    via a simple sum in quadrature of each bin significance
    """

    tot_signifiance = 0
    for iBin, (s, b) in enumerate(zip(signal, bkg)):
        if b <= 0:
            continue
        _sig = bin_significance_counting(s, b, s_much_less_than_b=s_much_less_than_b)
        logging.debug(
            'bin {}, signal = {}, background = {}, significance = {}'.format(
            iBin, s, b, _sig))
        tot_signifiance += _sig * _sig

    return np.sqrt(tot_signifiance)

# %%
sig_list = np.concatenate([np.array(ggh_plot[2]), np.array(vbfh_plot[2])])
sig_w_list = np.concatenate([np.array(ggh_plot[7])*lumi_scale_factor, np.array(vbfh_plot[7])*lumi_scale_factor])

bkg_list = np.concatenate([np.array(vv_plot[2]), np.array(ztt_plot[2])])
bkg_w_list = np.concatenate([np.array(vv_plot[7])*lumi_scale_factor, np.array(ztt_plot[7])*lumi_scale_factor])

sig_hist = plt_to_root_hist_w(sig_list, 20, 0, 150, sig_w_list, False)
bkg_hist = plt_to_root_hist_w(bkg_list, 20, 0, 150, bkg_w_list, False)
# sig_hist.Scale(1000.)
# bkg_hist.Scale(1000.)

significance_bin_by_bin(sig_hist, bkg_hist, s_much_less_than_b=False)
# Out:
# 1.0590920574944254
# Warning in <TROOT::Append>: Replacing existing TH1: root_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: root_hist (Potential memory leak).

# %%
np.array(vbfh_plot[2]).shape
# Out:
# (1074,)

# %%
def scatter(variable_x, variable_y):
    print("Start Scatter Plot:", variable_x, "vs", variable_y)
    plt.figure(figsize=(8, 6))  # Adjust the figsize as per your preference
#     plt.scatter(ggh_plot[i], ggh_plot[j], label='ggH', alpha=0.5, )
    plt.scatter(vbfh_plot[4], vbfh_plot[5], label='VBFH', alpha=0.5)
    plt.scatter(vv_plot[4], vv_plot[5], label='VV', alpha=0.5)
    plt.scatter(ztt_plot[4], ztt_plot[5], label='Ztt', alpha=0.03)
    plt.xlabel(variable_x)
    plt.ylabel(variable_y)
    plt.legend()
    plt.grid(True)
    plt.show()


scatter("leadsubjet_eta", 'leadsubjet_phi')
# Out:
# Start Scatter Plot: leadsubjet_eta vs leadsubjet_phi

# %%
# training_var = [
#     'leadsubjet_pT', 'subleadsubjet_pT',
#     'ditau_m', 'leadsubjet_eta', 'subleadsubjet_eta',
#     'leadsubjet_phi', 'subleadsubjet_phi', 'weight'
# ]
training_var = [
    'leadsubjet_pT', 'subleadsubjet_pT',
    'ditau_m', 'leadsubjet_phi', 'leadsubjet_eta', 'weight'
]

ggh_df = pd.DataFrame(np.array(ggh_plot).T, columns=training_var)
vbfh_df = pd.DataFrame(np.array(vbfh_plot).T, columns=training_var)
vv_df = pd.DataFrame(np.array(vv_plot).T, columns=training_var)
ztt_df = pd.DataFrame(np.array(ztt_plot).T, columns=training_var)
#combine ggh_df, vbfh_df into one df and add label column with values 1
ggh_df['label'] = 1
vbfh_df['label'] = 1
vv_df['label'] = 0
ztt_df['label'] = 0
df = pd.concat([ggh_df, vbfh_df, vv_df, ztt_df])
df
# Out:
#         leadsubjet_pT  subleadsubjet_pT     ditau_m  leadsubjet_phi  \
# 0          211.761250         63.461070   66.615230        1.739694
# 1          237.898859        105.042719  102.228745       -1.700233
# 2          227.077750        107.879742   74.630597        2.596596
# 3          207.387125        164.134766   87.593940       -2.497494
# 4          173.858094        119.113367   75.850367       -1.095264
# ...               ...               ...         ...             ...
# 130007     217.968422         58.263465   46.213397       -3.078367
# 130008     200.392812        136.866984   36.756689        1.617501
# 130009     295.088344        167.709797   69.391845       -2.361628
# 130010     223.296562        171.612109   71.516042       -2.084549
# 130011     436.632906        134.384281   82.108870       -2.099918
#
#         leadsubjet_eta        weight  label
# 0             0.180724  2.195783e-07      1
# 1            -1.208190  2.165901e-07      1
# 2             0.188478  2.137008e-07      1
# 3             1.086295  2.200535e-07      1
# 4             0.489969  2.180230e-07      1
# ...                ...           ...    ...
# 130007        2.134690  9.265185e-08      0
# 130008       -0.064757  6.369414e-08      0
# 130009        0.110125  1.993824e-08      0
# 130010        0.595729  6.745630e-08      0
# 130011        0.202870  2.819273e-08      0
#
# [138745 rows x 7 columns]

# %%
#split the data into training and testing
X = df[training_var]
y = df['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#save weights in a separate variable
weights_train = np.abs(X_train['weight']*lumi_scale_factor)
weights_test = np.abs(X_test['weight']*lumi_scale_factor)

# weights should not be included in the training data
X_train.drop(columns='weight', inplace=True)
X_test.drop(columns='weight', inplace=True)

#Change column names to integers if needed (for ML models that expect numerical feature names)
feature_mapping = {feature: i for i, feature in enumerate(X_train.columns)}
X_train.rename(columns=feature_mapping, inplace=True)
X_test.rename(columns=feature_mapping, inplace=True)

#print size of training and testing data
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape, weights_train.shape, weights_test.shape)
# Out:
# (97121, 5) (41624, 5) (97121,) (41624,) (97121,) (41624,)

# %%
weights_train
# Out:
# 36326     0.003177
# 122153    0.005736
# 462       0.001115
# 99994     0.003801
# 28641     0.001348
#             ...
# 101535    0.004445
# 111146    0.002096
# 94961     0.004324
# 123199    0.006467
# 113225    0.001847
# Name: weight, Length: 97121, dtype: float64

# %%
# create the BDT
params = {
'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 300,
'eval_metric': 'logloss',
'random_state': 0,
'gamma': 0.001,
'verbosity': 2
}
bdt = XGBClassifier(**params)

# Train the classifier
# bdt.fit(X_train, y_train, eval_set=[(X_test, y_test)], sample_weight=weights_train)
bdt.fit(X_train, y_train, eval_set=[(X_test, y_test)])
# Out:
# [0]	validation_0-logloss:0.15278
# [1]	validation_0-logloss:0.14929
# [2]	validation_0-logloss:0.14592
# [3]	validation_0-logloss:0.14267
# [4]	validation_0-logloss:0.13953
# [5]	validation_0-logloss:0.13650
# [6]	validation_0-logloss:0.13357
# [7]	validation_0-logloss:0.13074
# [8]	validation_0-logloss:0.12801
# [9]	validation_0-logloss:0.12538
# [10]	validation_0-logloss:0.12283
# [11]	validation_0-logloss:0.12037
# [12]	validation_0-logloss:0.11799
# [13]	validation_0-logloss:0.11569
# [14]	validation_0-logloss:0.11346
# [15]	validation_0-logloss:0.11132
# [16]	validation_0-logloss:0.10924
# [17]	validation_0-logloss:0.10724
# [18]	validation_0-logloss:0.10530
# [19]	validation_0-logloss:0.10343
# [20]	validation_0-logloss:0.10162
# [21]	validation_0-logloss:0.09987
# [22]	validation_0-logloss:0.09819
# [23]	validation_0-logloss:0.09656
# [24]	validation_0-logloss:0.09498
# [25]	validation_0-logloss:0.09346
# [26]	validation_0-logloss:0.09198
# [27]	validation_0-logloss:0.09056
# [28]	validation_0-logloss:0.08918
# [29]	validation_0-logloss:0.08785
# [30]	validation_0-logloss:0.08657
# [31]	validation_0-logloss:0.08533
# [32]	validation_0-logloss:0.08413
# [33]	validation_0-logloss:0.08296
# [34]	validation_0-logloss:0.08184
# [35]	validation_0-logloss:0.08076
# [36]	validation_0-logloss:0.07972
# [37]	validation_0-logloss:0.07872
# [38]	validation_0-logloss:0.07774
# [39]	validation_0-logloss:0.07681
# [40]	validation_0-logloss:0.07590
# [41]	validation_0-logloss:0.07503
# [42]	validation_0-logloss:0.07416
# [43]	validation_0-logloss:0.07333
# [44]	validation_0-logloss:0.07254
# [45]	validation_0-logloss:0.07176
# [46]	validation_0-logloss:0.07103
# [47]	validation_0-logloss:0.07032
# [48]	validation_0-logloss:0.06963
# [49]	validation_0-logloss:0.06897
# [50]	validation_0-logloss:0.06832
# [51]	validation_0-logloss:0.06771
# [52]	validation_0-logloss:0.06710
# [53]	validation_0-logloss:0.06653
# [54]	validation_0-logloss:0.06596
# [55]	validation_0-logloss:0.06541
# [56]	validation_0-logloss:0.06489
# [57]	validation_0-logloss:0.06438
# [58]	validation_0-logloss:0.06390
# [59]	validation_0-logloss:0.06342
# [60]	validation_0-logloss:0.06297
# [61]	validation_0-logloss:0.06252
# [62]	validation_0-logloss:0.06210
# [63]	validation_0-logloss:0.06170
# [64]	validation_0-logloss:0.06130
# [65]	validation_0-logloss:0.06091
# [66]	validation_0-logloss:0.06055
# [67]	validation_0-logloss:0.06017
# [68]	validation_0-logloss:0.05984
# [69]	validation_0-logloss:0.05949
# [70]	validation_0-logloss:0.05917
# [71]	validation_0-logloss:0.05887
# [72]	validation_0-logloss:0.05856
# [73]	validation_0-logloss:0.05828
# [74]	validation_0-logloss:0.05800
# [75]	validation_0-logloss:0.05774
# [76]	validation_0-logloss:0.05748
# [77]	validation_0-logloss:0.05722
# [78]	validation_0-logloss:0.05697
# [79]	validation_0-logloss:0.05674
# [80]	validation_0-logloss:0.05652
# [81]	validation_0-logloss:0.05629
# [82]	validation_0-logloss:0.05609
# [83]	validation_0-logloss:0.05588
# [84]	validation_0-logloss:0.05569
# [85]	validation_0-logloss:0.05551
# [86]	validation_0-logloss:0.05532
# [87]	validation_0-logloss:0.05515
# [88]	validation_0-logloss:0.05498
# [89]	validation_0-logloss:0.05481
# [90]	validation_0-logloss:0.05466
# [91]	validation_0-logloss:0.05451
# [92]	validation_0-logloss:0.05435
# [93]	validation_0-logloss:0.05422
# [94]	validation_0-logloss:0.05407
# [95]	validation_0-logloss:0.05395
# [96]	validation_0-logloss:0.05382
# [97]	validation_0-logloss:0.05370
# [98]	validation_0-logloss:0.05357
# [99]	validation_0-logloss:0.05347
# [100]	validation_0-logloss:0.05336
# [101]	validation_0-logloss:0.05326
# [102]	validation_0-logloss:0.05315
# [103]	validation_0-logloss:0.05306
# [104]	validation_0-logloss:0.05296
# [105]	validation_0-logloss:0.05286
# [106]	validation_0-logloss:0.05276
# [107]	validation_0-logloss:0.05267
# [108]	validation_0-logloss:0.05258
# [109]	validation_0-logloss:0.05249
# [110]	validation_0-logloss:0.05240
# [111]	validation_0-logloss:0.05233
# [112]	validation_0-logloss:0.05226
# [113]	validation_0-logloss:0.05218
# [114]	validation_0-logloss:0.05211
# [115]	validation_0-logloss:0.05204
# [116]	validation_0-logloss:0.05198
# [117]	validation_0-logloss:0.05191
# [118]	validation_0-logloss:0.05185
# [119]	validation_0-logloss:0.05179
# [120]	validation_0-logloss:0.05174
# [121]	validation_0-logloss:0.05166
# [122]	validation_0-logloss:0.05161
# [123]	validation_0-logloss:0.05157
# [124]	validation_0-logloss:0.05150
# [125]	validation_0-logloss:0.05145
# [126]	validation_0-logloss:0.05141
# [127]	validation_0-logloss:0.05135
# [128]	validation_0-logloss:0.05131
# [129]	validation_0-logloss:0.05126
# [130]	validation_0-logloss:0.05122
# [131]	validation_0-logloss:0.05116
# [132]	validation_0-logloss:0.05112
# [133]	validation_0-logloss:0.05109
# [134]	validation_0-logloss:0.05105
# [135]	validation_0-logloss:0.05102
# [136]	validation_0-logloss:0.05096
# [137]	validation_0-logloss:0.05094
# [138]	validation_0-logloss:0.05091
# [139]	validation_0-logloss:0.05087
# [140]	validation_0-logloss:0.05082
# [141]	validation_0-logloss:0.05080
# [142]	validation_0-logloss:0.05077
# [143]	validation_0-logloss:0.05074
# [144]	validation_0-logloss:0.05072
# [145]	validation_0-logloss:0.05067
# [146]	validation_0-logloss:0.05065
# [147]	validation_0-logloss:0.05062
# [148]	validation_0-logloss:0.05060
# [149]	validation_0-logloss:0.05056
# [150]	validation_0-logloss:0.05053
# [151]	validation_0-logloss:0.05052
# [152]	validation_0-logloss:0.05049
# [153]	validation_0-logloss:0.05047
# [154]	validation_0-logloss:0.05044
# [155]	validation_0-logloss:0.05042
# [156]	validation_0-logloss:0.05040
# [157]	validation_0-logloss:0.05038
# [158]	validation_0-logloss:0.05036
# [159]	validation_0-logloss:0.05032
# [160]	validation_0-logloss:0.05031
# [161]	validation_0-logloss:0.05029
# [162]	validation_0-logloss:0.05028
# [163]	validation_0-logloss:0.05026
# [164]	validation_0-logloss:0.05024
# [165]	validation_0-logloss:0.05021
# [166]	validation_0-logloss:0.05020
# [167]	validation_0-logloss:0.05018
# [168]	validation_0-logloss:0.05017
# [169]	validation_0-logloss:0.05016
# [170]	validation_0-logloss:0.05015
# [171]	validation_0-logloss:0.05014
# [172]	validation_0-logloss:0.05014
# [173]	validation_0-logloss:0.05013
# [174]	validation_0-logloss:0.05011
# [175]	validation_0-logloss:0.05010
# [176]	validation_0-logloss:0.05009
# [177]	validation_0-logloss:0.05008
# [178]	validation_0-logloss:0.05007
# [179]	validation_0-logloss:0.05006
# [180]	validation_0-logloss:0.05005
# [181]	validation_0-logloss:0.05002
# [182]	validation_0-logloss:0.05001
# [183]	validation_0-logloss:0.04999
# [184]	validation_0-logloss:0.04998
# [185]	validation_0-logloss:0.04997
# [186]	validation_0-logloss:0.04997
# [187]	validation_0-logloss:0.04995
# [188]	validation_0-logloss:0.04994
# [189]	validation_0-logloss:0.04993
# [190]	validation_0-logloss:0.04991
# [191]	validation_0-logloss:0.04990
# [192]	validation_0-logloss:0.04989
# [193]	validation_0-logloss:0.04987
# [194]	validation_0-logloss:0.04987
# [195]	validation_0-logloss:0.04986
# [196]	validation_0-logloss:0.04986
# [197]	validation_0-logloss:0.04985
# [198]	validation_0-logloss:0.04984
# [199]	validation_0-logloss:0.04981
# [200]	validation_0-logloss:0.04981
# [201]	validation_0-logloss:0.04980
# [202]	validation_0-logloss:0.04980
# [203]	validation_0-logloss:0.04979
# [204]	validation_0-logloss:0.04977
# [205]	validation_0-logloss:0.04975
# [206]	validation_0-logloss:0.04974
# [207]	validation_0-logloss:0.04974
# [208]	validation_0-logloss:0.04974
# [209]	validation_0-logloss:0.04972
# [210]	validation_0-logloss:0.04971
# [211]	validation_0-logloss:0.04971
# [212]	validation_0-logloss:0.04970
# [213]	validation_0-logloss:0.04970
# [214]	validation_0-logloss:0.04970
# [215]	validation_0-logloss:0.04969
# [216]	validation_0-logloss:0.04967
# [217]	validation_0-logloss:0.04967
# [218]	validation_0-logloss:0.04966
# [219]	validation_0-logloss:0.04965
# [220]	validation_0-logloss:0.04963
# [221]	validation_0-logloss:0.04962
# [222]	validation_0-logloss:0.04962
# [223]	validation_0-logloss:0.04961
# [224]	validation_0-logloss:0.04961
# [225]	validation_0-logloss:0.04959
# [226]	validation_0-logloss:0.04958
# [227]	validation_0-logloss:0.04958
# [228]	validation_0-logloss:0.04957
# [229]	validation_0-logloss:0.04957
# [230]	validation_0-logloss:0.04956
# [231]	validation_0-logloss:0.04956
# [232]	validation_0-logloss:0.04955
# [233]	validation_0-logloss:0.04955
# [234]	validation_0-logloss:0.04954
# [235]	validation_0-logloss:0.04954
# [236]	validation_0-logloss:0.04954
# [237]	validation_0-logloss:0.04952
# [238]	validation_0-logloss:0.04951
# [239]	validation_0-logloss:0.04948
# [240]	validation_0-logloss:0.04948
# [241]	validation_0-logloss:0.04948
# [242]	validation_0-logloss:0.04948
# [243]	validation_0-logloss:0.04948
# [244]	validation_0-logloss:0.04946
# [245]	validation_0-logloss:0.04945
# [246]	validation_0-logloss:0.04944
# [247]	validation_0-logloss:0.04943
# [248]	validation_0-logloss:0.04943
# [249]	validation_0-logloss:0.04943
# [250]	validation_0-logloss:0.04942
# [251]	validation_0-logloss:0.04942
# [252]	validation_0-logloss:0.04942
# [253]	validation_0-logloss:0.04940
# [254]	validation_0-logloss:0.04939
# [255]	validation_0-logloss:0.04939
# [256]	validation_0-logloss:0.04939
# [257]	validation_0-logloss:0.04938
# [258]	validation_0-logloss:0.04937
# [259]	validation_0-logloss:0.04937
# [260]	validation_0-logloss:0.04937
# [261]	validation_0-logloss:0.04937
# [262]	validation_0-logloss:0.04937
# [263]	validation_0-logloss:0.04936
# [264]	validation_0-logloss:0.04936
# [265]	validation_0-logloss:0.04935
# [266]	validation_0-logloss:0.04935
# [267]	validation_0-logloss:0.04935
# [268]	validation_0-logloss:0.04935
# [269]	validation_0-logloss:0.04935
# [270]	validation_0-logloss:0.04935
# [271]	validation_0-logloss:0.04934
# [272]	validation_0-logloss:0.04935
# [273]	validation_0-logloss:0.04934
# [274]	validation_0-logloss:0.04934
# [275]	validation_0-logloss:0.04933
# [276]	validation_0-logloss:0.04934
# [277]	validation_0-logloss:0.04933
# [278]	validation_0-logloss:0.04933
# [279]	validation_0-logloss:0.04933
# [280]	validation_0-logloss:0.04932
# [281]	validation_0-logloss:0.04932
# [282]	validation_0-logloss:0.04932
# [283]	validation_0-logloss:0.04932
# [284]	validation_0-logloss:0.04931
# [285]	validation_0-logloss:0.04931
# [286]	validation_0-logloss:0.04931
# [287]	validation_0-logloss:0.04930
# [288]	validation_0-logloss:0.04931
# [289]	validation_0-logloss:0.04931
# [290]	validation_0-logloss:0.04929
# [291]	validation_0-logloss:0.04929
# [292]	validation_0-logloss:0.04928
# [293]	validation_0-logloss:0.04928
# [294]	validation_0-logloss:0.04928
# [295]	validation_0-logloss:0.04928
# [296]	validation_0-logloss:0.04928
# [297]	validation_0-logloss:0.04927
# [298]	validation_0-logloss:0.04926
# [299]	validation_0-logloss:0.04926
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=0.001, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, random_state=0, ...)

# %%
# plot the ROC curve
y_pred = bdt.predict_proba(X_test)[:, 1]

# fpr, tpr, thresholds = roc_curve(y_test, y_pred, sample_weight=weights_test)
# roc_auc = roc_auc_score(y_test, y_pred, sample_weight=weights_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'(AUC={roc_auc:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='k', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
plt.plot(tpr, 1/fpr, lw=1)
plt.xlabel('Signal efficiency (TPR)')
plt.ylabel('Inverse background efficiency (1/FPR)')
plt.yscale('log')
plt.grid(True, which="both", ls="--")
plt.show()

print(len(y_pred[y_test == 1]), len(y_pred[y_test == 0]))

signal_scores = y_pred[y_test == 1]
background_scores = y_pred[y_test == 0]
plt.figure(figsize=(8, 6))
plt.hist(signal_scores, bins=50, alpha=0.5, color='blue', label='Signal', histtype='step')
plt.hist(background_scores, bins=50, alpha=0.5, color='red', label='Background', histtype='step')
plt.xlabel('Score')
plt.yscale('log')
plt.legend(loc='upper center')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_2232012/2610640352.py:19: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr, 1/fpr, lw=1)
# 509 41115

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

start = time.time()

learning_rate = 0.0001
batch_size = 256
dropout = 0.1
neuron1 = 32
neuron2 = 125
# neuron3 = 512
neuron4 = 125
neuron5 = 32


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Convert to PyTorch tensors and move to device
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).to(device)
# weights_train_tensor = torch.tensor(weights_train.values, dtype=torch.float32).to(device)

X_val_tensor = torch.tensor(X_test.values, dtype=torch.float32).to(device)
y_val_tensor = torch.tensor(y_test.values, dtype=torch.float32).to(device)

# Define the Dataset
class SignalBackgroundDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels
        # self.weights = weights

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# Define the DNN model with dropout
class DNN(nn.Module):
    def __init__(self, input_size):
        super(DNN, self).__init__()
        self.fc1 = nn.Linear(input_size, neuron1)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
        self.fc2 = nn.Linear(neuron1, neuron2)
        self.fc3 = nn.Linear(neuron2, neuron4)
        # self.fc4 = nn.Linear(neuron3, neuron4)
        self.fc5 = nn.Linear(neuron4, neuron5)
        self.fc6 = nn.Linear(neuron5, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.relu(self.fc3(x))
        x = self.dropout(x)
        # x = self.relu(self.fc4(x))
        # x = self.dropout(x)
        x = self.relu(self.fc5(x))
        x = self.dropout(x)
        x = self.sigmoid(self.fc6(x))
        return x

model = DNN(X_train_tensor.shape[1]).to(device)
criterion = nn.BCELoss(reduction='none')
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Create DataLoader for training data
train_dataset = SignalBackgroundDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = SignalBackgroundDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

num_epochs = 60
patience = 6  # How many epochs to wait after last time validation loss improved.
best_val_loss = np.inf  # Initialize best validation loss to infinity
epochs_no_improve = 0  # Counter for epochs with no improvement

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_predictions, total_predictions = 0, 0

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), targets)
        # loss = (loss * batch_weights).mean()
        loss = loss.mean()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # binary classification for accuracy calculation
        preds = outputs.squeeze().round()
        correct_predictions += (preds == targets).sum().item()
        total_predictions += targets.size(0)

    train_accuracy = correct_predictions / total_predictions
    avg_training_loss = running_loss / len(train_loader)

    # Validation phase
    model.eval()
    val_running_loss = 0.0
    correct_predictions, total_predictions = 0, 0

    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), targets)
            # loss = (loss * batch_weights).mean()
            loss = loss.mean()

            val_running_loss += loss.item()

            preds = outputs.squeeze().round()
            correct_predictions += (preds == targets).sum().item()
            total_predictions += targets.size(0)

    val_accuracy = correct_predictions / total_predictions
    avg_val_loss = val_running_loss / len(val_loader)

#     # Log metrics to W&B
#     wandb.log({
#         'epoch': epoch,
#         'training_loss': avg_training_loss,
#         'validation_loss': avg_val_loss,
#         'training_accuracy': train_accuracy,
#         'validation_accuracy': val_accuracy
#     })

    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {avg_training_loss:.4e}, Validation Loss: {avg_val_loss:.4e}, Training Accuracy: {train_accuracy:.4e}, Validation Accuracy: {val_accuracy:.4e}")

    # Check if the validation loss improved
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_no_improve = 0
        # Save the model
        # torch.save(model.state_dict(), 'best_model.pth')
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
            break  # Early stopping


# Evaluate on the validation set
model.eval()
val_predictions = []
with torch.no_grad():
    for inputs, targets in DataLoader(SignalBackgroundDataset(X_val_tensor, y_val_tensor), batch_size=batch_size, shuffle=False):
        inputs = inputs.to(device)
        outputs = model(inputs).squeeze()
        val_predictions.extend(outputs.cpu().numpy())
val_predictions = np.array(val_predictions)

# Compute ROC curve and ROC area
fpr_mlp, tpr_mlp, _ = roc_curve(y_test.values, val_predictions)
roc_auc_mlp = auc(fpr_mlp, tpr_mlp)

plt.figure(figsize=(22, 10))
plt.subplot(121)
plt.plot(fpr_mlp, tpr_mlp, label='MLP (area = {:.5f})'.format(roc_auc_mlp))
plt.plot([0, 1], [0, 1], linestyle='--', label='Random classifier')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)

plt.subplot(122)
plt.plot(tpr_mlp, 1/fpr_mlp, color='black', lw=1)
plt.xlabel('Signal efficiency (TPR)')
plt.ylabel('Inverse backround efficiency (1/FPR)')
plt.yscale('log')
plt.grid(True, which="both", ls="--")
plt.show()

print(f'Pytorch Time: {(time.time() - start)/60} min')
# Out:
# Epoch 1/60, Training Loss: 8.2091e-02, Validation Loss: 7.3850e-02, Training Accuracy: 9.8745e-01, Validation Accuracy: 9.8777e-01
# Epoch 2/60, Training Loss: 7.2485e-02, Validation Loss: 6.9898e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 3/60, Training Loss: 7.1291e-02, Validation Loss: 7.0828e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 4/60, Training Loss: 7.0217e-02, Validation Loss: 6.9322e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 5/60, Training Loss: 6.8571e-02, Validation Loss: 6.8008e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 6/60, Training Loss: 6.8095e-02, Validation Loss: 6.7276e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 7/60, Training Loss: 6.7364e-02, Validation Loss: 6.9212e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 8/60, Training Loss: 6.6810e-02, Validation Loss: 6.7897e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 9/60, Training Loss: 6.5933e-02, Validation Loss: 6.6005e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 10/60, Training Loss: 6.5550e-02, Validation Loss: 6.8517e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 11/60, Training Loss: 6.5324e-02, Validation Loss: 6.7921e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 12/60, Training Loss: 6.5061e-02, Validation Loss: 6.6101e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 13/60, Training Loss: 6.4048e-02, Validation Loss: 6.6566e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 14/60, Training Loss: 6.3541e-02, Validation Loss: 6.4958e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 15/60, Training Loss: 6.3853e-02, Validation Loss: 6.5007e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 16/60, Training Loss: 6.3365e-02, Validation Loss: 6.3621e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 17/60, Training Loss: 6.2553e-02, Validation Loss: 6.4045e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 18/60, Training Loss: 6.2629e-02, Validation Loss: 6.2267e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 19/60, Training Loss: 6.2714e-02, Validation Loss: 6.4758e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 20/60, Training Loss: 6.1582e-02, Validation Loss: 6.3570e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 21/60, Training Loss: 6.1416e-02, Validation Loss: 6.2061e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 22/60, Training Loss: 6.1421e-02, Validation Loss: 6.3975e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 23/60, Training Loss: 6.0865e-02, Validation Loss: 6.2972e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 24/60, Training Loss: 6.0033e-02, Validation Loss: 6.0097e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 25/60, Training Loss: 6.0164e-02, Validation Loss: 5.9740e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 26/60, Training Loss: 5.9792e-02, Validation Loss: 5.9267e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 27/60, Training Loss: 5.9551e-02, Validation Loss: 5.9432e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 28/60, Training Loss: 5.9211e-02, Validation Loss: 5.9371e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 29/60, Training Loss: 5.8950e-02, Validation Loss: 5.8498e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 30/60, Training Loss: 5.8535e-02, Validation Loss: 5.8567e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 31/60, Training Loss: 5.8243e-02, Validation Loss: 5.8402e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 32/60, Training Loss: 5.7796e-02, Validation Loss: 5.7674e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 33/60, Training Loss: 5.7326e-02, Validation Loss: 5.8008e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 34/60, Training Loss: 5.7256e-02, Validation Loss: 5.7164e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 35/60, Training Loss: 5.6699e-02, Validation Loss: 5.6729e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 36/60, Training Loss: 5.6570e-02, Validation Loss: 5.7127e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 37/60, Training Loss: 5.6777e-02, Validation Loss: 5.7617e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 38/60, Training Loss: 5.6079e-02, Validation Loss: 5.6236e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 39/60, Training Loss: 5.5715e-02, Validation Loss: 5.5444e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 40/60, Training Loss: 5.5517e-02, Validation Loss: 5.5763e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 41/60, Training Loss: 5.5227e-02, Validation Loss: 5.4865e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 42/60, Training Loss: 5.5278e-02, Validation Loss: 5.4741e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 43/60, Training Loss: 5.4792e-02, Validation Loss: 5.5089e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 44/60, Training Loss: 5.4257e-02, Validation Loss: 5.4245e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 45/60, Training Loss: 5.4521e-02, Validation Loss: 5.3959e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 46/60, Training Loss: 5.3711e-02, Validation Loss: 5.3619e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 47/60, Training Loss: 5.3988e-02, Validation Loss: 5.3481e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 48/60, Training Loss: 5.3744e-02, Validation Loss: 5.3306e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 49/60, Training Loss: 5.3676e-02, Validation Loss: 5.3011e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 50/60, Training Loss: 5.3085e-02, Validation Loss: 5.3006e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 51/60, Training Loss: 5.3194e-02, Validation Loss: 5.2697e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 52/60, Training Loss: 5.3108e-02, Validation Loss: 5.2803e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 53/60, Training Loss: 5.3107e-02, Validation Loss: 5.2367e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 54/60, Training Loss: 5.2738e-02, Validation Loss: 5.2201e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 55/60, Training Loss: 5.2730e-02, Validation Loss: 5.2682e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 56/60, Training Loss: 5.2296e-02, Validation Loss: 5.2053e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 57/60, Training Loss: 5.2322e-02, Validation Loss: 5.2667e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 58/60, Training Loss: 5.2522e-02, Validation Loss: 5.2066e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 59/60, Training Loss: 5.1964e-02, Validation Loss: 5.1907e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# Epoch 60/60, Training Loss: 5.2000e-02, Validation Loss: 5.2022e-02, Training Accuracy: 9.8854e-01, Validation Accuracy: 9.8777e-01
# /tmp/ipykernel_2232012/2485418620.py:184: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(tpr_mlp, 1/fpr_mlp, color='black', lw=1)
# Pytorch Time: 3.32885324160258 min

# %%
# plot score distribution from MLP
signal_scores = val_predictions[y_test == 1]
background_scores = val_predictions[y_test == 0]
plt.figure(figsize=(8, 6))
plt.hist(signal_scores, bins=50, alpha=0.5, color='blue', label='Signal', histtype='step')
plt.hist(background_scores, bins=50, alpha=0.5, color='red', label='Background', histtype='step')
plt.xlabel('Score')
plt.yscale('log')
plt.legend(loc='upper center')
# plt.grid(True)
plt.show()
